# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/stylegan2-toys/blob/master/morph_video_real.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Jeff Heaton](https://raw.githubusercontent.com/jeffheaton/present/master/images/github.jpg)
#
# Copyright 2021 by [Jeff Heaton](https://www.youtube.com/channel/UCR1-GEpyOPzT2AO4D_eifdw), [released under Apache 2.0 license](https://github.com/jeffheaton/present/blob/master/LICENSE)
# # StyleGAN2 Morph Between Two REAL Images
#
# This notebook allows you to choose a starting and ending image and use StyleGAN2 to produce a "morph" video between the two pictures.  For the morph to work correctly, both images should be of human faces.  It helps if both pictures are cropped reasonably well to a square portrait to eliminate the possibility of two faces being present in one image.  The preprocessing code will lock in on the exact positioning of each image, so your crop does not have to be perfect. The main point of your crop is for you to remove anything else that might be confused for a face.  If multiple faces are detected, you will receive an error.
#
# Also, make sure you have selected a GPU Runtime from CoLab. Choose "Runtime," then "Change Runtime Type," and choose GPU for "Hardware Accelerator."
#
# The following YouTube video describes precisely how to run this notebook.
#
# [Morphing Real Images to Video with StyleGAN2 ADA](http://youtube.com)
#
# These settings allow you to change the high-level configuration.  The number of steps determines how long your resulting video is.  The video plays at 30 frames a second, so 150 is 5 seconds. You can also specify freeze steps to leave the video unchanged at the beginning and end. You will not likely need to change the network.

# %%
STEPS = 1000
FPS = 30
FREEZE_STEPS = 30

# %%
# Let's get the tick-4920 trained StyleGAN2-ADA.

from google.colab import files
files.upload()  # Upload your kaggle.json here.

# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# Kaggle datasets here.

# Trained tick-4920.
# !mkdir stylegan2ada-weights
# %cd stylegan2ada-weights/
# !kaggle datasets download -d edwardyangiscool/stylegan-weights
# !unzip -q stylegan-weights.zip
# !rm stylegan-weights.zip
# %cd ../
# Out:
#      <input type="file" id="files-21b772ab-de59-468d-a7b3-ff739d7e2b7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21b772ab-de59-468d-a7b3-ff739d7e2b7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json
# mkdir: cannot create directory ‘stylegan2ada-weights’: File exists
# /content/stylegan2ada-weights
# Downloading stylegan-weights.zip to /content/stylegan2ada-weights
#  99% 249M/251M [00:01<00:00, 169MB/s]
# 100% 251M/251M [00:01<00:00, 168MB/s]
# replace network-snapshot-004920.pkl? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
# /content

# %%
NETWORK = r"/content/stylegan2ada-weights/network-snapshot-004920.pkl"

# %% [markdown]
# # Upload Starting Image
#
# Choose your starting image.

# %%
import os
from google.colab import files

uploaded = files.upload()

if len(uploaded) != 1:
  print("Upload exactly 1 file for source.")
else:
  for k, v in uploaded.items():
    _, ext = os.path.splitext(k)
    os.remove(k)
    SOURCE_NAME = f"source{ext}"
    open(SOURCE_NAME, 'wb').write(v)
# Out:
#      <input type="file" id="files-e540b3fb-d047-424e-9be1-ce020da7cbc5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e540b3fb-d047-424e-9be1-ce020da7cbc5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Screen Shot 2022-01-04 at 7.20.02 PM.png to Screen Shot 2022-01-04 at 7.20.02 PM.png

# %% [markdown]
# Also, choose your ending image.

# %%
uploaded = files.upload()

if len(uploaded) != 1:
  print("Upload exactly 1 file for target.")
else:
  for k, v in uploaded.items():
    _, ext = os.path.splitext(k)
    os.remove(k)
    TARGET_NAME = f"target{ext}"
    open(TARGET_NAME, 'wb').write(v)
# Out:
#      <input type="file" id="files-134ad2d9-5cf9-47a6-a506-834594684852" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-134ad2d9-5cf9-47a6-a506-834594684852">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Screen Shot 2022-01-04 at 7.20.11 PM.png to Screen Shot 2022-01-04 at 7.20.11 PM.png

# %% [markdown]
# # Install Software
#
# Some software must be installed into Colab, for this notebook to work. We are specificially using these technologies:
#
# * [Training Generative Adversarial Networks with Limited Data](https://arxiv.org/abs/2006.06676)
# Tero Karras, Miika Aittala, Janne Hellsten, Samuli Laine, Jaakko Lehtinen, Timo Aila
# * [One millisecond face alignment with an ensemble of regression trees](https://www.cv-foundation.org/openaccess/content_cvpr_2014/papers/Kazemi_One_Millisecond_Face_2014_CVPR_paper.pdf) Vahid Kazemi, Josephine Sullivan

# %%
# !wget http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# !bzip2 -d shape_predictor_5_face_landmarks.dat.bz2
# Out:
# --2022-01-05 04:27:35--  http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5706710 (5.4M)
# Saving to: ‘shape_predictor_5_face_landmarks.dat.bz2.1’
#
# shape_predictor_5_f 100%[===================>]   5.44M  28.7MB/s    in 0.2s
#
# 2022-01-05 04:27:35 (28.7 MB/s) - ‘shape_predictor_5_face_landmarks.dat.bz2.1’ saved [5706710/5706710]
#
# bzip2: Output file shape_predictor_5_face_landmarks.dat already exists.

# %%
import sys
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# !pip install ninja
sys.path.insert(0, "/content/stylegan2-ada-pytorch")
# Out:
# fatal: destination path 'stylegan2-ada-pytorch' already exists and is not an empty directory.
# Requirement already satisfied: ninja in /usr/local/lib/python3.7/dist-packages (1.10.2.3)

# %% [markdown]
# # Preprocess Images for Best StyleGAN Results
#
# The following are helper functions for the preprocessing.

# %%
import cv2
import numpy as np
from PIL import Image
import dlib

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_5_face_landmarks.dat')

def find_eyes(img):
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  rects = detector(gray, 0)
  
  if len(rects) == 0:
    raise ValueError("No faces detected")
  elif len(rects) > 1:
    raise ValueError("Multiple faces detected")

  shape = predictor(gray, rects[0])
  features = []

  for i in range(0, 5):
    features.append((i, (shape.part(i).x, shape.part(i).y)))

  return (int(features[3][1][0] + features[2][1][0]) // 2, \
    int(features[3][1][1] + features[2][1][1]) // 2), \
    (int(features[1][1][0] + features[0][1][0]) // 2, \
    int(features[1][1][1] + features[0][1][1]) // 2)

def crop_stylegan(img):
  left_eye, right_eye = find_eyes(img)
  d = abs(right_eye[0] - left_eye[0])
  z = 255/d
  ar = img.shape[0]/img.shape[1]
  w = img.shape[1] * z
  img2 = cv2.resize(img, (int(w), int(w*ar)))
  bordersize = 1024
  img3 = cv2.copyMakeBorder(
      img2,
      top=bordersize,
      bottom=bordersize,
      left=bordersize,
      right=bordersize,
      borderType=cv2.BORDER_REPLICATE)

  left_eye2, right_eye2 = find_eyes(img3)

  crop1 = left_eye2[0] - 385 
  crop0 = left_eye2[1] - 490
  return img3[crop0:crop0+1024,crop1:crop1+1024]

# %% [markdown]
# The following will preprocess and crop your images.  If you receive an error indicating multiple faces were found, try to crop your image better or obscure the background.  If the program does not see a face, then attempt to obtain a clearer and more high-resolution image.

# %%
print(SOURCE_NAME, TARGET_NAME)
# Out:
# source.png target.png

# %%
from matplotlib import pyplot as plt
import cv2

image_source = cv2.imread(SOURCE_NAME)
if image_source is None:
    raise ValueError("Source image not found")

image_target = cv2.imread(TARGET_NAME)
if image_target is None:
    raise ValueError("Source image not found")


cropped_source = crop_stylegan(image_source)
#cropped_target = crop_stylegan(image_target)
cropped_target = image_target

img = cv2.cvtColor(cropped_source, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('source')
plt.show()

img = cv2.cvtColor(cropped_target, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('target')
plt.show()

cv2.imwrite("cropped_source.png", cropped_source)
cv2.imwrite("cropped_target.png", cropped_target)

#print(find_eyes(cropped_source))
#print(find_eyes(cropped_target))
# Out:
# True

# %%
# Avoid the aligning from the above face detector.
# We can do manual aligning and center cropping, but I think the cat image is already
# pretty centered, so I simply resized. If you find fault with
# your cat image, add some preprocessing here!

img = Image.open('cropped_target.png')
img = img.resize((1024, 1024))
img.save('cropped_target.png')

# %% [markdown]
# # Convert Source to a GAN
#
# First, we convert the source to a GAN latent vector.  This process will take several minutes.

# %%
cmd = f"python /content/stylegan2-ada-pytorch/projector.py --save-video 0 --num-steps 1000 --outdir=out_source --target=cropped_source.png --network={NETWORK}"
# !{cmd}
# Out:
# Loading networks from "/content/stylegan2ada-weights/network-snapshot-004920.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/1000: dist 0.72 loss 24566.08
# step    2/1000: dist 0.60 loss 27639.31
# step    3/1000: dist 0.73 loss 27166.56
# step    4/1000: dist 0.71 loss 26250.53
# step    5/1000: dist 0.54 loss 24954.47
# step    6/1000: dist 0.62 loss 23352.42
# step    7/1000: dist 0.64 loss 21509.96
# step    8/1000: dist 0.71 loss 19484.48
# step    9/1000: dist 0.54 loss 17337.01
# step   10/1000: dist 0.59 loss 15137.44
# step   11/1000: dist 0.60 loss 12947.19
# step   12/1000: dist 0.56 loss 10817.20
# step   13/1000: dist 0.56 loss 8799.27
# step   14/1000: dist 0.59 loss 6944.96
# step   15/1000: dist 0.63 loss 5313.09
# step   16/1000: dist 0.64 loss 3968.43
# step   17/1000: dist 0.59 loss 2940.08
# step   18/1000: dist 0.54 loss 2212.76
# step   19/1000: dist 0.54 loss 1756.64
# step   20/1000: dist 0.56 loss 1564.54
# step   21/1000: dist 0.54 loss 1599.41
# step   22/1000: dist 0.54 loss 1785.71
# step   23/1000: dist 0.51 loss 2049.99
# step   24/1000: dist 0.54 loss 2324.69
# step   25/1000: dist 0.52 loss 2535.32
# step   26/1000: dist 0.53 loss 2633.74
# step   27/1000: dist 0.57 loss 2599.89
# step   28/1000: dist 0.53 loss 2473.17
# step   29/1000: dist 0.57 loss 2312.33
# step   30/1000: dist 0.55 loss 2116.74
# step   31/1000: dist 0.59 loss 1878.01
# step   32/1000: dist 0.55 loss 1620.40
# step   33/1000: dist 0.53 loss 1381.54
# step   34/1000: dist 0.58 loss 1178.91
# step   35/1000: dist 0.56 loss 1020.07
# step   36/1000: dist 0.53 loss 901.38
# step   37/1000: dist 0.55 loss 822.06
# step   38/1000: dist 0.51 loss 799.19
# step   39/1000: dist 0.52 loss 804.51
# step   40/1000: dist 0.57 loss 823.11
# step   41/1000: dist 0.53 loss 819.75
# step   42/1000: dist 0.51 loss 754.10
# step   43/1000: dist 0.54 loss 643.00
# step   44/1000: dist 0.50 loss 514.35
# step   45/1000: dist 0.50 loss 396.32
# step   46/1000: dist 0.54 loss 310.02
# step   47/1000: dist 0.54 loss 255.37
# step   48/1000: dist 0.55 loss 235.74
# step   49/1000: dist 0.49 loss 246.78
# step   50/1000: dist 0.49 loss 297.30
# step   51/1000: dist 0.52 loss 358.85
# step   52/1000: dist 0.52 loss 385.00
# step   53/1000: dist 0.55 loss 371.41
# step   54/1000: dist 0.52 loss 331.72
# step   55/1000: dist 0.54 loss 265.45
# step   56/1000: dist 0.47 loss 185.48
# step   57/1000: dist 0.49 loss 114.09
# step   58/1000: dist 0.48 loss 66.38
# step   59/1000: dist 0.48 loss 46.65
# step   60/1000: dist 0.52 loss 42.08
# step   61/1000: dist 0.48 loss 53.81
# step   62/1000: dist 0.50 loss 78.79
# step   63/1000: dist 0.52 loss 103.95
# step   64/1000: dist 0.48 loss 120.08
# step   65/1000: dist 0.48 loss 123.69
# step   66/1000: dist 0.46 loss 112.90
# step   67/1000: dist 0.49 loss 94.25
# step   68/1000: dist 0.47 loss 67.70
# step   69/1000: dist 0.49 loss 42.86
# step   70/1000: dist 0.49 loss 25.17
# step   71/1000: dist 0.45 loss 14.87
# step   72/1000: dist 0.47 loss 13.08
# step   73/1000: dist 0.46 loss 18.04
# step   74/1000: dist 0.48 loss 23.67
# step   75/1000: dist 0.45 loss 29.82
# step   76/1000: dist 0.46 loss 33.04
# step   77/1000: dist 0.49 loss 31.82
# step   78/1000: dist 0.48 loss 29.06
# step   79/1000: dist 0.45 loss 27.66
# step   80/1000: dist 0.45 loss 25.83
# step   81/1000: dist 0.50 loss 19.89
# step   82/1000: dist 0.47 loss 11.77
# step   83/1000: dist 0.46 loss 10.13
# step   84/1000: dist 0.44 loss 13.81
# step   85/1000: dist 0.47 loss 13.89
# step   86/1000: dist 0.43 loss 10.43
# step   87/1000: dist 0.44 loss 10.36
# step   88/1000: dist 0.47 loss 10.92
# step   89/1000: dist 0.48 loss 8.42
# step   90/1000: dist 0.51 loss 6.22
# step   91/1000: dist 0.44 loss 5.84
# step   92/1000: dist 0.47 loss 5.60
# step   93/1000: dist 0.44 loss 5.85
# step   94/1000: dist 0.47 loss 8.00
# step   95/1000: dist 0.46 loss 10.15
# step   96/1000: dist 0.44 loss 11.09
# step   97/1000: dist 0.45 loss 10.16
# step   98/1000: dist 0.42 loss 6.71
# step   99/1000: dist 0.44 loss 3.26
# step  100/1000: dist 0.44 loss 2.67
# step  101/1000: dist 0.44 loss 4.07
# step  102/1000: dist 0.44 loss 4.15
# step  103/1000: dist 0.45 loss 2.55
# step  104/1000: dist 0.49 loss 2.05
# step  105/1000: dist 0.47 loss 3.40
# step  106/1000: dist 0.47 loss 4.68
# step  107/1000: dist 0.45 loss 4.93
# step  108/1000: dist 0.48 loss 5.05
# step  109/1000: dist 0.42 loss 4.89
# step  110/1000: dist 0.42 loss 3.76
# step  111/1000: dist 0.42 loss 2.36
# step  112/1000: dist 0.41 loss 2.23
# step  113/1000: dist 0.41 loss 3.00
# step  114/1000: dist 0.43 loss 3.25
# step  115/1000: dist 0.43 loss 2.89
# step  116/1000: dist 0.43 loss 3.10
# step  117/1000: dist 0.42 loss 3.86
# step  118/1000: dist 0.48 loss 4.01
# step  119/1000: dist 0.46 loss 3.07
# step  120/1000: dist 0.45 loss 2.15
# step  121/1000: dist 0.45 loss 1.85
# step  122/1000: dist 0.46 loss 1.61
# step  123/1000: dist 0.46 loss 1.19
# step  124/1000: dist 0.43 loss 1.18
# step  125/1000: dist 0.42 loss 1.83
# step  126/1000: dist 0.44 loss 2.34
# step  127/1000: dist 0.45 loss 1.98
# step  128/1000: dist 0.44 loss 1.15
# step  129/1000: dist 0.41 loss 0.71
# step  130/1000: dist 0.44 loss 0.86
# step  131/1000: dist 0.43 loss 1.06
# step  132/1000: dist 0.42 loss 1.14
# step  133/1000: dist 0.45 loss 1.21
# step  134/1000: dist 0.44 loss 1.29
# step  135/1000: dist 0.42 loss 1.25
# step  136/1000: dist 0.41 loss 1.05
# step  137/1000: dist 0.42 loss 0.83
# step  138/1000: dist 0.43 loss 0.76
# step  139/1000: dist 0.45 loss 0.86
# step  140/1000: dist 0.42 loss 0.98
# step  141/1000: dist 0.42 loss 1.19
# step  142/1000: dist 0.46 loss 1.63
# step  143/1000: dist 0.42 loss 2.40
# step  144/1000: dist 0.49 loss 3.87
# step  145/1000: dist 0.45 loss 5.91
# step  146/1000: dist 0.42 loss 8.19
# step  147/1000: dist 0.43 loss 9.11
# step  148/1000: dist 0.43 loss 6.84
# step  149/1000: dist 0.43 loss 2.86
# step  150/1000: dist 0.43 loss 1.46
# step  151/1000: dist 0.41 loss 3.87
# step  152/1000: dist 0.49 loss 7.03
# step  153/1000: dist 0.45 loss 7.95
# step  154/1000: dist 0.44 loss 8.94
# step  155/1000: dist 0.47 loss 14.18
# step  156/1000: dist 0.44 loss 22.33
# step  157/1000: dist 0.42 loss 24.33
# step  158/1000: dist 0.42 loss 13.49
# step  159/1000: dist 0.41 loss 2.24
# step  160/1000: dist 0.41 loss 6.90
# step  161/1000: dist 0.43 loss 17.13
# step  162/1000: dist 0.42 loss 15.47
# step  163/1000: dist 0.42 loss 10.43
# step  164/1000: dist 0.41 loss 14.84
# step  165/1000: dist 0.42 loss 16.52
# step  166/1000: dist 0.41 loss 8.71
# step  167/1000: dist 0.39 loss 6.11
# step  168/1000: dist 0.44 loss 9.80
# step  169/1000: dist 0.43 loss 8.72
# step  170/1000: dist 0.39 loss 5.54
# step  171/1000: dist 0.40 loss 4.80
# step  172/1000: dist 0.40 loss 3.81
# step  173/1000: dist 0.39 loss 4.29
# step  174/1000: dist 0.42 loss 6.08
# step  175/1000: dist 0.43 loss 4.35
# step  176/1000: dist 0.43 loss 2.59
# step  177/1000: dist 0.41 loss 4.07
# step  178/1000: dist 0.39 loss 3.53
# step  179/1000: dist 0.40 loss 1.23
# step  180/1000: dist 0.40 loss 2.06
# step  181/1000: dist 0.41 loss 3.46
# step  182/1000: dist 0.42 loss 2.56
# step  183/1000: dist 0.40 loss 1.91
# step  184/1000: dist 0.40 loss 2.23
# step  185/1000: dist 0.42 loss 2.39
# step  186/1000: dist 0.44 loss 2.84
# step  187/1000: dist 0.41 loss 3.59
# step  188/1000: dist 0.41 loss 5.21
# step  189/1000: dist 0.41 loss 9.32
# step  190/1000: dist 0.41 loss 15.24
# step  191/1000: dist 0.40 loss 20.73
# step  192/1000: dist 0.44 loss 22.33
# step  193/1000: dist 0.43 loss 15.47
# step  194/1000: dist 0.39 loss 6.08
# step  195/1000: dist 0.41 loss 7.28
# step  196/1000: dist 0.39 loss 12.85
# step  197/1000: dist 0.40 loss 8.84
# step  198/1000: dist 0.40 loss 2.83
# step  199/1000: dist 0.40 loss 6.80
# step  200/1000: dist 0.40 loss 9.77
# step  201/1000: dist 0.39 loss 6.06
# step  202/1000: dist 0.39 loss 8.94
# step  203/1000: dist 0.39 loss 18.22
# step  204/1000: dist 0.41 loss 22.24
# step  205/1000: dist 0.39 loss 19.66
# step  206/1000: dist 0.41 loss 10.74
# step  207/1000: dist 0.41 loss 3.72
# step  208/1000: dist 0.40 loss 8.77
# step  209/1000: dist 0.38 loss 13.73
# step  210/1000: dist 0.39 loss 5.99
# step  211/1000: dist 0.38 loss 2.54
# step  212/1000: dist 0.38 loss 9.15
# step  213/1000: dist 0.39 loss 7.40
# step  214/1000: dist 0.40 loss 2.14
# step  215/1000: dist 0.38 loss 6.19
# step  216/1000: dist 0.42 loss 7.19
# step  217/1000: dist 0.39 loss 2.54
# step  218/1000: dist 0.42 loss 4.79
# step  219/1000: dist 0.41 loss 6.91
# step  220/1000: dist 0.38 loss 2.96
# step  221/1000: dist 0.40 loss 2.93
# step  222/1000: dist 0.38 loss 4.80
# step  223/1000: dist 0.40 loss 2.15
# step  224/1000: dist 0.39 loss 1.23
# step  225/1000: dist 0.38 loss 2.74
# step  226/1000: dist 0.38 loss 1.43
# step  227/1000: dist 0.38 loss 0.89
# step  228/1000: dist 0.38 loss 2.47
# step  229/1000: dist 0.39 loss 1.95
# step  230/1000: dist 0.39 loss 1.24
# step  231/1000: dist 0.39 loss 2.22
# step  232/1000: dist 0.39 loss 1.87
# step  233/1000: dist 0.39 loss 0.96
# step  234/1000: dist 0.40 loss 1.46
# step  235/1000: dist 0.39 loss 1.33
# step  236/1000: dist 0.37 loss 0.50
# step  237/1000: dist 0.37 loss 0.77
# step  238/1000: dist 0.41 loss 1.04
# step  239/1000: dist 0.38 loss 0.57
# step  240/1000: dist 0.39 loss 0.74
# step  241/1000: dist 0.38 loss 1.05
# step  242/1000: dist 0.40 loss 0.78
# step  243/1000: dist 0.42 loss 0.81
# step  244/1000: dist 0.38 loss 1.12
# step  245/1000: dist 0.37 loss 1.01
# step  246/1000: dist 0.37 loss 0.89
# step  247/1000: dist 0.39 loss 1.12
# step  248/1000: dist 0.37 loss 1.11
# step  249/1000: dist 0.38 loss 0.98
# step  250/1000: dist 0.38 loss 1.10
# step  251/1000: dist 0.37 loss 1.19
# step  252/1000: dist 0.38 loss 1.09
# step  253/1000: dist 0.40 loss 1.12
# step  254/1000: dist 0.37 loss 1.20
# step  255/1000: dist 0.38 loss 1.15
# step  256/1000: dist 0.38 loss 1.09
# step  257/1000: dist 0.36 loss 1.11
# step  258/1000: dist 0.38 loss 1.12
# step  259/1000: dist 0.38 loss 1.02
# step  260/1000: dist 0.39 loss 1.00
# step  261/1000: dist 0.40 loss 1.02
# step  262/1000: dist 0.38 loss 0.93
# step  263/1000: dist 0.38 loss 0.87
# step  264/1000: dist 0.38 loss 0.91
# step  265/1000: dist 0.38 loss 0.99
# step  266/1000: dist 0.38 loss 1.20
# step  267/1000: dist 0.40 loss 1.78
# step  268/1000: dist 0.36 loss 2.96
# step  269/1000: dist 0.37 loss 5.39
# step  270/1000: dist 0.38 loss 9.70
# step  271/1000: dist 0.39 loss 15.55
# step  272/1000: dist 0.42 loss 18.67
# step  273/1000: dist 0.39 loss 13.61
# step  274/1000: dist 0.36 loss 4.46
# step  275/1000: dist 0.38 loss 4.07
# step  276/1000: dist 0.39 loss 12.93
# step  277/1000: dist 0.41 loss 19.22
# step  278/1000: dist 0.38 loss 19.08
# step  279/1000: dist 0.37 loss 20.85
# step  280/1000: dist 0.37 loss 23.99
# step  281/1000: dist 0.38 loss 22.08
# step  282/1000: dist 0.37 loss 20.06
# step  283/1000: dist 0.37 loss 22.37
# step  284/1000: dist 0.38 loss 19.77
# step  285/1000: dist 0.37 loss 10.64
# step  286/1000: dist 0.40 loss 9.24
# step  287/1000: dist 0.38 loss 16.22
# step  288/1000: dist 0.37 loss 14.53
# step  289/1000: dist 0.39 loss 5.16
# step  290/1000: dist 0.37 loss 5.31
# step  291/1000: dist 0.40 loss 12.55
# step  292/1000: dist 0.37 loss 12.73
# step  293/1000: dist 0.38 loss 9.92
# step  294/1000: dist 0.38 loss 11.88
# step  295/1000: dist 0.36 loss 11.46
# step  296/1000: dist 0.36 loss 5.08
# step  297/1000: dist 0.36 loss 1.97
# step  298/1000: dist 0.37 loss 4.65
# step  299/1000: dist 0.36 loss 6.47
# step  300/1000: dist 0.37 loss 5.89
# step  301/1000: dist 0.36 loss 5.14
# step  302/1000: dist 0.38 loss 4.35
# step  303/1000: dist 0.37 loss 4.71
# step  304/1000: dist 0.36 loss 8.01
# step  305/1000: dist 0.36 loss 12.36
# step  306/1000: dist 0.36 loss 15.53
# step  307/1000: dist 0.36 loss 16.38
# step  308/1000: dist 0.37 loss 12.34
# step  309/1000: dist 0.36 loss 4.76
# step  310/1000: dist 0.37 loss 2.11
# step  311/1000: dist 0.37 loss 6.21
# step  312/1000: dist 0.37 loss 8.91
# step  313/1000: dist 0.37 loss 5.55
# step  314/1000: dist 0.37 loss 2.23
# step  315/1000: dist 0.36 loss 4.30
# step  316/1000: dist 0.36 loss 7.32
# step  317/1000: dist 0.37 loss 6.76
# step  318/1000: dist 0.37 loss 5.92
# step  319/1000: dist 0.37 loss 8.15
# step  320/1000: dist 0.36 loss 9.40
# step  321/1000: dist 0.37 loss 5.78
# step  322/1000: dist 0.36 loss 1.51
# step  323/1000: dist 0.38 loss 2.02
# step  324/1000: dist 0.36 loss 5.08
# step  325/1000: dist 0.37 loss 6.02
# step  326/1000: dist 0.36 loss 5.36
# step  327/1000: dist 0.36 loss 6.89
# step  328/1000: dist 0.35 loss 10.81
# step  329/1000: dist 0.36 loss 12.00
# step  330/1000: dist 0.35 loss 7.17
# step  331/1000: dist 0.36 loss 2.39
# step  332/1000: dist 0.35 loss 3.67
# step  333/1000: dist 0.36 loss 7.01
# step  334/1000: dist 0.40 loss 6.22
# step  335/1000: dist 0.36 loss 3.69
# step  336/1000: dist 0.35 loss 4.98
# step  337/1000: dist 0.37 loss 7.71
# step  338/1000: dist 0.37 loss 7.95
# step  339/1000: dist 0.35 loss 8.33
# step  340/1000: dist 0.36 loss 10.26
# step  341/1000: dist 0.36 loss 9.52
# step  342/1000: dist 0.36 loss 5.29
# step  343/1000: dist 0.35 loss 2.59
# step  344/1000: dist 0.35 loss 2.70
# step  345/1000: dist 0.36 loss 2.94
# step  346/1000: dist 0.36 loss 3.46
# step  347/1000: dist 0.36 loss 4.91
# step  348/1000: dist 0.36 loss 4.73
# step  349/1000: dist 0.35 loss 2.65
# step  350/1000: dist 0.39 loss 2.55
# step  351/1000: dist 0.36 loss 5.56
# step  352/1000: dist 0.34 loss 9.19
# step  353/1000: dist 0.35 loss 12.26
# step  354/1000: dist 0.34 loss 14.51
# step  355/1000: dist 0.35 loss 13.31
# step  356/1000: dist 0.35 loss 7.41
# step  357/1000: dist 0.36 loss 2.13
# step  358/1000: dist 0.38 loss 2.72
# step  359/1000: dist 0.37 loss 6.32
# step  360/1000: dist 0.35 loss 6.84
# step  361/1000: dist 0.37 loss 3.42
# step  362/1000: dist 0.35 loss 1.15
# step  363/1000: dist 0.36 loss 2.89
# step  364/1000: dist 0.35 loss 4.74
# step  365/1000: dist 0.35 loss 3.16
# step  366/1000: dist 0.35 loss 0.85
# step  367/1000: dist 0.35 loss 1.55
# step  368/1000: dist 0.35 loss 3.32
# step  369/1000: dist 0.35 loss 2.72
# step  370/1000: dist 0.34 loss 1.14
# step  371/1000: dist 0.34 loss 1.55
# step  372/1000: dist 0.35 loss 2.81
# step  373/1000: dist 0.34 loss 2.68
# step  374/1000: dist 0.35 loss 2.31
# step  375/1000: dist 0.35 loss 3.28
# step  376/1000: dist 0.34 loss 4.44
# step  377/1000: dist 0.35 loss 4.58
# step  378/1000: dist 0.34 loss 4.64
# step  379/1000: dist 0.34 loss 5.11
# step  380/1000: dist 0.34 loss 4.65
# step  381/1000: dist 0.34 loss 2.97
# step  382/1000: dist 0.34 loss 1.82
# step  383/1000: dist 0.36 loss 2.44
# step  384/1000: dist 0.35 loss 4.65
# step  385/1000: dist 0.34 loss 8.88
# step  386/1000: dist 0.35 loss 16.12
# step  387/1000: dist 0.34 loss 24.33
# step  388/1000: dist 0.33 loss 25.66
# step  389/1000: dist 0.34 loss 13.90
# step  390/1000: dist 0.34 loss 1.50
# step  391/1000: dist 0.34 loss 3.91
# step  392/1000: dist 0.34 loss 12.89
# step  393/1000: dist 0.34 loss 11.03
# step  394/1000: dist 0.35 loss 2.30
# step  395/1000: dist 0.35 loss 3.19
# step  396/1000: dist 0.35 loss 8.70
# step  397/1000: dist 0.33 loss 5.30
# step  398/1000: dist 0.34 loss 0.48
# step  399/1000: dist 0.34 loss 3.88
# step  400/1000: dist 0.35 loss 6.01
# step  401/1000: dist 0.33 loss 1.92
# step  402/1000: dist 0.34 loss 1.31
# step  403/1000: dist 0.34 loss 4.15
# step  404/1000: dist 0.34 loss 2.56
# step  405/1000: dist 0.34 loss 0.46
# step  406/1000: dist 0.33 loss 2.49
# step  407/1000: dist 0.34 loss 3.01
# step  408/1000: dist 0.33 loss 1.10
# step  409/1000: dist 0.33 loss 1.85
# step  410/1000: dist 0.34 loss 3.28
# step  411/1000: dist 0.33 loss 2.62
# step  412/1000: dist 0.33 loss 3.48
# step  413/1000: dist 0.34 loss 6.40
# step  414/1000: dist 0.33 loss 8.30
# step  415/1000: dist 0.33 loss 9.91
# step  416/1000: dist 0.33 loss 11.41
# step  417/1000: dist 0.33 loss 9.83
# step  418/1000: dist 0.35 loss 7.32
# step  419/1000: dist 0.33 loss 9.55
# step  420/1000: dist 0.33 loss 16.75
# step  421/1000: dist 0.33 loss 23.23
# step  422/1000: dist 0.34 loss 20.98
# step  423/1000: dist 0.33 loss 9.42
# step  424/1000: dist 0.35 loss 0.83
# step  425/1000: dist 0.32 loss 4.76
# step  426/1000: dist 0.33 loss 11.99
# step  427/1000: dist 0.33 loss 9.20
# step  428/1000: dist 0.34 loss 1.79
# step  429/1000: dist 0.33 loss 2.36
# step  430/1000: dist 0.34 loss 6.83
# step  431/1000: dist 0.32 loss 5.14
# step  432/1000: dist 0.32 loss 1.54
# step  433/1000: dist 0.32 loss 2.92
# step  434/1000: dist 0.34 loss 4.23
# step  435/1000: dist 0.33 loss 1.95
# step  436/1000: dist 0.33 loss 1.60
# step  437/1000: dist 0.32 loss 3.28
# step  438/1000: dist 0.32 loss 2.08
# step  439/1000: dist 0.35 loss 0.57
# step  440/1000: dist 0.35 loss 2.01
# step  441/1000: dist 0.33 loss 2.49
# step  442/1000: dist 0.33 loss 0.75
# step  443/1000: dist 0.33 loss 0.72
# step  444/1000: dist 0.34 loss 1.85
# step  445/1000: dist 0.33 loss 1.26
# step  446/1000: dist 0.32 loss 0.63
# step  447/1000: dist 0.33 loss 1.23
# step  448/1000: dist 0.34 loss 1.26
# step  449/1000: dist 0.34 loss 0.97
# step  450/1000: dist 0.32 loss 1.72
# step  451/1000: dist 0.33 loss 2.64
# step  452/1000: dist 0.32 loss 3.69
# step  453/1000: dist 0.33 loss 6.86
# step  454/1000: dist 0.33 loss 12.37
# step  455/1000: dist 0.33 loss 18.47
# step  456/1000: dist 0.33 loss 21.72
# step  457/1000: dist 0.33 loss 16.63
# step  458/1000: dist 0.33 loss 6.32
# step  459/1000: dist 0.33 loss 3.80
# step  460/1000: dist 0.33 loss 12.31
# step  461/1000: dist 0.33 loss 20.01
# step  462/1000: dist 0.33 loss 20.27
# step  463/1000: dist 0.33 loss 22.35
# step  464/1000: dist 0.32 loss 29.11
# step  465/1000: dist 0.32 loss 26.22
# step  466/1000: dist 0.32 loss 10.41
# step  467/1000: dist 0.32 loss 1.30
# step  468/1000: dist 0.32 loss 7.49
# step  469/1000: dist 0.32 loss 13.77
# step  470/1000: dist 0.33 loss 10.42
# step  471/1000: dist 0.32 loss 5.72
# step  472/1000: dist 0.32 loss 5.56
# step  473/1000: dist 0.32 loss 5.94
# step  474/1000: dist 0.32 loss 5.32
# step  475/1000: dist 0.32 loss 5.26
# step  476/1000: dist 0.32 loss 5.20
# step  477/1000: dist 0.32 loss 4.83
# step  478/1000: dist 0.32 loss 4.79
# step  479/1000: dist 0.32 loss 4.82
# step  480/1000: dist 0.32 loss 5.69
# step  481/1000: dist 0.32 loss 7.73
# step  482/1000: dist 0.32 loss 8.36
# step  483/1000: dist 0.31 loss 7.30
# step  484/1000: dist 0.32 loss 7.55
# step  485/1000: dist 0.32 loss 7.72
# step  486/1000: dist 0.31 loss 4.43
# step  487/1000: dist 0.32 loss 0.84
# step  488/1000: dist 0.31 loss 1.31
# step  489/1000: dist 0.31 loss 3.37
# step  490/1000: dist 0.31 loss 3.45
# step  491/1000: dist 0.32 loss 2.77
# step  492/1000: dist 0.31 loss 2.72
# step  493/1000: dist 0.32 loss 2.21
# step  494/1000: dist 0.32 loss 1.20
# step  495/1000: dist 0.32 loss 1.11
# step  496/1000: dist 0.31 loss 1.92
# step  497/1000: dist 0.31 loss 2.52
# step  498/1000: dist 0.33 loss 2.63
# step  499/1000: dist 0.31 loss 2.74
# step  500/1000: dist 0.31 loss 3.82
# step  501/1000: dist 0.31 loss 6.83
# step  502/1000: dist 0.32 loss 12.34
# step  503/1000: dist 0.32 loss 20.17
# step  504/1000: dist 0.32 loss 28.34
# step  505/1000: dist 0.31 loss 32.11
# step  506/1000: dist 0.31 loss 29.89
# step  507/1000: dist 0.31 loss 30.20
# step  508/1000: dist 0.31 loss 35.41
# step  509/1000: dist 0.32 loss 32.39
# step  510/1000: dist 0.32 loss 15.90
# step  511/1000: dist 0.31 loss 5.19
# step  512/1000: dist 0.31 loss 11.56
# step  513/1000: dist 0.31 loss 17.58
# step  514/1000: dist 0.31 loss 10.00
# step  515/1000: dist 0.31 loss 4.83
# step  516/1000: dist 0.31 loss 11.11
# step  517/1000: dist 0.31 loss 11.46
# step  518/1000: dist 0.32 loss 2.77
# step  519/1000: dist 0.32 loss 2.99
# step  520/1000: dist 0.31 loss 9.43
# step  521/1000: dist 0.31 loss 7.19
# step  522/1000: dist 0.31 loss 3.74
# step  523/1000: dist 0.32 loss 8.06
# step  524/1000: dist 0.32 loss 11.48
# step  525/1000: dist 0.31 loss 13.35
# step  526/1000: dist 0.31 loss 20.39
# step  527/1000: dist 0.31 loss 23.72
# step  528/1000: dist 0.32 loss 14.77
# step  529/1000: dist 0.31 loss 4.47
# step  530/1000: dist 0.31 loss 3.08
# step  531/1000: dist 0.31 loss 7.34
# step  532/1000: dist 0.31 loss 10.66
# step  533/1000: dist 0.30 loss 7.89
# step  534/1000: dist 0.30 loss 2.01
# step  535/1000: dist 0.31 loss 2.48
# step  536/1000: dist 0.31 loss 7.35
# step  537/1000: dist 0.31 loss 6.74
# step  538/1000: dist 0.31 loss 3.26
# step  539/1000: dist 0.30 loss 5.67
# step  540/1000: dist 0.31 loss 11.37
# step  541/1000: dist 0.31 loss 14.46
# step  542/1000: dist 0.30 loss 15.73
# step  543/1000: dist 0.31 loss 14.53
# step  544/1000: dist 0.30 loss 8.19
# step  545/1000: dist 0.30 loss 1.92
# step  546/1000: dist 0.30 loss 3.02
# step  547/1000: dist 0.31 loss 8.29
# step  548/1000: dist 0.31 loss 8.43
# step  549/1000: dist 0.30 loss 2.99
# step  550/1000: dist 0.30 loss 0.94
# step  551/1000: dist 0.30 loss 4.44
# step  552/1000: dist 0.30 loss 5.96
# step  553/1000: dist 0.30 loss 3.00
# step  554/1000: dist 0.30 loss 1.69
# step  555/1000: dist 0.30 loss 4.33
# step  556/1000: dist 0.30 loss 6.46
# step  557/1000: dist 0.30 loss 6.74
# step  558/1000: dist 0.30 loss 8.91
# step  559/1000: dist 0.30 loss 13.82
# step  560/1000: dist 0.30 loss 16.95
# step  561/1000: dist 0.30 loss 14.36
# step  562/1000: dist 0.30 loss 7.52
# step  563/1000: dist 0.30 loss 2.25
# step  564/1000: dist 0.30 loss 2.29
# step  565/1000: dist 0.30 loss 5.52
# step  566/1000: dist 0.30 loss 7.09
# step  567/1000: dist 0.30 loss 4.70
# step  568/1000: dist 0.30 loss 1.45
# step  569/1000: dist 0.30 loss 1.61
# step  570/1000: dist 0.30 loss 3.93
# step  571/1000: dist 0.30 loss 3.93
# step  572/1000: dist 0.30 loss 1.52
# step  573/1000: dist 0.30 loss 0.78
# step  574/1000: dist 0.30 loss 2.33
# step  575/1000: dist 0.30 loss 2.75
# step  576/1000: dist 0.29 loss 1.25
# step  577/1000: dist 0.30 loss 0.66
# step  578/1000: dist 0.30 loss 1.72
# step  579/1000: dist 0.30 loss 2.16
# step  580/1000: dist 0.30 loss 1.45
# step  581/1000: dist 0.29 loss 1.59
# step  582/1000: dist 0.29 loss 3.24
# step  583/1000: dist 0.30 loss 5.25
# step  584/1000: dist 0.29 loss 7.84
# step  585/1000: dist 0.30 loss 12.56
# step  586/1000: dist 0.29 loss 17.99
# step  587/1000: dist 0.30 loss 19.16
# step  588/1000: dist 0.29 loss 12.32
# step  589/1000: dist 0.30 loss 3.31
# step  590/1000: dist 0.29 loss 1.45
# step  591/1000: dist 0.29 loss 6.54
# step  592/1000: dist 0.30 loss 9.37
# step  593/1000: dist 0.29 loss 5.11
# step  594/1000: dist 0.29 loss 0.78
# step  595/1000: dist 0.29 loss 2.72
# step  596/1000: dist 0.29 loss 5.70
# step  597/1000: dist 0.29 loss 3.65
# step  598/1000: dist 0.29 loss 0.82
# step  599/1000: dist 0.29 loss 2.44
# step  600/1000: dist 0.29 loss 4.44
# step  601/1000: dist 0.29 loss 3.02
# step  602/1000: dist 0.29 loss 2.41
# step  603/1000: dist 0.29 loss 5.09
# step  604/1000: dist 0.29 loss 7.25
# step  605/1000: dist 0.30 loss 7.98
# step  606/1000: dist 0.29 loss 10.34
# step  607/1000: dist 0.29 loss 12.72
# step  608/1000: dist 0.30 loss 10.86
# step  609/1000: dist 0.30 loss 6.09
# step  610/1000: dist 0.29 loss 2.94
# step  611/1000: dist 0.29 loss 2.64
# step  612/1000: dist 0.30 loss 4.36
# step  613/1000: dist 0.29 loss 7.12
# step  614/1000: dist 0.29 loss 8.35
# step  615/1000: dist 0.29 loss 7.02
# step  616/1000: dist 0.29 loss 6.55
# step  617/1000: dist 0.29 loss 9.00
# step  618/1000: dist 0.29 loss 10.96
# step  619/1000: dist 0.29 loss 9.32
# step  620/1000: dist 0.29 loss 5.55
# step  621/1000: dist 0.29 loss 2.52
# step  622/1000: dist 0.30 loss 1.42
# step  623/1000: dist 0.29 loss 2.04
# step  624/1000: dist 0.29 loss 3.09
# step  625/1000: dist 0.29 loss 3.42
# step  626/1000: dist 0.29 loss 3.27
# step  627/1000: dist 0.29 loss 2.88
# step  628/1000: dist 0.29 loss 1.83
# step  629/1000: dist 0.29 loss 0.71
# step  630/1000: dist 0.29 loss 0.90
# step  631/1000: dist 0.29 loss 2.08
# step  632/1000: dist 0.29 loss 2.54
# step  633/1000: dist 0.29 loss 1.78
# step  634/1000: dist 0.29 loss 0.98
# step  635/1000: dist 0.28 loss 1.02
# step  636/1000: dist 0.29 loss 1.73
# step  637/1000: dist 0.28 loss 2.51
# step  638/1000: dist 0.29 loss 3.05
# step  639/1000: dist 0.28 loss 3.64
# step  640/1000: dist 0.28 loss 4.77
# step  641/1000: dist 0.28 loss 6.60
# step  642/1000: dist 0.28 loss 8.56
# step  643/1000: dist 0.28 loss 9.93
# step  644/1000: dist 0.29 loss 9.61
# step  645/1000: dist 0.29 loss 7.14
# step  646/1000: dist 0.29 loss 3.36
# step  647/1000: dist 0.28 loss 0.77
# step  648/1000: dist 0.29 loss 0.92
# step  649/1000: dist 0.28 loss 2.93
# step  650/1000: dist 0.28 loss 4.62
# step  651/1000: dist 0.29 loss 4.60
# step  652/1000: dist 0.29 loss 3.51
# step  653/1000: dist 0.28 loss 3.27
# step  654/1000: dist 0.29 loss 5.23
# step  655/1000: dist 0.29 loss 9.12
# step  656/1000: dist 0.28 loss 13.31
# step  657/1000: dist 0.29 loss 15.95
# step  658/1000: dist 0.28 loss 14.93
# step  659/1000: dist 0.28 loss 10.13
# step  660/1000: dist 0.28 loss 4.60
# step  661/1000: dist 0.28 loss 3.45
# step  662/1000: dist 0.28 loss 7.89
# step  663/1000: dist 0.28 loss 13.97
# step  664/1000: dist 0.28 loss 16.57
# step  665/1000: dist 0.28 loss 13.16
# step  666/1000: dist 0.28 loss 6.70
# step  667/1000: dist 0.28 loss 3.26
# step  668/1000: dist 0.28 loss 5.02
# step  669/1000: dist 0.28 loss 7.42
# step  670/1000: dist 0.28 loss 6.21
# step  671/1000: dist 0.28 loss 3.17
# step  672/1000: dist 0.28 loss 2.62
# step  673/1000: dist 0.28 loss 4.26
# step  674/1000: dist 0.28 loss 4.26
# step  675/1000: dist 0.28 loss 2.24
# step  676/1000: dist 0.28 loss 1.60
# step  677/1000: dist 0.28 loss 2.92
# step  678/1000: dist 0.28 loss 3.10
# step  679/1000: dist 0.28 loss 1.52
# step  680/1000: dist 0.28 loss 0.92
# step  681/1000: dist 0.28 loss 1.96
# step  682/1000: dist 0.28 loss 2.22
# step  683/1000: dist 0.28 loss 1.12
# step  684/1000: dist 0.28 loss 0.73
# step  685/1000: dist 0.28 loss 1.47
# step  686/1000: dist 0.28 loss 1.57
# step  687/1000: dist 0.28 loss 0.84
# step  688/1000: dist 0.28 loss 0.80
# step  689/1000: dist 0.28 loss 1.53
# step  690/1000: dist 0.28 loss 1.85
# step  691/1000: dist 0.28 loss 2.02
# step  692/1000: dist 0.28 loss 3.43
# step  693/1000: dist 0.28 loss 6.42
# step  694/1000: dist 0.28 loss 10.54
# step  695/1000: dist 0.28 loss 15.77
# step  696/1000: dist 0.28 loss 20.03
# step  697/1000: dist 0.28 loss 18.40
# step  698/1000: dist 0.28 loss 9.11
# step  699/1000: dist 0.28 loss 1.07
# step  700/1000: dist 0.28 loss 2.45
# step  701/1000: dist 0.27 loss 8.87
# step  702/1000: dist 0.27 loss 10.10
# step  703/1000: dist 0.27 loss 4.78
# step  704/1000: dist 0.27 loss 2.40
# step  705/1000: dist 0.27 loss 7.38
# step  706/1000: dist 0.27 loss 13.17
# step  707/1000: dist 0.27 loss 15.38
# step  708/1000: dist 0.27 loss 18.44
# step  709/1000: dist 0.27 loss 23.86
# step  710/1000: dist 0.28 loss 21.89
# step  711/1000: dist 0.27 loss 9.85
# step  712/1000: dist 0.27 loss 1.53
# step  713/1000: dist 0.27 loss 7.06
# step  714/1000: dist 0.27 loss 16.96
# step  715/1000: dist 0.27 loss 19.39
# step  716/1000: dist 0.28 loss 20.42
# step  717/1000: dist 0.27 loss 30.03
# step  718/1000: dist 0.27 loss 37.44
# step  719/1000: dist 0.27 loss 23.18
# step  720/1000: dist 0.27 loss 2.97
# step  721/1000: dist 0.27 loss 5.50
# step  722/1000: dist 0.27 loss 19.25
# step  723/1000: dist 0.27 loss 14.61
# step  724/1000: dist 0.27 loss 1.31
# step  725/1000: dist 0.27 loss 5.79
# step  726/1000: dist 0.27 loss 13.09
# step  727/1000: dist 0.27 loss 4.87
# step  728/1000: dist 0.27 loss 1.08
# step  729/1000: dist 0.27 loss 7.97
# step  730/1000: dist 0.27 loss 5.90
# step  731/1000: dist 0.27 loss 0.69
# step  732/1000: dist 0.27 loss 4.36
# step  733/1000: dist 0.27 loss 4.75
# step  734/1000: dist 0.27 loss 1.14
# step  735/1000: dist 0.27 loss 2.77
# step  736/1000: dist 0.27 loss 3.16
# step  737/1000: dist 0.27 loss 1.26
# step  738/1000: dist 0.27 loss 2.33
# step  739/1000: dist 0.27 loss 1.97
# step  740/1000: dist 0.27 loss 0.95
# step  741/1000: dist 0.27 loss 2.13
# step  742/1000: dist 0.27 loss 1.35
# step  743/1000: dist 0.27 loss 0.64
# step  744/1000: dist 0.27 loss 1.86
# step  745/1000: dist 0.27 loss 1.12
# step  746/1000: dist 0.27 loss 0.64
# step  747/1000: dist 0.27 loss 1.71
# step  748/1000: dist 0.27 loss 1.28
# step  749/1000: dist 0.27 loss 1.30
# step  750/1000: dist 0.27 loss 2.48
# step  751/1000: dist 0.27 loss 2.90
# step  752/1000: dist 0.27 loss 4.21
# step  753/1000: dist 0.27 loss 6.70
# step  754/1000: dist 0.27 loss 9.16
# step  755/1000: dist 0.27 loss 12.15
# step  756/1000: dist 0.27 loss 14.05
# step  757/1000: dist 0.27 loss 13.09
# step  758/1000: dist 0.27 loss 10.63
# step  759/1000: dist 0.27 loss 9.41
# step  760/1000: dist 0.27 loss 11.95
# step  761/1000: dist 0.27 loss 16.81
# step  762/1000: dist 0.27 loss 17.86
# step  763/1000: dist 0.27 loss 12.15
# step  764/1000: dist 0.27 loss 4.05
# step  765/1000: dist 0.27 loss 0.49
# step  766/1000: dist 0.27 loss 3.49
# step  767/1000: dist 0.27 loss 7.66
# step  768/1000: dist 0.27 loss 7.03
# step  769/1000: dist 0.27 loss 2.95
# step  770/1000: dist 0.27 loss 0.89
# step  771/1000: dist 0.28 loss 2.43
# step  772/1000: dist 0.27 loss 4.15
# step  773/1000: dist 0.27 loss 3.20
# step  774/1000: dist 0.27 loss 1.23
# step  775/1000: dist 0.27 loss 1.11
# step  776/1000: dist 0.27 loss 2.17
# step  777/1000: dist 0.27 loss 2.20
# step  778/1000: dist 0.27 loss 1.24
# step  779/1000: dist 0.27 loss 0.81
# step  780/1000: dist 0.27 loss 1.26
# step  781/1000: dist 0.27 loss 1.47
# step  782/1000: dist 0.27 loss 0.95
# step  783/1000: dist 0.27 loss 0.64
# step  784/1000: dist 0.27 loss 0.89
# step  785/1000: dist 0.27 loss 0.99
# step  786/1000: dist 0.27 loss 0.71
# step  787/1000: dist 0.27 loss 0.53
# step  788/1000: dist 0.27 loss 0.67
# step  789/1000: dist 0.27 loss 0.72
# step  790/1000: dist 0.27 loss 0.52
# step  791/1000: dist 0.27 loss 0.44
# step  792/1000: dist 0.27 loss 0.55
# step  793/1000: dist 0.27 loss 0.53
# step  794/1000: dist 0.27 loss 0.40
# step  795/1000: dist 0.26 loss 0.40
# step  796/1000: dist 0.27 loss 0.46
# step  797/1000: dist 0.27 loss 0.41
# step  798/1000: dist 0.27 loss 0.34
# step  799/1000: dist 0.27 loss 0.37
# step  800/1000: dist 0.26 loss 0.39
# step  801/1000: dist 0.27 loss 0.33
# step  802/1000: dist 0.27 loss 0.32
# step  803/1000: dist 0.27 loss 0.36
# step  804/1000: dist 0.26 loss 0.33
# step  805/1000: dist 0.27 loss 0.30
# step  806/1000: dist 0.26 loss 0.32
# step  807/1000: dist 0.26 loss 0.32
# step  808/1000: dist 0.26 loss 0.29
# step  809/1000: dist 0.26 loss 0.29
# step  810/1000: dist 0.26 loss 0.31
# step  811/1000: dist 0.26 loss 0.28
# step  812/1000: dist 0.26 loss 0.28
# step  813/1000: dist 0.26 loss 0.29
# step  814/1000: dist 0.26 loss 0.28
# step  815/1000: dist 0.26 loss 0.27
# step  816/1000: dist 0.26 loss 0.28
# step  817/1000: dist 0.26 loss 0.27
# step  818/1000: dist 0.26 loss 0.27
# step  819/1000: dist 0.26 loss 0.28
# step  820/1000: dist 0.26 loss 0.27
# step  821/1000: dist 0.26 loss 0.27
# step  822/1000: dist 0.26 loss 0.27
# step  823/1000: dist 0.26 loss 0.27
# step  824/1000: dist 0.26 loss 0.27
# step  825/1000: dist 0.26 loss 0.27
# step  826/1000: dist 0.26 loss 0.26
# step  827/1000: dist 0.26 loss 0.26
# step  828/1000: dist 0.26 loss 0.27
# step  829/1000: dist 0.26 loss 0.26
# step  830/1000: dist 0.26 loss 0.26
# step  831/1000: dist 0.26 loss 0.26
# step  832/1000: dist 0.26 loss 0.26
# step  833/1000: dist 0.26 loss 0.26
# step  834/1000: dist 0.26 loss 0.26
# step  835/1000: dist 0.26 loss 0.26
# step  836/1000: dist 0.26 loss 0.26
# step  837/1000: dist 0.26 loss 0.26
# step  838/1000: dist 0.26 loss 0.26
# step  839/1000: dist 0.26 loss 0.26
# step  840/1000: dist 0.26 loss 0.26
# step  841/1000: dist 0.26 loss 0.26
# step  842/1000: dist 0.26 loss 0.26
# step  843/1000: dist 0.26 loss 0.26
# step  844/1000: dist 0.26 loss 0.26
# step  845/1000: dist 0.26 loss 0.26
# step  846/1000: dist 0.26 loss 0.26
# step  847/1000: dist 0.26 loss 0.26
# step  848/1000: dist 0.26 loss 0.26
# step  849/1000: dist 0.26 loss 0.26
# step  850/1000: dist 0.26 loss 0.26
# step  851/1000: dist 0.26 loss 0.26
# step  852/1000: dist 0.26 loss 0.26
# step  853/1000: dist 0.26 loss 0.26
# step  854/1000: dist 0.26 loss 0.26
# step  855/1000: dist 0.26 loss 0.26
# step  856/1000: dist 0.26 loss 0.26
# step  857/1000: dist 0.26 loss 0.26
# step  858/1000: dist 0.26 loss 0.26
# step  859/1000: dist 0.26 loss 0.26
# step  860/1000: dist 0.26 loss 0.26
# step  861/1000: dist 0.26 loss 0.26
# step  862/1000: dist 0.26 loss 0.26
# step  863/1000: dist 0.26 loss 0.26
# step  864/1000: dist 0.26 loss 0.26
# step  865/1000: dist 0.26 loss 0.26
# step  866/1000: dist 0.26 loss 0.26
# step  867/1000: dist 0.26 loss 0.26
# step  868/1000: dist 0.26 loss 0.26
# step  869/1000: dist 0.26 loss 0.26
# step  870/1000: dist 0.26 loss 0.26
# step  871/1000: dist 0.26 loss 0.26
# step  872/1000: dist 0.26 loss 0.26
# step  873/1000: dist 0.26 loss 0.26
# step  874/1000: dist 0.26 loss 0.26
# step  875/1000: dist 0.26 loss 0.26
# step  876/1000: dist 0.26 loss 0.26
# step  877/1000: dist 0.26 loss 0.26
# step  878/1000: dist 0.26 loss 0.26
# step  879/1000: dist 0.26 loss 0.26
# step  880/1000: dist 0.26 loss 0.26
# step  881/1000: dist 0.26 loss 0.26
# step  882/1000: dist 0.26 loss 0.26
# step  883/1000: dist 0.26 loss 0.26
# step  884/1000: dist 0.26 loss 0.26
# step  885/1000: dist 0.26 loss 0.26
# step  886/1000: dist 0.26 loss 0.26
# step  887/1000: dist 0.26 loss 0.26
# step  888/1000: dist 0.26 loss 0.26
# step  889/1000: dist 0.26 loss 0.26
# step  890/1000: dist 0.26 loss 0.26
# step  891/1000: dist 0.26 loss 0.26
# step  892/1000: dist 0.26 loss 0.26
# step  893/1000: dist 0.26 loss 0.26
# step  894/1000: dist 0.26 loss 0.26
# step  895/1000: dist 0.26 loss 0.26
# step  896/1000: dist 0.26 loss 0.26
# step  897/1000: dist 0.26 loss 0.26
# step  898/1000: dist 0.26 loss 0.26
# step  899/1000: dist 0.26 loss 0.26
# step  900/1000: dist 0.26 loss 0.26
# step  901/1000: dist 0.26 loss 0.26
# step  902/1000: dist 0.26 loss 0.26
# step  903/1000: dist 0.26 loss 0.26
# step  904/1000: dist 0.26 loss 0.26
# step  905/1000: dist 0.26 loss 0.26
# step  906/1000: dist 0.26 loss 0.26
# step  907/1000: dist 0.26 loss 0.26
# step  908/1000: dist 0.26 loss 0.26
# step  909/1000: dist 0.26 loss 0.26
# step  910/1000: dist 0.26 loss 0.26
# step  911/1000: dist 0.26 loss 0.26
# step  912/1000: dist 0.26 loss 0.26
# step  913/1000: dist 0.26 loss 0.26
# step  914/1000: dist 0.26 loss 0.26
# step  915/1000: dist 0.26 loss 0.26
# step  916/1000: dist 0.26 loss 0.26
# step  917/1000: dist 0.26 loss 0.26
# step  918/1000: dist 0.26 loss 0.26
# step  919/1000: dist 0.26 loss 0.26
# step  920/1000: dist 0.26 loss 0.26
# step  921/1000: dist 0.26 loss 0.26
# step  922/1000: dist 0.26 loss 0.26
# step  923/1000: dist 0.26 loss 0.26
# step  924/1000: dist 0.26 loss 0.26
# step  925/1000: dist 0.26 loss 0.26
# step  926/1000: dist 0.26 loss 0.26
# step  927/1000: dist 0.26 loss 0.26
# step  928/1000: dist 0.26 loss 0.26
# step  929/1000: dist 0.26 loss 0.26
# step  930/1000: dist 0.26 loss 0.26
# step  931/1000: dist 0.26 loss 0.26
# step  932/1000: dist 0.26 loss 0.26
# step  933/1000: dist 0.26 loss 0.26
# step  934/1000: dist 0.26 loss 0.26
# step  935/1000: dist 0.26 loss 0.26
# step  936/1000: dist 0.26 loss 0.26
# step  937/1000: dist 0.26 loss 0.26
# step  938/1000: dist 0.26 loss 0.26
# step  939/1000: dist 0.26 loss 0.26
# step  940/1000: dist 0.26 loss 0.26
# step  941/1000: dist 0.26 loss 0.26
# step  942/1000: dist 0.26 loss 0.26
# step  943/1000: dist 0.26 loss 0.26
# step  944/1000: dist 0.26 loss 0.26
# step  945/1000: dist 0.26 loss 0.26
# step  946/1000: dist 0.26 loss 0.26
# step  947/1000: dist 0.26 loss 0.26
# step  948/1000: dist 0.26 loss 0.26
# step  949/1000: dist 0.26 loss 0.26
# step  950/1000: dist 0.26 loss 0.26
# step  951/1000: dist 0.26 loss 0.26
# step  952/1000: dist 0.26 loss 0.26
# step  953/1000: dist 0.26 loss 0.26
# step  954/1000: dist 0.26 loss 0.26
# step  955/1000: dist 0.26 loss 0.26
# step  956/1000: dist 0.26 loss 0.26
# step  957/1000: dist 0.26 loss 0.26
# step  958/1000: dist 0.26 loss 0.26
# step  959/1000: dist 0.26 loss 0.26
# step  960/1000: dist 0.26 loss 0.26
# step  961/1000: dist 0.26 loss 0.26
# step  962/1000: dist 0.26 loss 0.26
# step  963/1000: dist 0.26 loss 0.26
# step  964/1000: dist 0.26 loss 0.26
# step  965/1000: dist 0.26 loss 0.26
# step  966/1000: dist 0.26 loss 0.26
# step  967/1000: dist 0.26 loss 0.26
# step  968/1000: dist 0.26 loss 0.26
# step  969/1000: dist 0.26 loss 0.26
# step  970/1000: dist 0.26 loss 0.26
# step  971/1000: dist 0.26 loss 0.26
# step  972/1000: dist 0.26 loss 0.26
# step  973/1000: dist 0.26 loss 0.26
# step  974/1000: dist 0.26 loss 0.26
# step  975/1000: dist 0.26 loss 0.26
# step  976/1000: dist 0.26 loss 0.26
# step  977/1000: dist 0.26 loss 0.26
# step  978/1000: dist 0.26 loss 0.26
# step  979/1000: dist 0.26 loss 0.26
# step  980/1000: dist 0.26 loss 0.26
# step  981/1000: dist 0.26 loss 0.26
# step  982/1000: dist 0.26 loss 0.26
# step  983/1000: dist 0.26 loss 0.26
# step  984/1000: dist 0.26 loss 0.26
# step  985/1000: dist 0.26 loss 0.26
# step  986/1000: dist 0.26 loss 0.26
# step  987/1000: dist 0.26 loss 0.26
# step  988/1000: dist 0.26 loss 0.26
# step  989/1000: dist 0.26 loss 0.26
# step  990/1000: dist 0.26 loss 0.26
# step  991/1000: dist 0.26 loss 0.26
# step  992/1000: dist 0.26 loss 0.26
# step  993/1000: dist 0.26 loss 0.26
# step  994/1000: dist 0.26 loss 0.26
# step  995/1000: dist 0.26 loss 0.26
# step  996/1000: dist 0.26 loss 0.26
# step  997/1000: dist 0.26 loss 0.26
# step  998/1000: dist 0.26 loss 0.26
# step  999/1000: dist 0.26 loss 0.26
# step 1000/1000: dist 0.26 loss 0.26
# Elapsed: 78.7 s

# %% [markdown]
# # Convert Target to a GAN
#
# Next, we convert the target to a GAN latent vector.  This process will also take several minutes.

# %%
cmd = f"python /content/stylegan2-ada-pytorch/projector.py --save-video 0 --num-steps 1000 --outdir=out_target --target=cropped_target.png --network={NETWORK}"
# !{cmd}
# Out:
# Loading networks from "/content/stylegan2ada-weights/network-snapshot-004920.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/1000: dist 0.71 loss 24566.07
# step    2/1000: dist 0.79 loss 27639.50
# step    3/1000: dist 0.66 loss 27166.49
# step    4/1000: dist 0.65 loss 26250.48
# step    5/1000: dist 0.69 loss 24954.61
# step    6/1000: dist 0.65 loss 23352.46
# step    7/1000: dist 0.65 loss 21509.97
# step    8/1000: dist 0.63 loss 19484.40
# step    9/1000: dist 0.69 loss 17337.16
# step   10/1000: dist 0.57 loss 15137.42
# step   11/1000: dist 0.64 loss 12947.23
# step   12/1000: dist 0.71 loss 10817.35
# step   13/1000: dist 0.62 loss 8799.33
# step   14/1000: dist 0.62 loss 6945.00
# step   15/1000: dist 0.71 loss 5313.17
# step   16/1000: dist 0.64 loss 3968.43
# step   17/1000: dist 0.55 loss 2940.04
# step   18/1000: dist 0.59 loss 2212.81
# step   19/1000: dist 0.58 loss 1756.68
# step   20/1000: dist 0.60 loss 1564.58
# step   21/1000: dist 0.57 loss 1599.44
# step   22/1000: dist 0.50 loss 1785.68
# step   23/1000: dist 0.55 loss 2050.03
# step   24/1000: dist 0.54 loss 2324.70
# step   25/1000: dist 0.58 loss 2535.39
# step   26/1000: dist 0.57 loss 2633.79
# step   27/1000: dist 0.53 loss 2599.81
# step   28/1000: dist 0.62 loss 2473.23
# step   29/1000: dist 0.54 loss 2312.31
# step   30/1000: dist 0.54 loss 2116.71
# step   31/1000: dist 0.48 loss 1877.89
# step   32/1000: dist 0.54 loss 1620.39
# step   33/1000: dist 0.51 loss 1381.52
# step   34/1000: dist 0.52 loss 1178.85
# step   35/1000: dist 0.51 loss 1020.03
# step   36/1000: dist 0.53 loss 901.36
# step   37/1000: dist 0.54 loss 822.05
# step   38/1000: dist 0.54 loss 799.24
# step   39/1000: dist 0.51 loss 804.50
# step   40/1000: dist 0.51 loss 823.02
# step   41/1000: dist 0.51 loss 819.72
# step   42/1000: dist 0.49 loss 754.09
# step   43/1000: dist 0.50 loss 642.97
# step   44/1000: dist 0.48 loss 514.33
# step   45/1000: dist 0.49 loss 396.36
# step   46/1000: dist 0.49 loss 310.12
# step   47/1000: dist 0.51 loss 255.49
# step   48/1000: dist 0.51 loss 235.67
# step   49/1000: dist 0.50 loss 246.64
# step   50/1000: dist 0.47 loss 297.14
# step   51/1000: dist 0.47 loss 358.68
# step   52/1000: dist 0.48 loss 384.91
# step   53/1000: dist 0.46 loss 371.40
# step   54/1000: dist 0.48 loss 331.78
# step   55/1000: dist 0.48 loss 265.43
# step   56/1000: dist 0.45 loss 185.49
# step   57/1000: dist 0.47 loss 114.08
# step   58/1000: dist 0.51 loss 66.36
# step   59/1000: dist 0.45 loss 46.61
# step   60/1000: dist 0.42 loss 41.99
# step   61/1000: dist 0.43 loss 53.75
# step   62/1000: dist 0.46 loss 78.80
# step   63/1000: dist 0.44 loss 103.91
# step   64/1000: dist 0.44 loss 120.05
# step   65/1000: dist 0.46 loss 123.71
# step   66/1000: dist 0.44 loss 112.90
# step   67/1000: dist 0.46 loss 94.23
# step   68/1000: dist 0.46 loss 67.70
# step   69/1000: dist 0.44 loss 42.80
# step   70/1000: dist 0.45 loss 25.15
# step   71/1000: dist 0.42 loss 14.84
# step   72/1000: dist 0.41 loss 12.99
# step   73/1000: dist 0.43 loss 17.98
# step   74/1000: dist 0.44 loss 23.59
# step   75/1000: dist 0.42 loss 29.64
# step   76/1000: dist 0.43 loss 32.67
# step   77/1000: dist 0.40 loss 31.04
# step   78/1000: dist 0.47 loss 27.65
# step   79/1000: dist 0.42 loss 25.38
# step   80/1000: dist 0.41 loss 24.26
# step   81/1000: dist 0.43 loss 22.18
# step   82/1000: dist 0.47 loss 15.89
# step   83/1000: dist 0.44 loss 10.06
# step   84/1000: dist 0.39 loss 11.23
# step   85/1000: dist 0.40 loss 14.37
# step   86/1000: dist 0.42 loss 12.87
# step   87/1000: dist 0.45 loss 10.13
# step   88/1000: dist 0.46 loss 9.64
# step   89/1000: dist 0.40 loss 9.20
# step   90/1000: dist 0.42 loss 7.16
# step   91/1000: dist 0.41 loss 5.27
# step   92/1000: dist 0.44 loss 5.38
# step   93/1000: dist 0.46 loss 6.55
# step   94/1000: dist 0.45 loss 8.10
# step   95/1000: dist 0.43 loss 9.94
# step   96/1000: dist 0.40 loss 11.29
# step   97/1000: dist 0.40 loss 10.18
# step   98/1000: dist 0.40 loss 6.52
# step   99/1000: dist 0.39 loss 3.39
# step  100/1000: dist 0.40 loss 2.82
# step  101/1000: dist 0.39 loss 3.85
# step  102/1000: dist 0.39 loss 4.09
# step  103/1000: dist 0.38 loss 2.76
# step  104/1000: dist 0.42 loss 1.98
# step  105/1000: dist 0.40 loss 3.12
# step  106/1000: dist 0.40 loss 4.73
# step  107/1000: dist 0.40 loss 5.13
# step  108/1000: dist 0.43 loss 4.93
# step  109/1000: dist 0.38 loss 4.68
# step  110/1000: dist 0.37 loss 3.81
# step  111/1000: dist 0.37 loss 2.48
# step  112/1000: dist 0.38 loss 2.15
# step  113/1000: dist 0.37 loss 2.85
# step  114/1000: dist 0.36 loss 3.25
# step  115/1000: dist 0.40 loss 2.98
# step  116/1000: dist 0.36 loss 3.00
# step  117/1000: dist 0.37 loss 3.74
# step  118/1000: dist 0.40 loss 3.99
# step  119/1000: dist 0.38 loss 3.08
# step  120/1000: dist 0.39 loss 2.08
# step  121/1000: dist 0.40 loss 1.71
# step  122/1000: dist 0.39 loss 1.54
# step  123/1000: dist 0.41 loss 1.23
# step  124/1000: dist 0.38 loss 1.20
# step  125/1000: dist 0.37 loss 1.74
# step  126/1000: dist 0.38 loss 2.19
# step  127/1000: dist 0.38 loss 1.88
# step  128/1000: dist 0.38 loss 1.16
# step  129/1000: dist 0.37 loss 0.75
# step  130/1000: dist 0.37 loss 0.81
# step  131/1000: dist 0.35 loss 0.93
# step  132/1000: dist 0.36 loss 1.02
# step  133/1000: dist 0.37 loss 1.12
# step  134/1000: dist 0.37 loss 1.24
# step  135/1000: dist 0.37 loss 1.24
# step  136/1000: dist 0.35 loss 1.00
# step  137/1000: dist 0.37 loss 0.78
# step  138/1000: dist 0.36 loss 0.69
# step  139/1000: dist 0.37 loss 0.81
# step  140/1000: dist 0.35 loss 0.97
# step  141/1000: dist 0.37 loss 1.22
# step  142/1000: dist 0.37 loss 1.65
# step  143/1000: dist 0.36 loss 2.48
# step  144/1000: dist 0.40 loss 3.97
# step  145/1000: dist 0.38 loss 6.04
# step  146/1000: dist 0.36 loss 8.16
# step  147/1000: dist 0.37 loss 8.62
# step  148/1000: dist 0.38 loss 5.92
# step  149/1000: dist 0.36 loss 2.03
# step  150/1000: dist 0.38 loss 1.03
# step  151/1000: dist 0.35 loss 3.26
# step  152/1000: dist 0.41 loss 5.41
# step  153/1000: dist 0.35 loss 4.93
# step  154/1000: dist 0.35 loss 4.48
# step  155/1000: dist 0.35 loss 8.32
# step  156/1000: dist 0.36 loss 15.96
# step  157/1000: dist 0.34 loss 19.60
# step  158/1000: dist 0.36 loss 12.69
# step  159/1000: dist 0.36 loss 5.92
# step  160/1000: dist 0.35 loss 12.70
# step  161/1000: dist 0.35 loss 22.32
# step  162/1000: dist 0.35 loss 19.15
# step  163/1000: dist 0.35 loss 12.70
# step  164/1000: dist 0.36 loss 15.52
# step  165/1000: dist 0.37 loss 16.90
# step  166/1000: dist 0.36 loss 10.77
# step  167/1000: dist 0.39 loss 8.89
# step  168/1000: dist 0.36 loss 10.52
# step  169/1000: dist 0.38 loss 8.35
# step  170/1000: dist 0.33 loss 6.59
# step  171/1000: dist 0.35 loss 6.51
# step  172/1000: dist 0.36 loss 4.30
# step  173/1000: dist 0.34 loss 4.14
# step  174/1000: dist 0.37 loss 6.69
# step  175/1000: dist 0.38 loss 5.41
# step  176/1000: dist 0.38 loss 2.99
# step  177/1000: dist 0.36 loss 3.84
# step  178/1000: dist 0.35 loss 3.85
# step  179/1000: dist 0.33 loss 2.25
# step  180/1000: dist 0.36 loss 2.64
# step  181/1000: dist 0.34 loss 3.39
# step  182/1000: dist 0.33 loss 3.24
# step  183/1000: dist 0.36 loss 4.18
# step  184/1000: dist 0.32 loss 5.81
# step  185/1000: dist 0.37 loss 7.91
# step  186/1000: dist 0.34 loss 11.68
# step  187/1000: dist 0.34 loss 14.63
# step  188/1000: dist 0.34 loss 12.56
# step  189/1000: dist 0.37 loss 8.12
# step  190/1000: dist 0.34 loss 7.95
# step  191/1000: dist 0.34 loss 11.46
# step  192/1000: dist 0.40 loss 12.69
# step  193/1000: dist 0.35 loss 10.72
# step  194/1000: dist 0.33 loss 11.39
# step  195/1000: dist 0.32 loss 16.10
# step  196/1000: dist 0.33 loss 17.19
# step  197/1000: dist 0.36 loss 10.24
# step  198/1000: dist 0.33 loss 3.58
# step  199/1000: dist 0.35 loss 4.90
# step  200/1000: dist 0.34 loss 8.48
# step  201/1000: dist 0.33 loss 7.70
# step  202/1000: dist 0.32 loss 4.74
# step  203/1000: dist 0.31 loss 3.76
# step  204/1000: dist 0.34 loss 4.34
# step  205/1000: dist 0.34 loss 4.66
# step  206/1000: dist 0.40 loss 4.38
# step  207/1000: dist 0.36 loss 3.40
# step  208/1000: dist 0.35 loss 2.66
# step  209/1000: dist 0.35 loss 3.09
# step  210/1000: dist 0.36 loss 3.69
# step  211/1000: dist 0.33 loss 3.03
# step  212/1000: dist 0.34 loss 2.21
# step  213/1000: dist 0.34 loss 2.66
# step  214/1000: dist 0.34 loss 3.42
# step  215/1000: dist 0.31 loss 3.13
# step  216/1000: dist 0.36 loss 2.64
# step  217/1000: dist 0.36 loss 2.85
# step  218/1000: dist 0.35 loss 3.19
# step  219/1000: dist 0.33 loss 2.82
# step  220/1000: dist 0.32 loss 2.12
# step  221/1000: dist 0.34 loss 1.69
# step  222/1000: dist 0.34 loss 1.36
# step  223/1000: dist 0.32 loss 1.01
# step  224/1000: dist 0.34 loss 0.91
# step  225/1000: dist 0.32 loss 0.92
# step  226/1000: dist 0.32 loss 0.91
# step  227/1000: dist 0.32 loss 0.94
# step  228/1000: dist 0.31 loss 1.17
# step  229/1000: dist 0.31 loss 1.43
# step  230/1000: dist 0.33 loss 1.37
# step  231/1000: dist 0.32 loss 1.10
# step  232/1000: dist 0.33 loss 0.99
# step  233/1000: dist 0.32 loss 0.99
# step  234/1000: dist 0.32 loss 0.89
# step  235/1000: dist 0.30 loss 0.63
# step  236/1000: dist 0.32 loss 0.47
# step  237/1000: dist 0.30 loss 0.43
# step  238/1000: dist 0.32 loss 0.49
# step  239/1000: dist 0.32 loss 0.49
# step  240/1000: dist 0.32 loss 0.49
# step  241/1000: dist 0.31 loss 0.51
# step  242/1000: dist 0.31 loss 0.56
# step  243/1000: dist 0.31 loss 0.61
# step  244/1000: dist 0.32 loss 0.67
# step  245/1000: dist 0.33 loss 0.79
# step  246/1000: dist 0.31 loss 0.90
# step  247/1000: dist 0.34 loss 1.05
# step  248/1000: dist 0.32 loss 1.15
# step  249/1000: dist 0.31 loss 1.30
# step  250/1000: dist 0.30 loss 1.55
# step  251/1000: dist 0.30 loss 1.84
# step  252/1000: dist 0.32 loss 2.11
# step  253/1000: dist 0.32 loss 2.29
# step  254/1000: dist 0.32 loss 2.33
# step  255/1000: dist 0.30 loss 2.18
# step  256/1000: dist 0.29 loss 1.83
# step  257/1000: dist 0.31 loss 1.36
# step  258/1000: dist 0.34 loss 0.89
# step  259/1000: dist 0.32 loss 0.51
# step  260/1000: dist 0.32 loss 0.36
# step  261/1000: dist 0.33 loss 0.44
# step  262/1000: dist 0.30 loss 0.61
# step  263/1000: dist 0.30 loss 0.87
# step  264/1000: dist 0.30 loss 1.14
# step  265/1000: dist 0.30 loss 1.44
# step  266/1000: dist 0.30 loss 1.83
# step  267/1000: dist 0.31 loss 2.59
# step  268/1000: dist 0.30 loss 4.13
# step  269/1000: dist 0.30 loss 7.22
# step  270/1000: dist 0.30 loss 12.24
# step  271/1000: dist 0.32 loss 17.50
# step  272/1000: dist 0.35 loss 17.28
# step  273/1000: dist 0.31 loss 9.56
# step  274/1000: dist 0.31 loss 4.24
# step  275/1000: dist 0.29 loss 10.27
# step  276/1000: dist 0.30 loss 20.89
# step  277/1000: dist 0.32 loss 24.98
# step  278/1000: dist 0.30 loss 25.27
# step  279/1000: dist 0.32 loss 29.88
# step  280/1000: dist 0.30 loss 31.15
# step  281/1000: dist 0.32 loss 17.58
# step  282/1000: dist 0.31 loss 5.89
# step  283/1000: dist 0.30 loss 14.06
# step  284/1000: dist 0.31 loss 20.49
# step  285/1000: dist 0.32 loss 8.40
# step  286/1000: dist 0.30 loss 2.55
# step  287/1000: dist 0.28 loss 13.22
# step  288/1000: dist 0.29 loss 13.17
# step  289/1000: dist 0.29 loss 3.12
# step  290/1000: dist 0.30 loss 7.32
# step  291/1000: dist 0.30 loss 14.35
# step  292/1000: dist 0.29 loss 11.01
# step  293/1000: dist 0.30 loss 13.03
# step  294/1000: dist 0.28 loss 19.16
# step  295/1000: dist 0.29 loss 17.38
# step  296/1000: dist 0.31 loss 14.86
# step  297/1000: dist 0.29 loss 12.48
# step  298/1000: dist 0.32 loss 6.17
# step  299/1000: dist 0.28 loss 5.46
# step  300/1000: dist 0.32 loss 9.60
# step  301/1000: dist 0.29 loss 9.46
# step  302/1000: dist 0.29 loss 8.33
# step  303/1000: dist 0.28 loss 7.47
# step  304/1000: dist 0.30 loss 5.83
# step  305/1000: dist 0.29 loss 6.48
# step  306/1000: dist 0.28 loss 6.86
# step  307/1000: dist 0.29 loss 4.49
# step  308/1000: dist 0.29 loss 2.74
# step  309/1000: dist 0.27 loss 2.16
# step  310/1000: dist 0.29 loss 2.50
# step  311/1000: dist 0.29 loss 3.76
# step  312/1000: dist 0.30 loss 3.28
# step  313/1000: dist 0.29 loss 2.10
# step  314/1000: dist 0.29 loss 3.19
# step  315/1000: dist 0.27 loss 4.31
# step  316/1000: dist 0.28 loss 4.13
# step  317/1000: dist 0.27 loss 4.46
# step  318/1000: dist 0.28 loss 5.59
# step  319/1000: dist 0.28 loss 6.62
# step  320/1000: dist 0.28 loss 6.16
# step  321/1000: dist 0.27 loss 3.49
# step  322/1000: dist 0.28 loss 1.61
# step  323/1000: dist 0.29 loss 3.07
# step  324/1000: dist 0.28 loss 6.47
# step  325/1000: dist 0.28 loss 9.66
# step  326/1000: dist 0.29 loss 10.93
# step  327/1000: dist 0.28 loss 8.31
# step  328/1000: dist 0.28 loss 3.43
# step  329/1000: dist 0.28 loss 2.01
# step  330/1000: dist 0.27 loss 4.91
# step  331/1000: dist 0.28 loss 6.43
# step  332/1000: dist 0.27 loss 3.59
# step  333/1000: dist 0.27 loss 1.30
# step  334/1000: dist 0.29 loss 3.43
# step  335/1000: dist 0.28 loss 5.47
# step  336/1000: dist 0.28 loss 3.79
# step  337/1000: dist 0.29 loss 2.62
# step  338/1000: dist 0.28 loss 5.18
# step  339/1000: dist 0.28 loss 8.09
# step  340/1000: dist 0.28 loss 9.43
# step  341/1000: dist 0.27 loss 12.34
# step  342/1000: dist 0.29 loss 17.26
# step  343/1000: dist 0.27 loss 20.01
# step  344/1000: dist 0.27 loss 17.48
# step  345/1000: dist 0.29 loss 10.43
# step  346/1000: dist 0.29 loss 3.49
# step  347/1000: dist 0.28 loss 2.39
# step  348/1000: dist 0.28 loss 7.35
# step  349/1000: dist 0.27 loss 11.72
# step  350/1000: dist 0.28 loss 10.41
# step  351/1000: dist 0.26 loss 7.97
# step  352/1000: dist 0.27 loss 11.45
# step  353/1000: dist 0.26 loss 17.95
# step  354/1000: dist 0.28 loss 18.52
# step  355/1000: dist 0.27 loss 11.62
# step  356/1000: dist 0.27 loss 5.68
# step  357/1000: dist 0.26 loss 6.84
# step  358/1000: dist 0.28 loss 12.01
# step  359/1000: dist 0.30 loss 15.95
# step  360/1000: dist 0.28 loss 16.73
# step  361/1000: dist 0.27 loss 15.25
# step  362/1000: dist 0.27 loss 11.69
# step  363/1000: dist 0.28 loss 6.94
# step  364/1000: dist 0.29 loss 3.80
# step  365/1000: dist 0.29 loss 4.70
# step  366/1000: dist 0.28 loss 7.81
# step  367/1000: dist 0.27 loss 7.71
# step  368/1000: dist 0.27 loss 3.74
# step  369/1000: dist 0.28 loss 1.90
# step  370/1000: dist 0.26 loss 4.50
# step  371/1000: dist 0.27 loss 6.27
# step  372/1000: dist 0.28 loss 4.52
# step  373/1000: dist 0.27 loss 4.44
# step  374/1000: dist 0.27 loss 9.38
# step  375/1000: dist 0.27 loss 15.44
# step  376/1000: dist 0.27 loss 19.12
# step  377/1000: dist 0.26 loss 19.15
# step  378/1000: dist 0.26 loss 13.38
# step  379/1000: dist 0.26 loss 4.65
# step  380/1000: dist 0.27 loss 2.49
# step  381/1000: dist 0.27 loss 8.18
# step  382/1000: dist 0.27 loss 11.46
# step  383/1000: dist 0.28 loss 6.68
# step  384/1000: dist 0.27 loss 2.78
# step  385/1000: dist 0.27 loss 6.96
# step  386/1000: dist 0.27 loss 11.78
# step  387/1000: dist 0.26 loss 10.53
# step  388/1000: dist 0.26 loss 8.93
# step  389/1000: dist 0.26 loss 10.95
# step  390/1000: dist 0.26 loss 10.11
# step  391/1000: dist 0.27 loss 4.08
# step  392/1000: dist 0.26 loss 0.69
# step  393/1000: dist 0.25 loss 3.24
# step  394/1000: dist 0.26 loss 5.64
# step  395/1000: dist 0.26 loss 4.68
# step  396/1000: dist 0.27 loss 3.38
# step  397/1000: dist 0.27 loss 2.73
# step  398/1000: dist 0.27 loss 1.65
# step  399/1000: dist 0.26 loss 1.48
# step  400/1000: dist 0.27 loss 2.95
# step  401/1000: dist 0.27 loss 3.26
# step  402/1000: dist 0.27 loss 1.47
# step  403/1000: dist 0.26 loss 0.50
# step  404/1000: dist 0.26 loss 1.54
# step  405/1000: dist 0.26 loss 2.22
# step  406/1000: dist 0.25 loss 1.54
# step  407/1000: dist 0.26 loss 1.02
# step  408/1000: dist 0.26 loss 1.30
# step  409/1000: dist 0.26 loss 1.68
# step  410/1000: dist 0.26 loss 2.14
# step  411/1000: dist 0.26 loss 2.99
# step  412/1000: dist 0.26 loss 4.06
# step  413/1000: dist 0.25 loss 5.53
# step  414/1000: dist 0.26 loss 7.89
# step  415/1000: dist 0.26 loss 9.97
# step  416/1000: dist 0.26 loss 9.48
# step  417/1000: dist 0.25 loss 5.73
# step  418/1000: dist 0.26 loss 1.70
# step  419/1000: dist 0.25 loss 0.60
# step  420/1000: dist 0.26 loss 2.42
# step  421/1000: dist 0.26 loss 4.38
# step  422/1000: dist 0.25 loss 4.08
# step  423/1000: dist 0.25 loss 1.89
# step  424/1000: dist 0.26 loss 0.45
# step  425/1000: dist 0.25 loss 1.20
# step  426/1000: dist 0.26 loss 2.62
# step  427/1000: dist 0.25 loss 2.46
# step  428/1000: dist 0.26 loss 1.00
# step  429/1000: dist 0.24 loss 0.32
# step  430/1000: dist 0.25 loss 1.11
# step  431/1000: dist 0.25 loss 1.85
# step  432/1000: dist 0.25 loss 1.37
# step  433/1000: dist 0.25 loss 0.53
# step  434/1000: dist 0.25 loss 0.58
# step  435/1000: dist 0.26 loss 1.33
# step  436/1000: dist 0.26 loss 1.70
# step  437/1000: dist 0.25 loss 1.56
# step  438/1000: dist 0.26 loss 1.83
# step  439/1000: dist 0.25 loss 3.06
# step  440/1000: dist 0.25 loss 4.81
# step  441/1000: dist 0.25 loss 6.45
# step  442/1000: dist 0.25 loss 7.44
# step  443/1000: dist 0.25 loss 7.15
# step  444/1000: dist 0.25 loss 4.99
# step  445/1000: dist 0.25 loss 2.03
# step  446/1000: dist 0.25 loss 0.45
# step  447/1000: dist 0.25 loss 1.27
# step  448/1000: dist 0.25 loss 3.14
# step  449/1000: dist 0.25 loss 3.85
# step  450/1000: dist 0.25 loss 2.66
# step  451/1000: dist 0.25 loss 1.12
# step  452/1000: dist 0.25 loss 1.17
# step  453/1000: dist 0.24 loss 2.85
# step  454/1000: dist 0.25 loss 4.77
# step  455/1000: dist 0.25 loss 6.19
# step  456/1000: dist 0.26 loss 8.06
# step  457/1000: dist 0.26 loss 11.54
# step  458/1000: dist 0.25 loss 15.21
# step  459/1000: dist 0.25 loss 15.61
# step  460/1000: dist 0.24 loss 11.01
# step  461/1000: dist 0.25 loss 6.46
# step  462/1000: dist 0.26 loss 8.20
# step  463/1000: dist 0.24 loss 15.15
# step  464/1000: dist 0.24 loss 19.78
# step  465/1000: dist 0.24 loss 15.88
# step  466/1000: dist 0.25 loss 7.20
# step  467/1000: dist 0.25 loss 2.24
# step  468/1000: dist 0.25 loss 3.79
# step  469/1000: dist 0.24 loss 6.81
# step  470/1000: dist 0.25 loss 6.93
# step  471/1000: dist 0.24 loss 5.00
# step  472/1000: dist 0.25 loss 3.23
# step  473/1000: dist 0.25 loss 2.51
# step  474/1000: dist 0.24 loss 2.84
# step  475/1000: dist 0.25 loss 3.69
# step  476/1000: dist 0.24 loss 3.58
# step  477/1000: dist 0.24 loss 2.02
# step  478/1000: dist 0.25 loss 1.07
# step  479/1000: dist 0.25 loss 2.07
# step  480/1000: dist 0.25 loss 3.15
# step  481/1000: dist 0.25 loss 2.42
# step  482/1000: dist 0.25 loss 1.51
# step  483/1000: dist 0.24 loss 2.81
# step  484/1000: dist 0.24 loss 5.59
# step  485/1000: dist 0.25 loss 8.23
# step  486/1000: dist 0.24 loss 11.67
# step  487/1000: dist 0.24 loss 16.70
# step  488/1000: dist 0.24 loss 19.16
# step  489/1000: dist 0.24 loss 13.51
# step  490/1000: dist 0.25 loss 3.73
# step  491/1000: dist 0.26 loss 0.55
# step  492/1000: dist 0.24 loss 5.68
# step  493/1000: dist 0.25 loss 9.75
# step  494/1000: dist 0.26 loss 6.26
# step  495/1000: dist 0.24 loss 1.12
# step  496/1000: dist 0.24 loss 2.18
# step  497/1000: dist 0.24 loss 6.23
# step  498/1000: dist 0.25 loss 6.26
# step  499/1000: dist 0.25 loss 4.35
# step  500/1000: dist 0.23 loss 7.44
# step  501/1000: dist 0.24 loss 15.05
# step  502/1000: dist 0.24 loss 21.74
# step  503/1000: dist 0.25 loss 23.99
# step  504/1000: dist 0.24 loss 19.25
# step  505/1000: dist 0.24 loss 7.97
# step  506/1000: dist 0.24 loss 1.76
# step  507/1000: dist 0.24 loss 6.89
# step  508/1000: dist 0.24 loss 12.43
# step  509/1000: dist 0.24 loss 7.51
# step  510/1000: dist 0.24 loss 0.95
# step  511/1000: dist 0.24 loss 4.07
# step  512/1000: dist 0.24 loss 8.02
# step  513/1000: dist 0.23 loss 3.74
# step  514/1000: dist 0.23 loss 0.67
# step  515/1000: dist 0.23 loss 4.08
# step  516/1000: dist 0.24 loss 4.62
# step  517/1000: dist 0.24 loss 1.12
# step  518/1000: dist 0.23 loss 1.57
# step  519/1000: dist 0.24 loss 3.52
# step  520/1000: dist 0.23 loss 1.76
# step  521/1000: dist 0.24 loss 0.84
# step  522/1000: dist 0.23 loss 2.48
# step  523/1000: dist 0.23 loss 2.22
# step  524/1000: dist 0.23 loss 1.49
# step  525/1000: dist 0.23 loss 3.37
# step  526/1000: dist 0.23 loss 5.40
# step  527/1000: dist 0.23 loss 7.73
# step  528/1000: dist 0.23 loss 12.82
# step  529/1000: dist 0.23 loss 16.62
# step  530/1000: dist 0.24 loss 13.35
# step  531/1000: dist 0.23 loss 5.54
# step  532/1000: dist 0.23 loss 1.15
# step  533/1000: dist 0.23 loss 3.46
# step  534/1000: dist 0.23 loss 7.83
# step  535/1000: dist 0.23 loss 6.96
# step  536/1000: dist 0.23 loss 1.75
# step  537/1000: dist 0.23 loss 0.82
# step  538/1000: dist 0.23 loss 4.57
# step  539/1000: dist 0.23 loss 5.01
# step  540/1000: dist 0.23 loss 1.55
# step  541/1000: dist 0.23 loss 1.02
# step  542/1000: dist 0.23 loss 3.72
# step  543/1000: dist 0.23 loss 4.47
# step  544/1000: dist 0.23 loss 3.61
# step  545/1000: dist 0.23 loss 5.73
# step  546/1000: dist 0.23 loss 11.36
# step  547/1000: dist 0.23 loss 18.05
# step  548/1000: dist 0.23 loss 25.70
# step  549/1000: dist 0.23 loss 33.37
# step  550/1000: dist 0.23 loss 34.51
# step  551/1000: dist 0.23 loss 23.90
# step  552/1000: dist 0.23 loss 9.22
# step  553/1000: dist 0.23 loss 5.00
# step  554/1000: dist 0.23 loss 12.17
# step  555/1000: dist 0.23 loss 15.78
# step  556/1000: dist 0.23 loss 9.00
# step  557/1000: dist 0.23 loss 3.37
# step  558/1000: dist 0.22 loss 7.47
# step  559/1000: dist 0.23 loss 11.86
# step  560/1000: dist 0.23 loss 9.36
# step  561/1000: dist 0.22 loss 10.30
# step  562/1000: dist 0.22 loss 22.06
# step  563/1000: dist 0.23 loss 34.90
# step  564/1000: dist 0.22 loss 39.94
# step  565/1000: dist 0.23 loss 34.78
# step  566/1000: dist 0.22 loss 23.06
# step  567/1000: dist 0.23 loss 16.02
# step  568/1000: dist 0.22 loss 18.09
# step  569/1000: dist 0.22 loss 16.70
# step  570/1000: dist 0.22 loss 6.77
# step  571/1000: dist 0.22 loss 6.62
# step  572/1000: dist 0.22 loss 15.89
# step  573/1000: dist 0.23 loss 12.09
# step  574/1000: dist 0.22 loss 2.37
# step  575/1000: dist 0.23 loss 6.07
# step  576/1000: dist 0.22 loss 10.94
# step  577/1000: dist 0.23 loss 7.44
# step  578/1000: dist 0.23 loss 7.97
# step  579/1000: dist 0.23 loss 12.31
# step  580/1000: dist 0.23 loss 15.20
# step  581/1000: dist 0.22 loss 21.78
# step  582/1000: dist 0.22 loss 26.02
# step  583/1000: dist 0.22 loss 22.03
# step  584/1000: dist 0.23 loss 17.46
# step  585/1000: dist 0.22 loss 14.20
# step  586/1000: dist 0.22 loss 10.50
# step  587/1000: dist 0.23 loss 10.67
# step  588/1000: dist 0.22 loss 11.40
# step  589/1000: dist 0.23 loss 10.45
# step  590/1000: dist 0.23 loss 14.31
# step  591/1000: dist 0.22 loss 20.24
# step  592/1000: dist 0.22 loss 21.51
# step  593/1000: dist 0.23 loss 17.94
# step  594/1000: dist 0.23 loss 10.76
# step  595/1000: dist 0.22 loss 5.77
# step  596/1000: dist 0.22 loss 6.50
# step  597/1000: dist 0.23 loss 7.44
# step  598/1000: dist 0.22 loss 7.43
# step  599/1000: dist 0.22 loss 7.16
# step  600/1000: dist 0.23 loss 4.72
# step  601/1000: dist 0.23 loss 3.32
# step  602/1000: dist 0.22 loss 4.61
# step  603/1000: dist 0.22 loss 5.01
# step  604/1000: dist 0.23 loss 3.66
# step  605/1000: dist 0.23 loss 2.62
# step  606/1000: dist 0.22 loss 3.24
# step  607/1000: dist 0.22 loss 4.33
# step  608/1000: dist 0.22 loss 3.54
# step  609/1000: dist 0.22 loss 2.70
# step  610/1000: dist 0.22 loss 4.39
# step  611/1000: dist 0.22 loss 6.06
# step  612/1000: dist 0.22 loss 5.89
# step  613/1000: dist 0.22 loss 6.27
# step  614/1000: dist 0.22 loss 8.01
# step  615/1000: dist 0.22 loss 8.72
# step  616/1000: dist 0.22 loss 6.90
# step  617/1000: dist 0.22 loss 4.13
# step  618/1000: dist 0.22 loss 2.46
# step  619/1000: dist 0.22 loss 1.60
# step  620/1000: dist 0.22 loss 0.95
# step  621/1000: dist 0.22 loss 1.47
# step  622/1000: dist 0.22 loss 2.94
# step  623/1000: dist 0.21 loss 3.33
# step  624/1000: dist 0.22 loss 2.25
# step  625/1000: dist 0.22 loss 1.12
# step  626/1000: dist 0.22 loss 0.70
# step  627/1000: dist 0.22 loss 0.76
# step  628/1000: dist 0.22 loss 1.12
# step  629/1000: dist 0.22 loss 1.57
# step  630/1000: dist 0.21 loss 1.66
# step  631/1000: dist 0.21 loss 1.13
# step  632/1000: dist 0.21 loss 0.55
# step  633/1000: dist 0.22 loss 0.70
# step  634/1000: dist 0.22 loss 1.43
# step  635/1000: dist 0.21 loss 2.17
# step  636/1000: dist 0.21 loss 2.98
# step  637/1000: dist 0.22 loss 4.45
# step  638/1000: dist 0.22 loss 7.09
# step  639/1000: dist 0.22 loss 11.01
# step  640/1000: dist 0.21 loss 15.54
# step  641/1000: dist 0.21 loss 17.62
# step  642/1000: dist 0.21 loss 14.08
# step  643/1000: dist 0.22 loss 5.90
# step  644/1000: dist 0.21 loss 0.50
# step  645/1000: dist 0.21 loss 2.33
# step  646/1000: dist 0.22 loss 7.09
# step  647/1000: dist 0.21 loss 7.56
# step  648/1000: dist 0.21 loss 3.16
# step  649/1000: dist 0.22 loss 0.61
# step  650/1000: dist 0.22 loss 2.88
# step  651/1000: dist 0.21 loss 5.08
# step  652/1000: dist 0.22 loss 3.57
# step  653/1000: dist 0.22 loss 1.82
# step  654/1000: dist 0.21 loss 3.79
# step  655/1000: dist 0.22 loss 7.16
# step  656/1000: dist 0.22 loss 8.86
# step  657/1000: dist 0.21 loss 11.10
# step  658/1000: dist 0.21 loss 16.26
# step  659/1000: dist 0.22 loss 20.17
# step  660/1000: dist 0.21 loss 18.29
# step  661/1000: dist 0.21 loss 12.84
# step  662/1000: dist 0.21 loss 10.94
# step  663/1000: dist 0.21 loss 12.85
# step  664/1000: dist 0.21 loss 12.65
# step  665/1000: dist 0.21 loss 8.58
# step  666/1000: dist 0.21 loss 4.86
# step  667/1000: dist 0.21 loss 4.82
# step  668/1000: dist 0.21 loss 6.82
# step  669/1000: dist 0.21 loss 6.84
# step  670/1000: dist 0.21 loss 4.32
# step  671/1000: dist 0.21 loss 2.61
# step  672/1000: dist 0.21 loss 3.52
# step  673/1000: dist 0.21 loss 4.54
# step  674/1000: dist 0.21 loss 3.37
# step  675/1000: dist 0.21 loss 1.89
# step  676/1000: dist 0.21 loss 2.32
# step  677/1000: dist 0.21 loss 3.41
# step  678/1000: dist 0.21 loss 3.21
# step  679/1000: dist 0.21 loss 2.93
# step  680/1000: dist 0.21 loss 4.73
# step  681/1000: dist 0.21 loss 8.42
# step  682/1000: dist 0.21 loss 13.14
# step  683/1000: dist 0.21 loss 19.36
# step  684/1000: dist 0.21 loss 24.33
# step  685/1000: dist 0.21 loss 21.37
# step  686/1000: dist 0.21 loss 9.02
# step  687/1000: dist 0.21 loss 0.71
# step  688/1000: dist 0.21 loss 5.08
# step  689/1000: dist 0.21 loss 11.83
# step  690/1000: dist 0.21 loss 8.53
# step  691/1000: dist 0.21 loss 1.16
# step  692/1000: dist 0.21 loss 2.53
# step  693/1000: dist 0.21 loss 7.36
# step  694/1000: dist 0.21 loss 4.69
# step  695/1000: dist 0.21 loss 0.44
# step  696/1000: dist 0.21 loss 2.83
# step  697/1000: dist 0.21 loss 4.85
# step  698/1000: dist 0.21 loss 1.64
# step  699/1000: dist 0.21 loss 0.66
# step  700/1000: dist 0.21 loss 3.10
# step  701/1000: dist 0.21 loss 2.35
# step  702/1000: dist 0.21 loss 0.38
# step  703/1000: dist 0.21 loss 1.60
# step  704/1000: dist 0.21 loss 2.16
# step  705/1000: dist 0.21 loss 0.59
# step  706/1000: dist 0.21 loss 0.82
# step  707/1000: dist 0.21 loss 1.68
# step  708/1000: dist 0.21 loss 0.72
# step  709/1000: dist 0.21 loss 0.45
# step  710/1000: dist 0.21 loss 1.25
# step  711/1000: dist 0.21 loss 0.78
# step  712/1000: dist 0.20 loss 0.27
# step  713/1000: dist 0.20 loss 0.86
# step  714/1000: dist 0.21 loss 0.81
# step  715/1000: dist 0.20 loss 0.26
# step  716/1000: dist 0.20 loss 0.57
# step  717/1000: dist 0.20 loss 0.74
# step  718/1000: dist 0.20 loss 0.35
# step  719/1000: dist 0.20 loss 0.44
# step  720/1000: dist 0.20 loss 0.69
# step  721/1000: dist 0.20 loss 0.49
# step  722/1000: dist 0.20 loss 0.54
# step  723/1000: dist 0.20 loss 0.87
# step  724/1000: dist 0.20 loss 0.93
# step  725/1000: dist 0.20 loss 1.17
# step  726/1000: dist 0.20 loss 1.86
# step  727/1000: dist 0.20 loss 2.60
# step  728/1000: dist 0.20 loss 3.63
# step  729/1000: dist 0.20 loss 5.28
# step  730/1000: dist 0.20 loss 7.11
# step  731/1000: dist 0.20 loss 8.55
# step  732/1000: dist 0.20 loss 8.95
# step  733/1000: dist 0.20 loss 7.42
# step  734/1000: dist 0.20 loss 4.22
# step  735/1000: dist 0.20 loss 1.35
# step  736/1000: dist 0.20 loss 0.60
# step  737/1000: dist 0.20 loss 1.96
# step  738/1000: dist 0.20 loss 3.94
# step  739/1000: dist 0.20 loss 4.83
# step  740/1000: dist 0.20 loss 4.30
# step  741/1000: dist 0.20 loss 3.94
# step  742/1000: dist 0.20 loss 5.53
# step  743/1000: dist 0.20 loss 9.03
# step  744/1000: dist 0.20 loss 12.70
# step  745/1000: dist 0.20 loss 14.58
# step  746/1000: dist 0.20 loss 13.31
# step  747/1000: dist 0.20 loss 9.08
# step  748/1000: dist 0.20 loss 4.06
# step  749/1000: dist 0.20 loss 1.33
# step  750/1000: dist 0.20 loss 2.05
# step  751/1000: dist 0.20 loss 4.47
# step  752/1000: dist 0.20 loss 5.57
# step  753/1000: dist 0.20 loss 3.97
# step  754/1000: dist 0.20 loss 1.48
# step  755/1000: dist 0.20 loss 0.82
# step  756/1000: dist 0.20 loss 2.14
# step  757/1000: dist 0.20 loss 3.10
# step  758/1000: dist 0.20 loss 2.24
# step  759/1000: dist 0.20 loss 0.81
# step  760/1000: dist 0.20 loss 0.69
# step  761/1000: dist 0.20 loss 1.61
# step  762/1000: dist 0.20 loss 1.87
# step  763/1000: dist 0.20 loss 1.07
# step  764/1000: dist 0.20 loss 0.53
# step  765/1000: dist 0.20 loss 1.01
# step  766/1000: dist 0.20 loss 1.64
# step  767/1000: dist 0.20 loss 1.59
# step  768/1000: dist 0.21 loss 1.51
# step  769/1000: dist 0.20 loss 2.34
# step  770/1000: dist 0.21 loss 3.90
# step  771/1000: dist 0.20 loss 5.47
# step  772/1000: dist 0.20 loss 7.10
# step  773/1000: dist 0.20 loss 8.90
# step  774/1000: dist 0.20 loss 9.92
# step  775/1000: dist 0.20 loss 8.63
# step  776/1000: dist 0.20 loss 5.52
# step  777/1000: dist 0.20 loss 3.14
# step  778/1000: dist 0.20 loss 3.47
# step  779/1000: dist 0.20 loss 5.85
# step  780/1000: dist 0.20 loss 7.87
# step  781/1000: dist 0.20 loss 7.67
# step  782/1000: dist 0.20 loss 5.21
# step  783/1000: dist 0.20 loss 2.40
# step  784/1000: dist 0.20 loss 1.19
# step  785/1000: dist 0.20 loss 1.68
# step  786/1000: dist 0.20 loss 2.37
# step  787/1000: dist 0.20 loss 2.21
# step  788/1000: dist 0.20 loss 1.77
# step  789/1000: dist 0.20 loss 1.77
# step  790/1000: dist 0.20 loss 1.80
# step  791/1000: dist 0.20 loss 1.22
# step  792/1000: dist 0.20 loss 0.54
# step  793/1000: dist 0.20 loss 0.69
# step  794/1000: dist 0.20 loss 1.34
# step  795/1000: dist 0.20 loss 1.38
# step  796/1000: dist 0.20 loss 0.67
# step  797/1000: dist 0.20 loss 0.22
# step  798/1000: dist 0.20 loss 0.55
# step  799/1000: dist 0.20 loss 0.93
# step  800/1000: dist 0.20 loss 0.74
# step  801/1000: dist 0.20 loss 0.33
# step  802/1000: dist 0.20 loss 0.30
# step  803/1000: dist 0.20 loss 0.53
# step  804/1000: dist 0.20 loss 0.54
# step  805/1000: dist 0.20 loss 0.36
# step  806/1000: dist 0.20 loss 0.30
# step  807/1000: dist 0.20 loss 0.36
# step  808/1000: dist 0.20 loss 0.36
# step  809/1000: dist 0.20 loss 0.31
# step  810/1000: dist 0.20 loss 0.31
# step  811/1000: dist 0.20 loss 0.29
# step  812/1000: dist 0.20 loss 0.26
# step  813/1000: dist 0.20 loss 0.28
# step  814/1000: dist 0.20 loss 0.29
# step  815/1000: dist 0.20 loss 0.23
# step  816/1000: dist 0.20 loss 0.23
# step  817/1000: dist 0.20 loss 0.27
# step  818/1000: dist 0.20 loss 0.25
# step  819/1000: dist 0.20 loss 0.20
# step  820/1000: dist 0.20 loss 0.23
# step  821/1000: dist 0.20 loss 0.25
# step  822/1000: dist 0.20 loss 0.21
# step  823/1000: dist 0.20 loss 0.21
# step  824/1000: dist 0.20 loss 0.24
# step  825/1000: dist 0.20 loss 0.21
# step  826/1000: dist 0.20 loss 0.20
# step  827/1000: dist 0.20 loss 0.22
# step  828/1000: dist 0.20 loss 0.22
# step  829/1000: dist 0.20 loss 0.20
# step  830/1000: dist 0.20 loss 0.21
# step  831/1000: dist 0.20 loss 0.21
# step  832/1000: dist 0.20 loss 0.20
# step  833/1000: dist 0.20 loss 0.20
# step  834/1000: dist 0.20 loss 0.20
# step  835/1000: dist 0.20 loss 0.20
# step  836/1000: dist 0.19 loss 0.20
# step  837/1000: dist 0.20 loss 0.20
# step  838/1000: dist 0.20 loss 0.20
# step  839/1000: dist 0.19 loss 0.20
# step  840/1000: dist 0.19 loss 0.20
# step  841/1000: dist 0.20 loss 0.20
# step  842/1000: dist 0.20 loss 0.20
# step  843/1000: dist 0.19 loss 0.20
# step  844/1000: dist 0.20 loss 0.20
# step  845/1000: dist 0.19 loss 0.20
# step  846/1000: dist 0.19 loss 0.20
# step  847/1000: dist 0.19 loss 0.20
# step  848/1000: dist 0.19 loss 0.20
# step  849/1000: dist 0.19 loss 0.20
# step  850/1000: dist 0.19 loss 0.19
# step  851/1000: dist 0.19 loss 0.20
# step  852/1000: dist 0.19 loss 0.20
# step  853/1000: dist 0.19 loss 0.19
# step  854/1000: dist 0.19 loss 0.20
# step  855/1000: dist 0.19 loss 0.19
# step  856/1000: dist 0.19 loss 0.20
# step  857/1000: dist 0.19 loss 0.19
# step  858/1000: dist 0.19 loss 0.19
# step  859/1000: dist 0.19 loss 0.19
# step  860/1000: dist 0.19 loss 0.19
# step  861/1000: dist 0.19 loss 0.19
# step  862/1000: dist 0.19 loss 0.19
# step  863/1000: dist 0.19 loss 0.19
# step  864/1000: dist 0.19 loss 0.19
# step  865/1000: dist 0.19 loss 0.19
# step  866/1000: dist 0.19 loss 0.19
# step  867/1000: dist 0.19 loss 0.19
# step  868/1000: dist 0.19 loss 0.19
# step  869/1000: dist 0.19 loss 0.19
# step  870/1000: dist 0.19 loss 0.19
# step  871/1000: dist 0.19 loss 0.19
# step  872/1000: dist 0.19 loss 0.19
# step  873/1000: dist 0.19 loss 0.19
# step  874/1000: dist 0.19 loss 0.19
# step  875/1000: dist 0.19 loss 0.19
# step  876/1000: dist 0.19 loss 0.19
# step  877/1000: dist 0.19 loss 0.19
# step  878/1000: dist 0.19 loss 0.19
# step  879/1000: dist 0.19 loss 0.19
# step  880/1000: dist 0.19 loss 0.19
# step  881/1000: dist 0.19 loss 0.19
# step  882/1000: dist 0.19 loss 0.19
# step  883/1000: dist 0.19 loss 0.19
# step  884/1000: dist 0.19 loss 0.19
# step  885/1000: dist 0.19 loss 0.19
# step  886/1000: dist 0.19 loss 0.19
# step  887/1000: dist 0.19 loss 0.19
# step  888/1000: dist 0.19 loss 0.19
# step  889/1000: dist 0.19 loss 0.19
# step  890/1000: dist 0.19 loss 0.19
# step  891/1000: dist 0.19 loss 0.19
# step  892/1000: dist 0.19 loss 0.19
# step  893/1000: dist 0.19 loss 0.19
# step  894/1000: dist 0.19 loss 0.19
# step  895/1000: dist 0.19 loss 0.19
# step  896/1000: dist 0.19 loss 0.19
# step  897/1000: dist 0.19 loss 0.19
# step  898/1000: dist 0.19 loss 0.19
# step  899/1000: dist 0.19 loss 0.19
# step  900/1000: dist 0.19 loss 0.19
# step  901/1000: dist 0.19 loss 0.19
# step  902/1000: dist 0.19 loss 0.19
# step  903/1000: dist 0.19 loss 0.19
# step  904/1000: dist 0.19 loss 0.19
# step  905/1000: dist 0.19 loss 0.19
# step  906/1000: dist 0.19 loss 0.19
# step  907/1000: dist 0.19 loss 0.19
# step  908/1000: dist 0.19 loss 0.19
# step  909/1000: dist 0.19 loss 0.19
# step  910/1000: dist 0.19 loss 0.19
# step  911/1000: dist 0.19 loss 0.19
# step  912/1000: dist 0.19 loss 0.19
# step  913/1000: dist 0.19 loss 0.19
# step  914/1000: dist 0.19 loss 0.19
# step  915/1000: dist 0.19 loss 0.19
# step  916/1000: dist 0.19 loss 0.19
# step  917/1000: dist 0.19 loss 0.19
# step  918/1000: dist 0.19 loss 0.19
# step  919/1000: dist 0.19 loss 0.19
# step  920/1000: dist 0.19 loss 0.19
# step  921/1000: dist 0.19 loss 0.19
# step  922/1000: dist 0.19 loss 0.19
# step  923/1000: dist 0.19 loss 0.19
# step  924/1000: dist 0.19 loss 0.19
# step  925/1000: dist 0.19 loss 0.19
# step  926/1000: dist 0.19 loss 0.19
# step  927/1000: dist 0.19 loss 0.19
# step  928/1000: dist 0.19 loss 0.19
# step  929/1000: dist 0.19 loss 0.19
# step  930/1000: dist 0.19 loss 0.19
# step  931/1000: dist 0.19 loss 0.19
# step  932/1000: dist 0.19 loss 0.19
# step  933/1000: dist 0.19 loss 0.19
# step  934/1000: dist 0.19 loss 0.19
# step  935/1000: dist 0.19 loss 0.19
# step  936/1000: dist 0.19 loss 0.19
# step  937/1000: dist 0.19 loss 0.19
# step  938/1000: dist 0.19 loss 0.19
# step  939/1000: dist 0.19 loss 0.19
# step  940/1000: dist 0.19 loss 0.19
# step  941/1000: dist 0.19 loss 0.19
# step  942/1000: dist 0.19 loss 0.19
# step  943/1000: dist 0.19 loss 0.19
# step  944/1000: dist 0.19 loss 0.19
# step  945/1000: dist 0.19 loss 0.19
# step  946/1000: dist 0.19 loss 0.19
# step  947/1000: dist 0.19 loss 0.19
# step  948/1000: dist 0.19 loss 0.19
# step  949/1000: dist 0.19 loss 0.19
# step  950/1000: dist 0.19 loss 0.19
# step  951/1000: dist 0.19 loss 0.19
# step  952/1000: dist 0.19 loss 0.19
# step  953/1000: dist 0.19 loss 0.19
# step  954/1000: dist 0.19 loss 0.19
# step  955/1000: dist 0.19 loss 0.19
# step  956/1000: dist 0.19 loss 0.19
# step  957/1000: dist 0.19 loss 0.19
# step  958/1000: dist 0.19 loss 0.19
# step  959/1000: dist 0.19 loss 0.19
# step  960/1000: dist 0.19 loss 0.19
# step  961/1000: dist 0.19 loss 0.19
# step  962/1000: dist 0.19 loss 0.19
# step  963/1000: dist 0.19 loss 0.19
# step  964/1000: dist 0.19 loss 0.19
# step  965/1000: dist 0.19 loss 0.19
# step  966/1000: dist 0.19 loss 0.19
# step  967/1000: dist 0.19 loss 0.19
# step  968/1000: dist 0.19 loss 0.19
# step  969/1000: dist 0.19 loss 0.19
# step  970/1000: dist 0.19 loss 0.19
# step  971/1000: dist 0.19 loss 0.19
# step  972/1000: dist 0.19 loss 0.19
# step  973/1000: dist 0.19 loss 0.19
# step  974/1000: dist 0.19 loss 0.19
# step  975/1000: dist 0.19 loss 0.19
# step  976/1000: dist 0.19 loss 0.19
# step  977/1000: dist 0.19 loss 0.19
# step  978/1000: dist 0.19 loss 0.19
# step  979/1000: dist 0.19 loss 0.19
# step  980/1000: dist 0.19 loss 0.19
# step  981/1000: dist 0.19 loss 0.19
# step  982/1000: dist 0.19 loss 0.19
# step  983/1000: dist 0.19 loss 0.19
# step  984/1000: dist 0.19 loss 0.19
# step  985/1000: dist 0.19 loss 0.19
# step  986/1000: dist 0.19 loss 0.19
# step  987/1000: dist 0.19 loss 0.19
# step  988/1000: dist 0.19 loss 0.19
# step  989/1000: dist 0.19 loss 0.19
# step  990/1000: dist 0.19 loss 0.19
# step  991/1000: dist 0.19 loss 0.19
# step  992/1000: dist 0.19 loss 0.19
# step  993/1000: dist 0.19 loss 0.19
# step  994/1000: dist 0.19 loss 0.19
# step  995/1000: dist 0.19 loss 0.19
# step  996/1000: dist 0.19 loss 0.19
# step  997/1000: dist 0.19 loss 0.19
# step  998/1000: dist 0.19 loss 0.19
# step  999/1000: dist 0.19 loss 0.19
# step 1000/1000: dist 0.19 loss 0.19
# Elapsed: 78.2 s

# %% [markdown]
# With the conversion complete, lets have a look at the two GANs.

# %%
img_gan_source = cv2.imread('/content/out_source/proj.png')
img = cv2.cvtColor(img_gan_source, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('source-gan')
plt.show()

# %%
img_gan_target = cv2.imread('/content/out_target/proj.png')
img = cv2.cvtColor(img_gan_target, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('target-gan')
plt.show()

# %% [markdown]
# # Build the Video
#
# The following code builds a transition video between the two latent vectors previously obtained.

# %%
import math

def skipped_frames_by_step_num(step_num, steps, max_skip):
  power = ((3 * max_skip) / steps) * (step_num - (steps / 2))
  function = (4 * max_skip) * ((-1 * math.exp(power)) / ((1 + math.exp(power)) ** 2)) + max_skip
  
  return math.floor(function)

# %%
import torch
import dnnlib
import legacy
import PIL.Image
import numpy as np
import imageio
from tqdm.notebook import tqdm

lvec1 = np.load('/content/out_source/projected_w.npz')['w']
lvec2 = np.load('/content/out_target/projected_w.npz')['w']

network_pkl = "/content/stylegan2ada-weights/network-snapshot-004920.pkl"
device = torch.device('cuda')
with dnnlib.util.open_url(network_pkl) as fp:
    G = legacy.load_network_pkl(fp)['G_ema'].requires_grad_(False).to(device) # type: ignore

############
STEPS = 1000
SKIPPED_FRAME_CAP = 10
############

diff = lvec2 - lvec1
step = diff / STEPS
current = lvec1.copy()
target_uint8 = np.array([1024,1024,3], dtype=np.uint8)

video = imageio.get_writer('/content/movie.mp4', mode='I', fps=FPS, codec='libx264', bitrate='16M')

MID_SECTION = 200 # num steps to have in the mid section



for j in tqdm(range(STEPS)):
  z = torch.from_numpy(current).to(device)
  synth_image = G.synthesis(z, noise_mode='const')
  synth_image = (synth_image + 1) * (255/2)
  synth_image = synth_image.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

  repeat = FREEZE_STEPS if j==0 or j==(STEPS-1) else 1

  skip_frames = skipped_frames_by_step_num(j, STEPS, SKIPPED_FRAME_CAP)

  if (repeat == 1 and skip_frames > 0):
    if (j % skip_frames == 0):
      video.append_data(synth_image)
  else:
    for i in range(repeat):
      video.append_data(synth_image)
  
  current = current + step


video.close()
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# # Download your Video
#
# If you made it through all of these steps, you are now ready to download your video.

# %%
from google.colab import files
files.download("movie.mp4")

# %% [markdown]
# # Exploring Some Python Files

# %% [markdown]
# *First off, what is projector.py?*
#
# We know at a high-level, this basically takes an input image and the network model tries to find the best latent vector to represent it.
#
# ```py
# @click.option('--network', 'network_pkl', help='Network pickle filename', required=True)
# @click.option('--target', 'target_fname', help='Target image file to project to', required=True, metavar='FILE')
# @click.option('--num-steps',              help='Number of optimization steps', type=int, default=1000, show_default=True)
# @click.option('--seed',                   help='Random seed', type=int, default=303, show_default=True)
# @click.option('--save-video',             help='Save an mp4 video of optimization progress', type=bool, default=True, show_default=True)
# @click.option('--outdir',                 help='Where to save the output images', required=True, metavar='DIR')
# ```
#
# Well, that about sums up the parameters! Looking through a bit of the code, it does, indeed, look like they are optimizing a latent vector.

# %% [markdown]
# Well, that's great. We understand this projector.py file on a high level and how to use it. *Now how does the "Build the Video" section work?*
#
# From a 2nd longer look, it looks like it's taking the difference between the 2 vectors and dividing it into intervals. Each interval mark is a new image. At each interval, the synthesis network will predict an image. These images are all put into an mp4.
