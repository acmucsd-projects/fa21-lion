# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/stylegan2-toys/blob/master/morph_video_real.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Jeff Heaton](https://raw.githubusercontent.com/jeffheaton/present/master/images/github.jpg)
#
# Copyright 2021 by [Jeff Heaton](https://www.youtube.com/channel/UCR1-GEpyOPzT2AO4D_eifdw), [released under Apache 2.0 license](https://github.com/jeffheaton/present/blob/master/LICENSE)
# # StyleGAN2 Morph Between Two REAL Images
#
# This notebook allows you to choose a starting and ending image and use StyleGAN2 to produce a "morph" video between the two pictures.  For the morph to work correctly, both images should be of human faces.  It helps if both pictures are cropped reasonably well to a square portrait to eliminate the possibility of two faces being present in one image.  The preprocessing code will lock in on the exact positioning of each image, so your crop does not have to be perfect. The main point of your crop is for you to remove anything else that might be confused for a face.  If multiple faces are detected, you will receive an error.
#
# Also, make sure you have selected a GPU Runtime from CoLab. Choose "Runtime," then "Change Runtime Type," and choose GPU for "Hardware Accelerator."
#
# The following YouTube video describes precisely how to run this notebook.
#
# [Morphing Real Images to Video with StyleGAN2 ADA](http://youtube.com)
#
# These settings allow you to change the high-level configuration.  The number of steps determines how long your resulting video is.  The video plays at 30 frames a second, so 150 is 5 seconds. You can also specify freeze steps to leave the video unchanged at the beginning and end. You will not likely need to change the network.

# %%
STEPS = 150
FPS = 30
FREEZE_STEPS = 30

# %%
# Let's get the tick-4920 trained StyleGAN2-ADA.

from google.colab import files
files.upload()  # Upload your kaggle.json here.

# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# Kaggle datasets here.

# Trained tick-4920.
# !mkdir stylegan2ada-weights
# %cd stylegan2ada-weights/
# !kaggle datasets download -d edwardyangiscool/stylegan-weights
# !unzip -q stylegan-weights.zip
# !rm stylegan-weights.zip
# %cd ../
# Out:
#      <input type="file" id="files-d708b451-c11f-466a-b657-e2d30017eac0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d708b451-c11f-466a-b657-e2d30017eac0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# /content/stylegan2ada-weights
# Downloading stylegan-weights.zip to /content/stylegan2ada-weights
#  93% 233M/251M [00:02<00:00, 68.1MB/s]
# 100% 251M/251M [00:02<00:00, 94.8MB/s]
# /content

# %%
NETWORK = r"/content/stylegan2ada-weights/network-snapshot-004920.pkl"

# %% [markdown]
# # Upload Starting Image
#
# Choose your starting image.

# %%
import os
from google.colab import files

uploaded = files.upload()

if len(uploaded) != 1:
  print("Upload exactly 1 file for source.")
else:
  for k, v in uploaded.items():
    _, ext = os.path.splitext(k)
    os.remove(k)
    SOURCE_NAME = f"source{ext}"
    open(SOURCE_NAME, 'wb').write(v)
# Out:
#      <input type="file" id="files-c8794b36-a6f9-4fc6-bb02-5a8ea2da07cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8794b36-a6f9-4fc6-bb02-5a8ea2da07cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving human_aligned.jpg to human_aligned.jpg

# %% [markdown]
# Also, choose your ending image.

# %%
uploaded = files.upload()

if len(uploaded) != 1:
  print("Upload exactly 1 file for target.")
else:
  for k, v in uploaded.items():
    _, ext = os.path.splitext(k)
    os.remove(k)
    TARGET_NAME = f"target{ext}"
    open(TARGET_NAME, 'wb').write(v)
# Out:
#      <input type="file" id="files-88ce2d29-3a8d-4c55-a8bc-1fc8003b45ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88ce2d29-3a8d-4c55-a8bc-1fc8003b45ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat_best_LL.jpg to cat_best_LL.jpg

# %% [markdown]
# # Install Software
#
# Some software must be installed into Colab, for this notebook to work. We are specificially using these technologies:
#
# * [Training Generative Adversarial Networks with Limited Data](https://arxiv.org/abs/2006.06676)
# Tero Karras, Miika Aittala, Janne Hellsten, Samuli Laine, Jaakko Lehtinen, Timo Aila
# * [One millisecond face alignment with an ensemble of regression trees](https://www.cv-foundation.org/openaccess/content_cvpr_2014/papers/Kazemi_One_Millisecond_Face_2014_CVPR_paper.pdf) Vahid Kazemi, Josephine Sullivan

# %%
# !wget http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# !bzip2 -d shape_predictor_5_face_landmarks.dat.bz2
# Out:
# --2022-01-04 21:59:31--  http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5706710 (5.4M)
# Saving to: ‘shape_predictor_5_face_landmarks.dat.bz2’
#
# shape_predictor_5_f 100%[===================>]   5.44M  6.20MB/s    in 0.9s
#
# 2022-01-04 21:59:32 (6.20 MB/s) - ‘shape_predictor_5_face_landmarks.dat.bz2’ saved [5706710/5706710]

# %%
import sys
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# !pip install ninja
sys.path.insert(0, "/content/stylegan2-ada-pytorch")
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 128, done.
# remote: Total 128 (delta 0), reused 0 (delta 0), pack-reused 128
# Receiving objects: 100% (128/128), 1.12 MiB | 16.63 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# Collecting ninja
#   Downloading ninja-1.10.2.3-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (108 kB)
#      |████████████████████████████████| 108 kB 8.8 MB/s
# Installing collected packages: ninja
# Successfully installed ninja-1.10.2.3

# %% [markdown]
# # Preprocess Images for Best StyleGAN Results
#
# The following are helper functions for the preprocessing.

# %%
import cv2
import numpy as np
from PIL import Image
import dlib

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_5_face_landmarks.dat')

def find_eyes(img):
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  rects = detector(gray, 0)
  
  if len(rects) == 0:
    raise ValueError("No faces detected")
  elif len(rects) > 1:
    raise ValueError("Multiple faces detected")

  shape = predictor(gray, rects[0])
  features = []

  for i in range(0, 5):
    features.append((i, (shape.part(i).x, shape.part(i).y)))

  return (int(features[3][1][0] + features[2][1][0]) // 2, \
    int(features[3][1][1] + features[2][1][1]) // 2), \
    (int(features[1][1][0] + features[0][1][0]) // 2, \
    int(features[1][1][1] + features[0][1][1]) // 2)

def crop_stylegan(img):
  left_eye, right_eye = find_eyes(img)
  d = abs(right_eye[0] - left_eye[0])
  z = 255/d
  ar = img.shape[0]/img.shape[1]
  w = img.shape[1] * z
  img2 = cv2.resize(img, (int(w), int(w*ar)))
  bordersize = 1024
  img3 = cv2.copyMakeBorder(
      img2,
      top=bordersize,
      bottom=bordersize,
      left=bordersize,
      right=bordersize,
      borderType=cv2.BORDER_REPLICATE)

  left_eye2, right_eye2 = find_eyes(img3)

  crop1 = left_eye2[0] - 385 
  crop0 = left_eye2[1] - 490
  return img3[crop0:crop0+1024,crop1:crop1+1024]

# %% [markdown]
# The following will preprocess and crop your images.  If you receive an error indicating multiple faces were found, try to crop your image better or obscure the background.  If the program does not see a face, then attempt to obtain a clearer and more high-resolution image.

# %%
print(SOURCE_NAME, TARGET_NAME)
# Out:
# source.jpg target.jpg

# %%
from matplotlib import pyplot as plt
import cv2

image_source = cv2.imread(SOURCE_NAME)
if image_source is None:
    raise ValueError("Source image not found")

image_target = cv2.imread(TARGET_NAME)
if image_target is None:
    raise ValueError("Source image not found")


cropped_source = crop_stylegan(image_source)
# cropped_target = crop_stylegan(image_target)
cropped_target = image_target

img = cv2.cvtColor(cropped_source, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('source')
plt.show()

img = cv2.cvtColor(cropped_target, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('target')
plt.show()

cv2.imwrite("cropped_source.png", cropped_source)
cv2.imwrite("cropped_target.png", cropped_target)

#print(find_eyes(cropped_source))
#print(find_eyes(cropped_target))
# Out:
# True

# %%
# Avoid the aligning from the above face detector.
# We can do manual aligning and center cropping, but I think the cat image is already
# pretty centered, so I simply resized. If you find fault with
# your cat image, add some preprocessing here!

img = Image.open('cropped_target.png')
img = img.resize((1024, 1024))
img.save('cropped_target.png')

# %% [markdown]
# # Convert Source to a GAN
#
# First, we convert the source to a GAN latent vector.  This process will take several minutes.

# %%
cmd = f"python /content/stylegan2-ada-pytorch/projector.py --save-video 0 --num-steps 1000 --outdir=out_source --target=cropped_source.png --network={NETWORK}"
# !{cmd}
# Out:
# Loading networks from "/content/stylegan2ada-weights/network-snapshot-004920.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Downloading https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/metrics/vgg16.pt ... done
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/1000: dist 0.74 loss 24566.09
# step    2/1000: dist 0.62 loss 27639.33
# step    3/1000: dist 0.75 loss 27166.58
# step    4/1000: dist 0.73 loss 26250.55
# step    5/1000: dist 0.57 loss 24954.50
# step    6/1000: dist 0.64 loss 23352.45
# step    7/1000: dist 0.67 loss 21509.99
# step    8/1000: dist 0.72 loss 19484.49
# step    9/1000: dist 0.56 loss 17337.03
# step   10/1000: dist 0.61 loss 15137.46
# step   11/1000: dist 0.61 loss 12947.20
# step   12/1000: dist 0.58 loss 10817.22
# step   13/1000: dist 0.57 loss 8799.28
# step   14/1000: dist 0.60 loss 6944.97
# step   15/1000: dist 0.65 loss 5313.11
# step   16/1000: dist 0.66 loss 3968.45
# step   17/1000: dist 0.61 loss 2940.11
# step   18/1000: dist 0.56 loss 2212.78
# step   19/1000: dist 0.56 loss 1756.66
# step   20/1000: dist 0.58 loss 1564.56
# step   21/1000: dist 0.57 loss 1599.44
# step   22/1000: dist 0.57 loss 1785.74
# step   23/1000: dist 0.56 loss 2050.04
# step   24/1000: dist 0.55 loss 2324.71
# step   25/1000: dist 0.56 loss 2535.36
# step   26/1000: dist 0.57 loss 2633.78
# step   27/1000: dist 0.57 loss 2599.88
# step   28/1000: dist 0.57 loss 2473.20
# step   29/1000: dist 0.59 loss 2312.35
# step   30/1000: dist 0.56 loss 2116.74
# step   31/1000: dist 0.59 loss 1878.00
# step   32/1000: dist 0.57 loss 1620.42
# step   33/1000: dist 0.54 loss 1381.55
# step   34/1000: dist 0.58 loss 1178.91
# step   35/1000: dist 0.57 loss 1020.08
# step   36/1000: dist 0.55 loss 901.40
# step   37/1000: dist 0.58 loss 822.08
# step   38/1000: dist 0.55 loss 799.23
# step   39/1000: dist 0.56 loss 804.55
# step   40/1000: dist 0.59 loss 823.12
# step   41/1000: dist 0.56 loss 819.78
# step   42/1000: dist 0.53 loss 754.12
# step   43/1000: dist 0.54 loss 643.00
# step   44/1000: dist 0.54 loss 514.39
# step   45/1000: dist 0.53 loss 396.36
# step   46/1000: dist 0.55 loss 310.09
# step   47/1000: dist 0.56 loss 255.44
# step   48/1000: dist 0.55 loss 235.73
# step   49/1000: dist 0.54 loss 246.77
# step   50/1000: dist 0.56 loss 297.32
# step   51/1000: dist 0.55 loss 358.83
# step   52/1000: dist 0.56 loss 385.03
# step   53/1000: dist 0.58 loss 371.47
# step   54/1000: dist 0.53 loss 331.77
# step   55/1000: dist 0.54 loss 265.46
# step   56/1000: dist 0.51 loss 185.53
# step   57/1000: dist 0.52 loss 114.13
# step   58/1000: dist 0.50 loss 66.39
# step   59/1000: dist 0.50 loss 46.67
# step   60/1000: dist 0.54 loss 42.11
# step   61/1000: dist 0.53 loss 53.86
# step   62/1000: dist 0.52 loss 78.83
# step   63/1000: dist 0.54 loss 103.97
# step   64/1000: dist 0.50 loss 120.09
# step   65/1000: dist 0.53 loss 123.75
# step   66/1000: dist 0.51 loss 112.96
# step   67/1000: dist 0.53 loss 94.30
# step   68/1000: dist 0.51 loss 67.73
# step   69/1000: dist 0.55 loss 42.92
# step   70/1000: dist 0.53 loss 25.23
# step   71/1000: dist 0.52 loss 14.93
# step   72/1000: dist 0.52 loss 13.11
# step   73/1000: dist 0.52 loss 18.09
# step   74/1000: dist 0.53 loss 23.72
# step   75/1000: dist 0.49 loss 29.82
# step   76/1000: dist 0.51 loss 32.99
# step   77/1000: dist 0.50 loss 31.66
# step   78/1000: dist 0.50 loss 28.72
# step   79/1000: dist 0.49 loss 27.14
# step   80/1000: dist 0.50 loss 25.58
# step   81/1000: dist 0.54 loss 20.55
# step   82/1000: dist 0.50 loss 12.50
# step   83/1000: dist 0.50 loss 9.81
# step   84/1000: dist 0.49 loss 13.27
# step   85/1000: dist 0.50 loss 14.25
# step   86/1000: dist 0.49 loss 10.98
# step   87/1000: dist 0.49 loss 10.11
# step   88/1000: dist 0.52 loss 10.67
# step   89/1000: dist 0.55 loss 8.80
# step   90/1000: dist 0.56 loss 6.42
# step   91/1000: dist 0.49 loss 5.64
# step   92/1000: dist 0.50 loss 5.60
# step   93/1000: dist 0.48 loss 6.06
# step   94/1000: dist 0.51 loss 8.00
# step   95/1000: dist 0.49 loss 10.11
# step   96/1000: dist 0.49 loss 11.20
# step   97/1000: dist 0.49 loss 10.22
# step   98/1000: dist 0.49 loss 6.79
# step   99/1000: dist 0.48 loss 3.37
# step  100/1000: dist 0.48 loss 2.70
# step  101/1000: dist 0.49 loss 4.05
# step  102/1000: dist 0.49 loss 4.27
# step  103/1000: dist 0.51 loss 2.69
# step  104/1000: dist 0.53 loss 2.02
# step  105/1000: dist 0.51 loss 3.37
# step  106/1000: dist 0.50 loss 4.81
# step  107/1000: dist 0.49 loss 5.03
# step  108/1000: dist 0.51 loss 4.98
# step  109/1000: dist 0.49 loss 4.92
# step  110/1000: dist 0.51 loss 3.94
# step  111/1000: dist 0.50 loss 2.50
# step  112/1000: dist 0.50 loss 2.26
# step  113/1000: dist 0.48 loss 3.05
# step  114/1000: dist 0.49 loss 3.43
# step  115/1000: dist 0.52 loss 3.12
# step  116/1000: dist 0.49 loss 3.21
# step  117/1000: dist 0.50 loss 3.97
# step  118/1000: dist 0.52 loss 4.10
# step  119/1000: dist 0.52 loss 3.12
# step  120/1000: dist 0.48 loss 2.06
# step  121/1000: dist 0.49 loss 1.74
# step  122/1000: dist 0.51 loss 1.64
# step  123/1000: dist 0.49 loss 1.33
# step  124/1000: dist 0.48 loss 1.37
# step  125/1000: dist 0.46 loss 1.94
# step  126/1000: dist 0.49 loss 2.36
# step  127/1000: dist 0.49 loss 1.94
# step  128/1000: dist 0.48 loss 1.11
# step  129/1000: dist 0.47 loss 0.72
# step  130/1000: dist 0.47 loss 0.89
# step  131/1000: dist 0.48 loss 1.16
# step  132/1000: dist 0.48 loss 1.27
# step  133/1000: dist 0.49 loss 1.33
# step  134/1000: dist 0.49 loss 1.36
# step  135/1000: dist 0.48 loss 1.26
# step  136/1000: dist 0.47 loss 1.01
# step  137/1000: dist 0.48 loss 0.79
# step  138/1000: dist 0.48 loss 0.76
# step  139/1000: dist 0.50 loss 0.92
# step  140/1000: dist 0.48 loss 1.09
# step  141/1000: dist 0.48 loss 1.32
# step  142/1000: dist 0.50 loss 1.71
# step  143/1000: dist 0.48 loss 2.45
# step  144/1000: dist 0.54 loss 3.85
# step  145/1000: dist 0.51 loss 5.84
# step  146/1000: dist 0.51 loss 8.16
# step  147/1000: dist 0.49 loss 9.18
# step  148/1000: dist 0.48 loss 7.05
# step  149/1000: dist 0.46 loss 2.95
# step  150/1000: dist 0.46 loss 1.28
# step  151/1000: dist 0.47 loss 3.57
# step  152/1000: dist 0.51 loss 6.68
# step  153/1000: dist 0.48 loss 7.58
# step  154/1000: dist 0.47 loss 8.35
# step  155/1000: dist 0.49 loss 13.58
# step  156/1000: dist 0.48 loss 22.25
# step  157/1000: dist 0.47 loss 24.56
# step  158/1000: dist 0.49 loss 13.34
# step  159/1000: dist 0.47 loss 2.07
# step  160/1000: dist 0.47 loss 6.59
# step  161/1000: dist 0.46 loss 15.85
# step  162/1000: dist 0.48 loss 14.42
# step  163/1000: dist 0.46 loss 11.37
# step  164/1000: dist 0.48 loss 16.14
# step  165/1000: dist 0.49 loss 16.54
# step  166/1000: dist 0.46 loss 9.67
# step  167/1000: dist 0.45 loss 9.56
# step  168/1000: dist 0.50 loss 13.23
# step  169/1000: dist 0.48 loss 9.82
# step  170/1000: dist 0.45 loss 5.09
# step  171/1000: dist 0.45 loss 4.71
# step  172/1000: dist 0.48 loss 5.52
# step  173/1000: dist 0.47 loss 7.03
# step  174/1000: dist 0.48 loss 7.17
# step  175/1000: dist 0.47 loss 3.15
# step  176/1000: dist 0.49 loss 1.62
# step  177/1000: dist 0.47 loss 4.93
# step  178/1000: dist 0.46 loss 5.36
# step  179/1000: dist 0.47 loss 2.40
# step  180/1000: dist 0.45 loss 1.99
# step  181/1000: dist 0.45 loss 3.12
# step  182/1000: dist 0.47 loss 3.01
# step  183/1000: dist 0.46 loss 2.93
# step  184/1000: dist 0.46 loss 3.19
# step  185/1000: dist 0.47 loss 3.73
# step  186/1000: dist 0.47 loss 5.96
# step  187/1000: dist 0.46 loss 10.09
# step  188/1000: dist 0.46 loss 15.64
# step  189/1000: dist 0.47 loss 21.02
# step  190/1000: dist 0.49 loss 20.35
# step  191/1000: dist 0.47 loss 13.94
# step  192/1000: dist 0.50 loss 12.05
# step  193/1000: dist 0.47 loss 17.00
# step  194/1000: dist 0.48 loss 18.02
# step  195/1000: dist 0.48 loss 10.21
# step  196/1000: dist 0.46 loss 4.52
# step  197/1000: dist 0.46 loss 7.06
# step  198/1000: dist 0.46 loss 9.70
# step  199/1000: dist 0.46 loss 7.60
# step  200/1000: dist 0.46 loss 5.45
# step  201/1000: dist 0.46 loss 5.31
# step  202/1000: dist 0.46 loss 4.57
# step  203/1000: dist 0.45 loss 4.05
# step  204/1000: dist 0.47 loss 4.91
# step  205/1000: dist 0.45 loss 4.40
# step  206/1000: dist 0.48 loss 2.68
# step  207/1000: dist 0.47 loss 2.76
# step  208/1000: dist 0.45 loss 3.53
# step  209/1000: dist 0.46 loss 2.68
# step  210/1000: dist 0.44 loss 1.97
# step  211/1000: dist 0.45 loss 2.55
# step  212/1000: dist 0.44 loss 2.37
# step  213/1000: dist 0.45 loss 1.52
# step  214/1000: dist 0.46 loss 1.72
# step  215/1000: dist 0.46 loss 2.08
# step  216/1000: dist 0.47 loss 1.48
# step  217/1000: dist 0.45 loss 1.14
# step  218/1000: dist 0.47 loss 1.59
# step  219/1000: dist 0.45 loss 1.45
# step  220/1000: dist 0.47 loss 0.93
# step  221/1000: dist 0.45 loss 1.08
# step  222/1000: dist 0.46 loss 1.43
# step  223/1000: dist 0.44 loss 1.07
# step  224/1000: dist 0.46 loss 0.68
# step  225/1000: dist 0.45 loss 0.83
# step  226/1000: dist 0.45 loss 1.02
# step  227/1000: dist 0.44 loss 0.87
# step  228/1000: dist 0.45 loss 0.75
# step  229/1000: dist 0.45 loss 0.79
# step  230/1000: dist 0.45 loss 0.75
# step  231/1000: dist 0.45 loss 0.69
# step  232/1000: dist 0.45 loss 0.72
# step  233/1000: dist 0.45 loss 0.73
# step  234/1000: dist 0.45 loss 0.66
# step  235/1000: dist 0.45 loss 0.65
# step  236/1000: dist 0.45 loss 0.72
# step  237/1000: dist 0.46 loss 0.72
# step  238/1000: dist 0.45 loss 0.64
# step  239/1000: dist 0.44 loss 0.65
# step  240/1000: dist 0.44 loss 0.73
# step  241/1000: dist 0.44 loss 0.79
# step  242/1000: dist 0.45 loss 0.89
# step  243/1000: dist 0.48 loss 1.14
# step  244/1000: dist 0.45 loss 1.48
# step  245/1000: dist 0.44 loss 1.98
# step  246/1000: dist 0.43 loss 2.74
# step  247/1000: dist 0.44 loss 3.88
# step  248/1000: dist 0.44 loss 5.26
# step  249/1000: dist 0.44 loss 6.33
# step  250/1000: dist 0.44 loss 6.25
# step  251/1000: dist 0.44 loss 4.57
# step  252/1000: dist 0.45 loss 2.12
# step  253/1000: dist 0.45 loss 0.58
# step  254/1000: dist 0.44 loss 0.86
# step  255/1000: dist 0.45 loss 2.24
# step  256/1000: dist 0.46 loss 3.17
# step  257/1000: dist 0.44 loss 2.71
# step  258/1000: dist 0.45 loss 1.38
# step  259/1000: dist 0.44 loss 0.52
# step  260/1000: dist 0.46 loss 0.82
# step  261/1000: dist 0.43 loss 1.61
# step  262/1000: dist 0.45 loss 2.00
# step  263/1000: dist 0.45 loss 1.60
# step  264/1000: dist 0.45 loss 1.01
# step  265/1000: dist 0.44 loss 1.03
# step  266/1000: dist 0.45 loss 1.89
# step  267/1000: dist 0.45 loss 3.36
# step  268/1000: dist 0.43 loss 5.48
# step  269/1000: dist 0.45 loss 9.17
# step  270/1000: dist 0.43 loss 14.97
# step  271/1000: dist 0.44 loss 21.09
# step  272/1000: dist 0.44 loss 21.67
# step  273/1000: dist 0.43 loss 16.03
# step  274/1000: dist 0.43 loss 13.09
# step  275/1000: dist 0.43 loss 16.38
# step  276/1000: dist 0.44 loss 16.71
# step  277/1000: dist 0.45 loss 10.96
# step  278/1000: dist 0.44 loss 10.77
# step  279/1000: dist 0.44 loss 21.61
# step  280/1000: dist 0.43 loss 27.82
# step  281/1000: dist 0.44 loss 17.37
# step  282/1000: dist 0.43 loss 5.95
# step  283/1000: dist 0.44 loss 11.59
# step  284/1000: dist 0.47 loss 25.60
# step  285/1000: dist 0.43 loss 32.15
# step  286/1000: dist 0.43 loss 27.27
# step  287/1000: dist 0.44 loss 14.87
# step  288/1000: dist 0.43 loss 7.53
# step  289/1000: dist 0.44 loss 12.98
# step  290/1000: dist 0.43 loss 17.67
# step  291/1000: dist 0.43 loss 11.28
# step  292/1000: dist 0.43 loss 8.01
# step  293/1000: dist 0.43 loss 15.24
# step  294/1000: dist 0.44 loss 16.50
# step  295/1000: dist 0.43 loss 9.79
# step  296/1000: dist 0.43 loss 9.34
# step  297/1000: dist 0.43 loss 9.88
# step  298/1000: dist 0.43 loss 3.61
# step  299/1000: dist 0.42 loss 3.03
# step  300/1000: dist 0.45 loss 9.13
# step  301/1000: dist 0.42 loss 7.33
# step  302/1000: dist 0.43 loss 2.25
# step  303/1000: dist 0.42 loss 3.80
# step  304/1000: dist 0.42 loss 4.68
# step  305/1000: dist 0.43 loss 2.60
# step  306/1000: dist 0.43 loss 3.78
# step  307/1000: dist 0.42 loss 4.26
# step  308/1000: dist 0.43 loss 1.48
# step  309/1000: dist 0.44 loss 1.74
# step  310/1000: dist 0.43 loss 3.77
# step  311/1000: dist 0.43 loss 2.92
# step  312/1000: dist 0.43 loss 2.36
# step  313/1000: dist 0.43 loss 3.89
# step  314/1000: dist 0.42 loss 5.44
# step  315/1000: dist 0.42 loss 8.37
# step  316/1000: dist 0.42 loss 13.32
# step  317/1000: dist 0.42 loss 16.79
# step  318/1000: dist 0.43 loss 16.06
# step  319/1000: dist 0.43 loss 11.42
# step  320/1000: dist 0.44 loss 7.31
# step  321/1000: dist 0.43 loss 8.23
# step  322/1000: dist 0.46 loss 11.16
# step  323/1000: dist 0.44 loss 9.49
# step  324/1000: dist 0.44 loss 5.74
# step  325/1000: dist 0.43 loss 8.36
# step  326/1000: dist 0.44 loss 15.16
# step  327/1000: dist 0.43 loss 14.27
# step  328/1000: dist 0.43 loss 5.00
# step  329/1000: dist 0.43 loss 1.01
# step  330/1000: dist 0.43 loss 6.20
# step  331/1000: dist 0.43 loss 9.28
# step  332/1000: dist 0.43 loss 4.80
# step  333/1000: dist 0.43 loss 1.34
# step  334/1000: dist 0.43 loss 3.83
# step  335/1000: dist 0.44 loss 5.51
# step  336/1000: dist 0.44 loss 3.05
# step  337/1000: dist 0.43 loss 1.89
# step  338/1000: dist 0.42 loss 3.53
# step  339/1000: dist 0.42 loss 3.65
# step  340/1000: dist 0.42 loss 2.54
# step  341/1000: dist 0.43 loss 3.97
# step  342/1000: dist 0.42 loss 6.84
# step  343/1000: dist 0.42 loss 9.01
# step  344/1000: dist 0.42 loss 12.70
# step  345/1000: dist 0.42 loss 18.35
# step  346/1000: dist 0.42 loss 19.28
# step  347/1000: dist 0.42 loss 12.44
# step  348/1000: dist 0.41 loss 5.97
# step  349/1000: dist 0.41 loss 9.09
# step  350/1000: dist 0.42 loss 17.30
# step  351/1000: dist 0.41 loss 19.12
# step  352/1000: dist 0.41 loss 14.31
# step  353/1000: dist 0.41 loss 15.00
# step  354/1000: dist 0.42 loss 21.20
# step  355/1000: dist 0.42 loss 18.41
# step  356/1000: dist 0.41 loss 6.60
# step  357/1000: dist 0.41 loss 2.97
# step  358/1000: dist 0.42 loss 9.63
# step  359/1000: dist 0.41 loss 11.53
# step  360/1000: dist 0.41 loss 5.56
# step  361/1000: dist 0.42 loss 2.73
# step  362/1000: dist 0.42 loss 5.53
# step  363/1000: dist 0.42 loss 6.57
# step  364/1000: dist 0.41 loss 4.26
# step  365/1000: dist 0.41 loss 2.80
# step  366/1000: dist 0.43 loss 3.24
# step  367/1000: dist 0.42 loss 3.69
# step  368/1000: dist 0.41 loss 3.38
# step  369/1000: dist 0.42 loss 2.77
# step  370/1000: dist 0.41 loss 2.82
# step  371/1000: dist 0.40 loss 3.79
# step  372/1000: dist 0.42 loss 4.89
# step  373/1000: dist 0.41 loss 6.74
# step  374/1000: dist 0.42 loss 11.20
# step  375/1000: dist 0.41 loss 16.88
# step  376/1000: dist 0.41 loss 19.17
# step  377/1000: dist 0.41 loss 13.79
# step  378/1000: dist 0.41 loss 4.80
# step  379/1000: dist 0.41 loss 1.64
# step  380/1000: dist 0.42 loss 6.21
# step  381/1000: dist 0.41 loss 9.63
# step  382/1000: dist 0.40 loss 5.54
# step  383/1000: dist 0.41 loss 1.00
# step  384/1000: dist 0.42 loss 3.29
# step  385/1000: dist 0.41 loss 6.17
# step  386/1000: dist 0.41 loss 3.34
# step  387/1000: dist 0.41 loss 0.73
# step  388/1000: dist 0.40 loss 2.99
# step  389/1000: dist 0.40 loss 4.06
# step  390/1000: dist 0.41 loss 1.42
# step  391/1000: dist 0.41 loss 0.95
# step  392/1000: dist 0.41 loss 2.89
# step  393/1000: dist 0.40 loss 2.34
# step  394/1000: dist 0.41 loss 0.95
# step  395/1000: dist 0.40 loss 2.12
# step  396/1000: dist 0.40 loss 3.43
# step  397/1000: dist 0.40 loss 3.61
# step  398/1000: dist 0.40 loss 5.98
# step  399/1000: dist 0.39 loss 11.16
# step  400/1000: dist 0.40 loss 16.51
# step  401/1000: dist 0.41 loss 19.45
# step  402/1000: dist 0.41 loss 15.96
# step  403/1000: dist 0.40 loss 6.06
# step  404/1000: dist 0.40 loss 0.58
# step  405/1000: dist 0.40 loss 5.22
# step  406/1000: dist 0.40 loss 10.45
# step  407/1000: dist 0.40 loss 7.05
# step  408/1000: dist 0.40 loss 1.09
# step  409/1000: dist 0.41 loss 2.29
# step  410/1000: dist 0.40 loss 6.32
# step  411/1000: dist 0.41 loss 4.88
# step  412/1000: dist 0.41 loss 1.16
# step  413/1000: dist 0.39 loss 2.02
# step  414/1000: dist 0.40 loss 4.67
# step  415/1000: dist 0.40 loss 3.77
# step  416/1000: dist 0.40 loss 2.26
# step  417/1000: dist 0.40 loss 4.50
# step  418/1000: dist 0.41 loss 7.85
# step  419/1000: dist 0.41 loss 9.40
# step  420/1000: dist 0.40 loss 11.34
# step  421/1000: dist 0.39 loss 13.15
# step  422/1000: dist 0.40 loss 10.20
# step  423/1000: dist 0.40 loss 3.46
# step  424/1000: dist 0.41 loss 0.65
# step  425/1000: dist 0.40 loss 3.61
# step  426/1000: dist 0.40 loss 6.45
# step  427/1000: dist 0.39 loss 5.21
# step  428/1000: dist 0.40 loss 2.18
# step  498/1000: dist 0.39 loss 4.57
# step  499/1000: dist 0.38 loss 8.69
# step  500/1000: dist 0.38 loss 15.31
# step  501/1000: dist 0.38 loss 23.64
# step  502/1000: dist 0.38 loss 29.86
# step  503/1000: dist 0.39 loss 28.21
# step  504/1000: dist 0.39 loss 23.85
# step  505/1000: dist 0.38 loss 25.71
# step  506/1000: dist 0.38 loss 26.50
# step  507/1000: dist 0.38 loss 15.90
# step  508/1000: dist 0.38 loss 4.92
# step  509/1000: dist 0.38 loss 8.76
# step  510/1000: dist 0.38 loss 16.71
# step  511/1000: dist 0.38 loss 10.86
# step  512/1000: dist 0.38 loss 2.34
# step  513/1000: dist 0.38 loss 6.74
# step  514/1000: dist 0.38 loss 10.97
# step  515/1000: dist 0.38 loss 4.63
# step  516/1000: dist 0.38 loss 2.38
# step  517/1000: dist 0.38 loss 7.56
# step  518/1000: dist 0.38 loss 6.65
# step  519/1000: dist 0.38 loss 3.48
# step  520/1000: dist 0.38 loss 7.55
# step  521/1000: dist 0.38 loss 11.29
# step  522/1000: dist 0.38 loss 12.10
# step  523/1000: dist 0.38 loss 17.61
# step  524/1000: dist 0.38 loss 23.58
# step  525/1000: dist 0.38 loss 22.96
# step  526/1000: dist 0.38 loss 18.97
# step  527/1000: dist 0.38 loss 12.81
# step  528/1000: dist 0.37 loss 5.77
# step  529/1000: dist 0.38 loss 5.27
# step  530/1000: dist 0.38 loss 10.07
# step  531/1000: dist 0.37 loss 10.72
# step  532/1000: dist 0.38 loss 6.23
# step  533/1000: dist 0.38 loss 3.03
# step  534/1000: dist 0.37 loss 4.20
# step  535/1000: dist 0.38 loss 6.62
# step  536/1000: dist 0.37 loss 5.61
# step  537/1000: dist 0.37 loss 2.27
# step  538/1000: dist 0.38 loss 1.99
# step  539/1000: dist 0.38 loss 4.28
# step  540/1000: dist 0.38 loss 4.09
# step  541/1000: dist 0.37 loss 1.74
# step  542/1000: dist 0.38 loss 1.30
# step  543/1000: dist 0.38 loss 2.72
# step  544/1000: dist 0.38 loss 2.91
# step  545/1000: dist 0.37 loss 1.43
# step  546/1000: dist 0.37 loss 0.81
# step  547/1000: dist 0.37 loss 1.85
# step  548/1000: dist 0.38 loss 2.19
# step  549/1000: dist 0.38 loss 1.02
# step  550/1000: dist 0.37 loss 0.59
# step  551/1000: dist 0.37 loss 1.43
# step  552/1000: dist 0.37 loss 1.55
# step  553/1000: dist 0.37 loss 0.75
# step  554/1000: dist 0.37 loss 0.57
# step  555/1000: dist 0.37 loss 1.05
# step  556/1000: dist 0.37 loss 1.11
# step  557/1000: dist 0.37 loss 0.69
# step  558/1000: dist 0.37 loss 0.51
# step  559/1000: dist 0.37 loss 0.75
# step  560/1000: dist 0.37 loss 0.91
# step  561/1000: dist 0.37 loss 0.64
# step  562/1000: dist 0.37 loss 0.43
# step  563/1000: dist 0.38 loss 0.65
# step  564/1000: dist 0.37 loss 0.83
# step  565/1000: dist 0.37 loss 0.64
# step  566/1000: dist 0.38 loss 0.55
# step  567/1000: dist 0.37 loss 0.82
# step  568/1000: dist 0.37 loss 1.10
# step  569/1000: dist 0.37 loss 1.30
# step  570/1000: dist 0.37 loss 1.80
# step  571/1000: dist 0.37 loss 2.86
# step  572/1000: dist 0.37 loss 4.53
# step  573/1000: dist 0.37 loss 6.89
# step  574/1000: dist 0.37 loss 9.85
# step  575/1000: dist 0.37 loss 12.45
# step  576/1000: dist 0.37 loss 12.55
# step  577/1000: dist 0.36 loss 8.73
# step  578/1000: dist 0.37 loss 3.15
# step  579/1000: dist 0.37 loss 0.49
# step  580/1000: dist 0.37 loss 2.40
# step  581/1000: dist 0.36 loss 5.58
# step  582/1000: dist 0.37 loss 5.87
# step  583/1000: dist 0.38 loss 3.32
# step  584/1000: dist 0.37 loss 2.02
# step  585/1000: dist 0.37 loss 4.35
# step  586/1000: dist 0.37 loss 8.19
# step  587/1000: dist 0.37 loss 10.95
# step  588/1000: dist 0.37 loss 13.74
# step  589/1000: dist 0.37 loss 18.60
# step  590/1000: dist 0.37 loss 23.74
# step  591/1000: dist 0.37 loss 25.24
# step  592/1000: dist 0.36 loss 24.48
# step  593/1000: dist 0.36 loss 24.35
# step  594/1000: dist 0.36 loss 21.41
# step  595/1000: dist 0.37 loss 13.19
# step  596/1000: dist 0.36 loss 7.80
# step  597/1000: dist 0.36 loss 10.01
# step  598/1000: dist 0.37 loss 12.70
# step  599/1000: dist 0.37 loss 9.13
# step  600/1000: dist 0.36 loss 5.49
# step  601/1000: dist 0.37 loss 8.49
# step  602/1000: dist 0.37 loss 11.24
# step  603/1000: dist 0.36 loss 8.71
# step  604/1000: dist 0.36 loss 9.44
# step  605/1000: dist 0.36 loss 16.93
# step  606/1000: dist 0.36 loss 20.15
# step  607/1000: dist 0.36 loss 14.68
# step  608/1000: dist 0.36 loss 8.70
# step  609/1000: dist 0.37 loss 6.09
# step  610/1000: dist 0.37 loss 4.29
# step  611/1000: dist 0.36 loss 5.34
# step  612/1000: dist 0.37 loss 9.33
# step  613/1000: dist 0.37 loss 9.12
# step  614/1000: dist 0.36 loss 5.31
# step  615/1000: dist 0.36 loss 7.08
# step  616/1000: dist 0.37 loss 14.91
# step  617/1000: dist 0.36 loss 22.10
# step  618/1000: dist 0.36 loss 26.33
# step  619/1000: dist 0.36 loss 25.88
# step  620/1000: dist 0.36 loss 16.84
# step  621/1000: dist 0.36 loss 6.32
# step  622/1000: dist 0.36 loss 5.84
# step  623/1000: dist 0.36 loss 12.74
# step  624/1000: dist 0.36 loss 14.73
# step  625/1000: dist 0.37 loss 8.09
# step  626/1000: dist 0.36 loss 3.46
# step  627/1000: dist 0.36 loss 7.00
# step  628/1000: dist 0.36 loss 10.73
# step  629/1000: dist 0.36 loss 9.09
# step  630/1000: dist 0.36 loss 9.74
# step  631/1000: dist 0.36 loss 18.13
# step  632/1000: dist 0.36 loss 25.62
# step  633/1000: dist 0.36 loss 24.13
# step  634/1000: dist 0.36 loss 15.33
# step  635/1000: dist 0.36 loss 6.77
# step  636/1000: dist 0.36 loss 4.03
# step  637/1000: dist 0.36 loss 8.00
# step  638/1000: dist 0.36 loss 11.75
# step  639/1000: dist 0.36 loss 7.46
# step  640/1000: dist 0.36 loss 1.82
# step  641/1000: dist 0.36 loss 4.45
# step  642/1000: dist 0.36 loss 8.37
# step  643/1000: dist 0.36 loss 4.85
# step  644/1000: dist 0.36 loss 1.61
# step  645/1000: dist 0.36 loss 5.19
# step  646/1000: dist 0.36 loss 7.32
# step  647/1000: dist 0.36 loss 5.11
# step  648/1000: dist 0.36 loss 6.87
# step  649/1000: dist 0.36 loss 12.14
# step  650/1000: dist 0.36 loss 13.90
# step  651/1000: dist 0.36 loss 13.56
# step  652/1000: dist 0.36 loss 13.51
# step  653/1000: dist 0.36 loss 9.94
# step  654/1000: dist 0.36 loss 5.19
# step  655/1000: dist 0.36 loss 6.38
# step  656/1000: dist 0.35 loss 11.92
# step  657/1000: dist 0.36 loss 15.28
# step  658/1000: dist 0.36 loss 15.22
# step  659/1000: dist 0.36 loss 12.75
# step  660/1000: dist 0.36 loss 9.51
# step  661/1000: dist 0.36 loss 9.34
# step  662/1000: dist 0.36 loss 13.19
# step  663/1000: dist 0.35 loss 14.95
# step  664/1000: dist 0.36 loss 10.73
# step  665/1000: dist 0.36 loss 5.30
# step  666/1000: dist 0.35 loss 4.31
# step  667/1000: dist 0.36 loss 6.52
# step  668/1000: dist 0.36 loss 7.21
# step  669/1000: dist 0.36 loss 4.71
# step  670/1000: dist 0.36 loss 2.60
# step  671/1000: dist 0.36 loss 3.83
# step  672/1000: dist 0.36 loss 5.30
# step  673/1000: dist 0.36 loss 3.55
# step  674/1000: dist 0.35 loss 1.25
# step  675/1000: dist 0.36 loss 2.03
# step  676/1000: dist 0.35 loss 3.78
# step  677/1000: dist 0.36 loss 3.02
# step  678/1000: dist 0.36 loss 1.11
# step  679/1000: dist 0.35 loss 1.06
# step  680/1000: dist 0.36 loss 2.22
# step  681/1000: dist 0.35 loss 2.24
# step  682/1000: dist 0.36 loss 1.25
# step  683/1000: dist 0.36 loss 0.92
# step  684/1000: dist 0.35 loss 1.35
# step  685/1000: dist 0.36 loss 1.42
# step  686/1000: dist 0.35 loss 1.02
# step  687/1000: dist 0.35 loss 0.95
# step  688/1000: dist 0.35 loss 1.16
# step  689/1000: dist 0.35 loss 1.00
# step  690/1000: dist 0.35 loss 0.71
# step  691/1000: dist 0.35 loss 0.88
# step  692/1000: dist 0.35 loss 1.21
# step  693/1000: dist 0.35 loss 1.12
# step  694/1000: dist 0.36 loss 0.92
# step  695/1000: dist 0.36 loss 1.22
# step  696/1000: dist 0.35 loss 1.83
# step  697/1000: dist 0.35 loss 2.32
# step  698/1000: dist 0.35 loss 2.88
# step  699/1000: dist 0.35 loss 3.98
# step  700/1000: dist 0.36 loss 5.54
# step  701/1000: dist 0.35 loss 7.15
# step  702/1000: dist 0.35 loss 8.37
# step  703/1000: dist 0.36 loss 8.64
# step  980/1000: dist 0.34 loss 0.34
# step  981/1000: dist 0.34 loss 0.34
# step  982/1000: dist 0.34 loss 0.34
# step  983/1000: dist 0.34 loss 0.34
# step  984/1000: dist 0.34 loss 0.34
# step  985/1000: dist 0.34 loss 0.34
# step  986/1000: dist 0.34 loss 0.34
# step  987/1000: dist 0.34 loss 0.34
# step  988/1000: dist 0.34 loss 0.34
# step  989/1000: dist 0.34 loss 0.34
# step  990/1000: dist 0.34 loss 0.34
# step  991/1000: dist 0.34 loss 0.34
# step  992/1000: dist 0.34 loss 0.34
# step  993/1000: dist 0.34 loss 0.34
# step  994/1000: dist 0.34 loss 0.34
# step  995/1000: dist 0.34 loss 0.34
# step  996/1000: dist 0.34 loss 0.34
# step  997/1000: dist 0.34 loss 0.34
# step  998/1000: dist 0.34 loss 0.34
# step  999/1000: dist 0.34 loss 0.34
# step 1000/1000: dist 0.34 loss 0.34
# Elapsed: 93.8 s

# %% [markdown]
# # Convert Target to a GAN
#
# Next, we convert the target to a GAN latent vector.  This process will also take several minutes.

# %%
cmd = f"python /content/stylegan2-ada-pytorch/projector.py --save-video 0 --num-steps 1000 --outdir=out_target --target=cropped_target.png --network={NETWORK}"
# !{cmd}
# Out:
# Loading networks from "/content/stylegan2ada-weights/network-snapshot-004920.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/1000: dist 0.70 loss 24566.06
# step    2/1000: dist 0.79 loss 27639.51
# step    3/1000: dist 0.65 loss 27166.48
# step    4/1000: dist 0.65 loss 26250.47
# step    5/1000: dist 0.71 loss 24954.63
# step    6/1000: dist 0.65 loss 23352.45
# step    7/1000: dist 0.66 loss 21509.98
# step    8/1000: dist 0.63 loss 19484.40
# step    9/1000: dist 0.70 loss 17337.17
# step   10/1000: dist 0.57 loss 15137.42
# step   11/1000: dist 0.65 loss 12947.24
# step   12/1000: dist 0.73 loss 10817.37
# step   13/1000: dist 0.60 loss 8799.31
# step   14/1000: dist 0.61 loss 6944.99
# step   15/1000: dist 0.73 loss 5313.19
# step   16/1000: dist 0.67 loss 3968.46
# step   17/1000: dist 0.57 loss 2940.06
# step   18/1000: dist 0.59 loss 2212.81
# step   19/1000: dist 0.56 loss 1756.66
# step   20/1000: dist 0.60 loss 1564.58
# step   21/1000: dist 0.57 loss 1599.43
# step   22/1000: dist 0.51 loss 1785.69
# step   23/1000: dist 0.56 loss 2050.04
# step   24/1000: dist 0.55 loss 2324.70
# step   25/1000: dist 0.58 loss 2535.39
# step   26/1000: dist 0.57 loss 2633.79
# step   27/1000: dist 0.55 loss 2599.84
# step   28/1000: dist 0.60 loss 2473.22
# step   29/1000: dist 0.55 loss 2312.32
# step   30/1000: dist 0.55 loss 2116.72
# step   31/1000: dist 0.51 loss 1877.92
# step   32/1000: dist 0.55 loss 1620.40
# step   33/1000: dist 0.52 loss 1381.53
# step   34/1000: dist 0.54 loss 1178.87
# step   35/1000: dist 0.52 loss 1020.04
# step   36/1000: dist 0.56 loss 901.40
# step   37/1000: dist 0.56 loss 822.06
# step   38/1000: dist 0.56 loss 799.25
# step   39/1000: dist 0.55 loss 804.54
# step   40/1000: dist 0.53 loss 823.05
# step   41/1000: dist 0.55 loss 819.76
# step   42/1000: dist 0.50 loss 754.10
# step   43/1000: dist 0.53 loss 642.99
# step   44/1000: dist 0.51 loss 514.37
# step   45/1000: dist 0.52 loss 396.38
# step   46/1000: dist 0.49 loss 310.08
# step   47/1000: dist 0.51 loss 255.45
# step   48/1000: dist 0.50 loss 235.67
# step   49/1000: dist 0.52 loss 246.69
# step   50/1000: dist 0.50 loss 297.20
# step   51/1000: dist 0.51 loss 358.74
# step   52/1000: dist 0.52 loss 384.96
# step   53/1000: dist 0.52 loss 371.43
# step   54/1000: dist 0.48 loss 331.75
# step   55/1000: dist 0.50 loss 265.44
# step   56/1000: dist 0.49 loss 185.53
# step   57/1000: dist 0.48 loss 114.10
# step   58/1000: dist 0.50 loss 66.36
# step   59/1000: dist 0.50 loss 46.67
# step   60/1000: dist 0.47 loss 42.04
# step   61/1000: dist 0.46 loss 53.79
# step   62/1000: dist 0.50 loss 78.83
# step   63/1000: dist 0.49 loss 103.94
# step   64/1000: dist 0.49 loss 120.09
# step   65/1000: dist 0.50 loss 123.74
# step   66/1000: dist 0.50 loss 112.96
# step   67/1000: dist 0.50 loss 94.27
# step   68/1000: dist 0.49 loss 67.72
# step   69/1000: dist 0.47 loss 42.83
# step   70/1000: dist 0.49 loss 25.18
# step   71/1000: dist 0.47 loss 14.89
# step   72/1000: dist 0.45 loss 13.03
# step   73/1000: dist 0.45 loss 18.01
# step   74/1000: dist 0.45 loss 23.62
# step   75/1000: dist 0.45 loss 29.71
# step   76/1000: dist 0.46 loss 32.80
# step   77/1000: dist 0.45 loss 31.30
# step   78/1000: dist 0.50 loss 28.11
# step   79/1000: dist 0.45 loss 26.15
# step   80/1000: dist 0.44 loss 24.95
# step   81/1000: dist 0.47 loss 21.60
# step   82/1000: dist 0.49 loss 14.21
# step   83/1000: dist 0.46 loss 9.63
# step   84/1000: dist 0.44 loss 12.13
# step   85/1000: dist 0.45 loss 14.50
# step   86/1000: dist 0.44 loss 11.97
# step   87/1000: dist 0.46 loss 9.94
# step   88/1000: dist 0.48 loss 10.10
# step   89/1000: dist 0.43 loss 9.06
# step   90/1000: dist 0.48 loss 6.78
# step   91/1000: dist 0.43 loss 5.37
# step   92/1000: dist 0.45 loss 5.48
# step   93/1000: dist 0.46 loss 6.32
# step   94/1000: dist 0.45 loss 8.02
# step   95/1000: dist 0.47 loss 10.02
# step   96/1000: dist 0.42 loss 11.20
# step   97/1000: dist 0.43 loss 10.16
# step   98/1000: dist 0.45 loss 6.66
# step   99/1000: dist 0.44 loss 3.39
# step  100/1000: dist 0.43 loss 2.73
# step  101/1000: dist 0.42 loss 3.92
# step  102/1000: dist 0.43 loss 4.19
# step  172/1000: dist 0.39 loss 3.99
# step  173/1000: dist 0.39 loss 6.43
# step  174/1000: dist 0.41 loss 9.27
# step  175/1000: dist 0.42 loss 4.76
# step  176/1000: dist 0.42 loss 0.91
# step  177/1000: dist 0.39 loss 4.23
# step  178/1000: dist 0.39 loss 6.20
# step  179/1000: dist 0.39 loss 3.34
# step  180/1000: dist 0.38 loss 2.07
# step  181/1000: dist 0.40 loss 3.10
# step  182/1000: dist 0.39 loss 3.14
# step  183/1000: dist 0.38 loss 2.75
# step  184/1000: dist 0.38 loss 3.05
# step  185/1000: dist 0.40 loss 4.20
# step  186/1000: dist 0.39 loss 6.32
# step  187/1000: dist 0.39 loss 9.48
# step  188/1000: dist 0.43 loss 14.80
# step  189/1000: dist 0.38 loss 20.46
# step  190/1000: dist 0.39 loss 18.73
# step  191/1000: dist 0.40 loss 8.51
# step  192/1000: dist 0.41 loss 3.74
# step  193/1000: dist 0.41 loss 9.58
# step  194/1000: dist 0.38 loss 13.34
# step  195/1000: dist 0.38 loss 8.07
# step  196/1000: dist 0.37 loss 4.23
# step  197/1000: dist 0.40 loss 7.61
# step  198/1000: dist 0.37 loss 9.90
# step  199/1000: dist 0.38 loss 8.94
# step  200/1000: dist 0.40 loss 11.32
# step  201/1000: dist 0.37 loss 14.48
# step  202/1000: dist 0.37 loss 10.99
# step  203/1000: dist 0.37 loss 4.65
# step  204/1000: dist 0.39 loss 3.29
# step  205/1000: dist 0.38 loss 5.21
# step  206/1000: dist 0.42 loss 6.34
# step  207/1000: dist 0.40 loss 5.82
# step  208/1000: dist 0.38 loss 3.54
# step  209/1000: dist 0.38 loss 1.98
# step  210/1000: dist 0.39 loss 3.57
# step  211/1000: dist 0.38 loss 4.83
# step  212/1000: dist 0.38 loss 2.64
# step  213/1000: dist 0.38 loss 0.97
# step  214/1000: dist 0.38 loss 2.53
# step  215/1000: dist 0.36 loss 3.38
# step  216/1000: dist 0.38 loss 1.74
# step  217/1000: dist 0.40 loss 0.93
# step  218/1000: dist 0.39 loss 1.89
# step  219/1000: dist 0.37 loss 2.22
# step  220/1000: dist 0.37 loss 1.47
# step  221/1000: dist 0.39 loss 1.01
# step  222/1000: dist 0.38 loss 1.14
# step  223/1000: dist 0.39 loss 1.41
# step  224/1000: dist 0.37 loss 1.38
# step  225/1000: dist 0.37 loss 0.98
# step  226/1000: dist 0.37 loss 0.67
# step  227/1000: dist 0.37 loss 0.89
# step  228/1000: dist 0.37 loss 1.14
# step  229/1000: dist 0.37 loss 0.87
# step  230/1000: dist 0.38 loss 0.56
# step  231/1000: dist 0.37 loss 0.71
# step  232/1000: dist 0.36 loss 0.89
# step  233/1000: dist 0.36 loss 0.69
# step  234/1000: dist 0.37 loss 0.52
# step  235/1000: dist 0.36 loss 0.65
# step  236/1000: dist 0.37 loss 0.81
# step  237/1000: dist 0.35 loss 0.73
# step  238/1000: dist 0.39 loss 0.73
# step  239/1000: dist 0.38 loss 0.94
# step  240/1000: dist 0.38 loss 1.38
# step  241/1000: dist 0.39 loss 2.04
# step  242/1000: dist 0.39 loss 3.12
# step  243/1000: dist 0.39 loss 4.93
# step  244/1000: dist 0.38 loss 7.42
# step  245/1000: dist 0.37 loss 9.65
# step  246/1000: dist 0.36 loss 9.43
# step  247/1000: dist 0.38 loss 5.71
# step  248/1000: dist 0.38 loss 1.40
# step  249/1000: dist 0.37 loss 0.67
# step  250/1000: dist 0.36 loss 3.25
# step  251/1000: dist 0.36 loss 5.09
# step  252/1000: dist 0.36 loss 3.61
# step  253/1000: dist 0.36 loss 0.96
# step  254/1000: dist 0.36 loss 0.70
# step  255/1000: dist 0.35 loss 2.42
# step  256/1000: dist 0.35 loss 3.05
# step  257/1000: dist 0.37 loss 1.67
# step  258/1000: dist 0.38 loss 0.54
# step  259/1000: dist 0.38 loss 1.10
# step  260/1000: dist 0.39 loss 1.98
# step  261/1000: dist 0.35 loss 1.61
# step  262/1000: dist 0.37 loss 0.80
# step  263/1000: dist 0.36 loss 0.81
# step  264/1000: dist 0.36 loss 1.43
# step  265/1000: dist 0.36 loss 1.69
# step  266/1000: dist 0.35 loss 1.73
# step  267/1000: dist 0.37 loss 2.64
# step  268/1000: dist 0.36 loss 4.93
# step  269/1000: dist 0.35 loss 8.76
# step  270/1000: dist 0.36 loss 14.12
# step  271/1000: dist 0.35 loss 19.04
# step  272/1000: dist 0.36 loss 17.91
# step  273/1000: dist 0.34 loss 11.05
# step  274/1000: dist 0.34 loss 9.78
# step  275/1000: dist 0.34 loss 19.87
# step  276/1000: dist 0.35 loss 30.30
# step  277/1000: dist 0.35 loss 28.22
# step  278/1000: dist 0.35 loss 17.94
# step  279/1000: dist 0.35 loss 11.16
# step  280/1000: dist 0.35 loss 9.31
# step  281/1000: dist 0.34 loss 8.80
# step  282/1000: dist 0.35 loss 10.20
# step  283/1000: dist 0.35 loss 11.55
# step  284/1000: dist 0.35 loss 8.30
# step  285/1000: dist 0.36 loss 4.77
# step  286/1000: dist 0.35 loss 7.42
# step  287/1000: dist 0.34 loss 10.86
# step  288/1000: dist 0.33 loss 9.51
# step  289/1000: dist 0.36 loss 8.59
# step  290/1000: dist 0.35 loss 10.73
# step  291/1000: dist 0.35 loss 9.68
# step  292/1000: dist 0.35 loss 4.85
# step  293/1000: dist 0.34 loss 2.56
# step  294/1000: dist 0.34 loss 3.69
# step  295/1000: dist 0.35 loss 4.78
# step  296/1000: dist 0.33 loss 5.10
# step  297/1000: dist 0.34 loss 4.38
# step  298/1000: dist 0.34 loss 2.28
# step  299/1000: dist 0.34 loss 1.40
# step  300/1000: dist 0.36 loss 2.93
# step  301/1000: dist 0.33 loss 3.65
# step  302/1000: dist 0.34 loss 2.22
# step  303/1000: dist 0.34 loss 1.19
# step  304/1000: dist 0.35 loss 1.68
# step  305/1000: dist 0.35 loss 2.01
# step  306/1000: dist 0.34 loss 1.71
# step  307/1000: dist 0.35 loss 1.55
# step  308/1000: dist 0.33 loss 1.35
# step  309/1000: dist 0.33 loss 1.10
# step  310/1000: dist 0.34 loss 1.29
# step  311/1000: dist 0.34 loss 1.82
# step  312/1000: dist 0.34 loss 2.19
# step  313/1000: dist 0.33 loss 2.78
# step  314/1000: dist 0.34 loss 4.75
# step  315/1000: dist 0.33 loss 8.92
# step  316/1000: dist 0.33 loss 15.30
# step  317/1000: dist 0.33 loss 21.86
# step  318/1000: dist 0.34 loss 22.44
# step  319/1000: dist 0.34 loss 14.53
# step  320/1000: dist 0.34 loss 7.07
# step  321/1000: dist 0.33 loss 8.11
# step  322/1000: dist 0.34 loss 11.17
# step  323/1000: dist 0.35 loss 7.52
# step  324/1000: dist 0.33 loss 3.08
# step  325/1000: dist 0.34 loss 6.34
# step  326/1000: dist 0.33 loss 9.10
# step  327/1000: dist 0.34 loss 3.98
# step  328/1000: dist 0.32 loss 0.67
# step  329/1000: dist 0.33 loss 4.73
# step  330/1000: dist 0.32 loss 5.98
# step  331/1000: dist 0.33 loss 1.92
# step  332/1000: dist 0.33 loss 1.43
# step  333/1000: dist 0.33 loss 3.69
# step  334/1000: dist 0.34 loss 2.84
# step  335/1000: dist 0.32 loss 2.13
# step  336/1000: dist 0.33 loss 3.97
# step  337/1000: dist 0.34 loss 5.48
# step  338/1000: dist 0.34 loss 9.35
# step  339/1000: dist 0.32 loss 18.10
# step  340/1000: dist 0.33 loss 22.32
# step  341/1000: dist 0.33 loss 15.62
# step  342/1000: dist 0.33 loss 12.27
# step  343/1000: dist 0.33 loss 19.21
# step  344/1000: dist 0.32 loss 19.35
# step  345/1000: dist 0.33 loss 8.23
# step  346/1000: dist 0.33 loss 4.87
# step  347/1000: dist 0.34 loss 12.87
# step  348/1000: dist 0.33 loss 16.65
# step  349/1000: dist 0.32 loss 15.47
# step  350/1000: dist 0.33 loss 15.86
# step  351/1000: dist 0.33 loss 13.91
# step  352/1000: dist 0.32 loss 12.31
# step  353/1000: dist 0.32 loss 17.89
# step  354/1000: dist 0.32 loss 22.09
# step  355/1000: dist 0.33 loss 16.67
# step  356/1000: dist 0.32 loss 9.02
# step  357/1000: dist 0.32 loss 6.02
# step  358/1000: dist 0.33 loss 6.80
# step  359/1000: dist 0.34 loss 9.17
# step  360/1000: dist 0.33 loss 8.32
# step  361/1000: dist 0.32 loss 4.21
# step  362/1000: dist 0.32 loss 4.17
# step  363/1000: dist 0.32 loss 6.65
# step  364/1000: dist 0.33 loss 4.59
# step  365/1000: dist 0.33 loss 1.91
# step  366/1000: dist 0.32 loss 3.83
# step  367/1000: dist 0.32 loss 5.20
# step  368/1000: dist 0.32 loss 2.83
# step  369/1000: dist 0.34 loss 1.73
# step  370/1000: dist 0.32 loss 3.90
# step  371/1000: dist 0.32 loss 5.85
# step  372/1000: dist 0.33 loss 6.46
# step  373/1000: dist 0.31 loss 9.28
# step  374/1000: dist 0.31 loss 16.51
# step  375/1000: dist 0.33 loss 24.91
# step  376/1000: dist 0.33 loss 28.99
# step  377/1000: dist 0.32 loss 25.43
# step  378/1000: dist 0.32 loss 16.05
# step  379/1000: dist 0.31 loss 7.77
# step  380/1000: dist 0.34 loss 6.70
# step  381/1000: dist 0.32 loss 10.81
# step  382/1000: dist 0.32 loss 11.43
# step  383/1000: dist 0.32 loss 7.15
# step  384/1000: dist 0.32 loss 4.71
# step  385/1000: dist 0.32 loss 6.21
# step  386/1000: dist 0.32 loss 7.05
# step  387/1000: dist 0.31 loss 5.42
# step  388/1000: dist 0.32 loss 4.70
# step  389/1000: dist 0.31 loss 6.28
# step  390/1000: dist 0.31 loss 8.36
# step  391/1000: dist 0.32 loss 10.52
# step  392/1000: dist 0.32 loss 13.92
# step  393/1000: dist 0.32 loss 17.02
# step  394/1000: dist 0.32 loss 15.22
# step  395/1000: dist 0.31 loss 7.89
# step  396/1000: dist 0.31 loss 2.15
# step  397/1000: dist 0.32 loss 3.53
# step  398/1000: dist 0.31 loss 7.79
# step  399/1000: dist 0.31 loss 7.63
# step  400/1000: dist 0.32 loss 3.33
# step  401/1000: dist 0.32 loss 1.57
# step  402/1000: dist 0.32 loss 3.95
# step  403/1000: dist 0.32 loss 5.10
# step  404/1000: dist 0.30 loss 2.82
# step  405/1000: dist 0.32 loss 1.45
# step  406/1000: dist 0.30 loss 3.05
# step  407/1000: dist 0.30 loss 4.27
# step  408/1000: dist 0.32 loss 3.62
# step  409/1000: dist 0.32 loss 4.27
# step  410/1000: dist 0.31 loss 7.59
# step  411/1000: dist 0.31 loss 10.98
# step  412/1000: dist 0.31 loss 12.50
# step  413/1000: dist 0.31 loss 11.87
# step  414/1000: dist 0.31 loss 7.92
# step  415/1000: dist 0.32 loss 2.57
# step  416/1000: dist 0.32 loss 0.99
# step  417/1000: dist 0.31 loss 4.22
# step  418/1000: dist 0.32 loss 6.80
# step  419/1000: dist 0.30 loss 4.49
# step  420/1000: dist 0.31 loss 0.98
# step  421/1000: dist 0.31 loss 1.25
# step  422/1000: dist 0.30 loss 3.60
# step  423/1000: dist 0.30 loss 3.57
# step  424/1000: dist 0.31 loss 1.42
# step  425/1000: dist 0.31 loss 0.73
# step  426/1000: dist 0.31 loss 1.95
# step  427/1000: dist 0.31 loss 2.41
# step  428/1000: dist 0.32 loss 1.35
# step  429/1000: dist 0.30 loss 0.61
# step  430/1000: dist 0.30 loss 1.17
# step  431/1000: dist 0.31 loss 1.64
# step  432/1000: dist 0.30 loss 1.10
# step  433/1000: dist 0.30 loss 0.54
# step  434/1000: dist 0.30 loss 0.79
# step  435/1000: dist 0.31 loss 1.16
# step  436/1000: dist 0.30 loss 0.88
# step  437/1000: dist 0.31 loss 0.48
# step  438/1000: dist 0.29 loss 0.58
# step  439/1000: dist 0.31 loss 0.86
# step  440/1000: dist 0.32 loss 0.72
# step  441/1000: dist 0.30 loss 0.43
# step  442/1000: dist 0.30 loss 0.47
# step  443/1000: dist 0.30 loss 0.66
# step  444/1000: dist 0.30 loss 0.59
# step  445/1000: dist 0.30 loss 0.39
# step  446/1000: dist 0.31 loss 0.41
# step  447/1000: dist 0.31 loss 0.55
# step  448/1000: dist 0.30 loss 0.52
# step  449/1000: dist 0.30 loss 0.39
# step  450/1000: dist 0.30 loss 0.40
# step  451/1000: dist 0.30 loss 0.53
# step  452/1000: dist 0.30 loss 0.60
# step  453/1000: dist 0.30 loss 0.63
# step  454/1000: dist 0.30 loss 0.86
# step  455/1000: dist 0.30 loss 1.41
# step  456/1000: dist 0.30 loss 2.34
# step  457/1000: dist 0.30 loss 3.91
# step  458/1000: dist 0.30 loss 6.50
# step  459/1000: dist 0.30 loss 9.88
# step  460/1000: dist 0.29 loss 12.34
# step  461/1000: dist 0.30 loss 11.07
# step  462/1000: dist 0.30 loss 6.41
# step  463/1000: dist 0.31 loss 3.69
# step  464/1000: dist 0.30 loss 7.58
# step  465/1000: dist 0.30 loss 16.52
# step  466/1000: dist 0.30 loss 24.83
# step  467/1000: dist 0.30 loss 26.71
# step  468/1000: dist 0.30 loss 18.77
# step  469/1000: dist 0.30 loss 6.69
# step  470/1000: dist 0.31 loss 3.79
# step  471/1000: dist 0.30 loss 10.44
# step  472/1000: dist 0.30 loss 12.33
# step  473/1000: dist 0.30 loss 5.00
# step  474/1000: dist 0.30 loss 2.12
# step  475/1000: dist 0.30 loss 7.55
# step  476/1000: dist 0.30 loss 7.57
# step  477/1000: dist 0.29 loss 1.57
# step  478/1000: dist 0.30 loss 2.59
# step  479/1000: dist 0.30 loss 6.88
# step  480/1000: dist 0.31 loss 4.19
# step  481/1000: dist 0.30 loss 2.10
# step  482/1000: dist 0.29 loss 6.63
# step  483/1000: dist 0.29 loss 9.58
# step  484/1000: dist 0.29 loss 11.43
# step  485/1000: dist 0.30 loss 19.41
# step  486/1000: dist 0.29 loss 28.87
# step  487/1000: dist 0.29 loss 32.14
# step  488/1000: dist 0.29 loss 26.77
# step  489/1000: dist 0.29 loss 12.87
# step  490/1000: dist 0.29 loss 1.82
# step  491/1000: dist 0.31 loss 5.21
# step  492/1000: dist 0.29 loss 14.11
# step  493/1000: dist 0.29 loss 13.34
# step  494/1000: dist 0.30 loss 5.65
# step  495/1000: dist 0.30 loss 2.97
# step  496/1000: dist 0.30 loss 6.66
# step  497/1000: dist 0.29 loss 9.85
# step  498/1000: dist 0.29 loss 9.24
# step  499/1000: dist 0.29 loss 9.77
# step  500/1000: dist 0.29 loss 16.85
# step  501/1000: dist 0.29 loss 25.44
# step  502/1000: dist 0.29 loss 25.97
# step  503/1000: dist 0.29 loss 15.84
# step  504/1000: dist 0.29 loss 5.07
# step  505/1000: dist 0.29 loss 4.10
# step  506/1000: dist 0.29 loss 10.44
# step  507/1000: dist 0.29 loss 12.10
# step  508/1000: dist 0.29 loss 5.33
# step  509/1000: dist 0.29 loss 2.03
# step  510/1000: dist 0.29 loss 6.53
# step  511/1000: dist 0.29 loss 7.45
# step  512/1000: dist 0.29 loss 2.51
# step  513/1000: dist 0.29 loss 2.09
# step  514/1000: dist 0.29 loss 5.44
# step  515/1000: dist 0.29 loss 3.95
# step  585/1000: dist 0.27 loss 1.26
# step  586/1000: dist 0.27 loss 5.68
# step  587/1000: dist 0.28 loss 9.36
# step  588/1000: dist 0.28 loss 6.48
# step  589/1000: dist 0.28 loss 1.45
# step  590/1000: dist 0.28 loss 1.38
# step  591/1000: dist 0.28 loss 4.79
# step  592/1000: dist 0.27 loss 5.12
# step  593/1000: dist 0.28 loss 2.00
# step  594/1000: dist 0.27 loss 0.87
# step  595/1000: dist 0.28 loss 2.97
# step  596/1000: dist 0.28 loss 4.13
# step  597/1000: dist 0.28 loss 3.15
# step  598/1000: dist 0.28 loss 3.70
# step  599/1000: dist 0.28 loss 7.65
# step  600/1000: dist 0.27 loss 13.05
# step  601/1000: dist 0.27 loss 18.86
# step  602/1000: dist 0.27 loss 23.21
# step  603/1000: dist 0.28 loss 20.70
# step  604/1000: dist 0.27 loss 9.47
# step  605/1000: dist 0.27 loss 2.23
# step  606/1000: dist 0.27 loss 7.71
# step  607/1000: dist 0.27 loss 16.40
# step  608/1000: dist 0.27 loss 16.82
# step  609/1000: dist 0.28 loss 15.31
# step  610/1000: dist 0.27 loss 22.23
# step  611/1000: dist 0.28 loss 27.46
# step  612/1000: dist 0.28 loss 17.79
# step  613/1000: dist 0.27 loss 6.25
# step  614/1000: dist 0.27 loss 9.89
# step  615/1000: dist 0.27 loss 20.74
# step  616/1000: dist 0.27 loss 25.08
# step  617/1000: dist 0.27 loss 25.11
# step  618/1000: dist 0.27 loss 27.89
# step  619/1000: dist 0.27 loss 31.98
# step  620/1000: dist 0.27 loss 35.64
# step  621/1000: dist 0.27 loss 40.06
# step  622/1000: dist 0.27 loss 41.90
# step  623/1000: dist 0.27 loss 32.96
# step  624/1000: dist 0.27 loss 15.80
# step  625/1000: dist 0.27 loss 6.45
# step  626/1000: dist 0.27 loss 13.86
# step  627/1000: dist 0.27 loss 23.62
# step  628/1000: dist 0.27 loss 16.85
# step  629/1000: dist 0.27 loss 4.45
# step  630/1000: dist 0.27 loss 6.73
# step  631/1000: dist 0.27 loss 14.42
# step  632/1000: dist 0.27 loss 10.50
# step  633/1000: dist 0.27 loss 3.97
# step  634/1000: dist 0.27 loss 6.23
# step  635/1000: dist 0.27 loss 8.47
# step  636/1000: dist 0.27 loss 5.24
# step  637/1000: dist 0.27 loss 4.02
# step  638/1000: dist 0.27 loss 5.26
# step  639/1000: dist 0.27 loss 4.16
# step  640/1000: dist 0.27 loss 3.27
# step  641/1000: dist 0.27 loss 4.10
# step  642/1000: dist 0.26 loss 3.18
# step  643/1000: dist 0.27 loss 1.86
# step  644/1000: dist 0.27 loss 3.00
# step  645/1000: dist 0.27 loss 3.37
# step  646/1000: dist 0.27 loss 1.55
# step  647/1000: dist 0.27 loss 1.46
# step  648/1000: dist 0.27 loss 2.85
# step  649/1000: dist 0.27 loss 2.20
# step  650/1000: dist 0.26 loss 1.04
# step  651/1000: dist 0.27 loss 1.96
# step  652/1000: dist 0.27 loss 2.72
# step  653/1000: dist 0.27 loss 1.95
# step  654/1000: dist 0.26 loss 2.02
# step  655/1000: dist 0.27 loss 3.45
# step  656/1000: dist 0.27 loss 4.43
# step  657/1000: dist 0.27 loss 5.54
# step  658/1000: dist 0.27 loss 8.64
# step  659/1000: dist 0.26 loss 13.50
# step  660/1000: dist 0.26 loss 18.82
# step  661/1000: dist 0.26 loss 22.72
# step  662/1000: dist 0.26 loss 20.47
# step  663/1000: dist 0.26 loss 11.04
# step  664/1000: dist 0.26 loss 2.63
# step  665/1000: dist 0.26 loss 3.20
# step  666/1000: dist 0.26 loss 8.54
# step  667/1000: dist 0.26 loss 9.02
# step  668/1000: dist 0.26 loss 3.73
# step  669/1000: dist 0.26 loss 1.01
# step  670/1000: dist 0.26 loss 4.34
# step  671/1000: dist 0.26 loss 7.11
# step  672/1000: dist 0.26 loss 4.80
# step  673/1000: dist 0.26 loss 2.50
# step  674/1000: dist 0.26 loss 5.36
# step  675/1000: dist 0.26 loss 10.69
# step  676/1000: dist 0.26 loss 14.83
# step  677/1000: dist 0.26 loss 17.06
# step  678/1000: dist 0.26 loss 14.16
# step  679/1000: dist 0.26 loss 5.88
# step  680/1000: dist 0.26 loss 2.36
# step  681/1000: dist 0.26 loss 7.18
# step  682/1000: dist 0.26 loss 9.94
# step  683/1000: dist 0.26 loss 4.68
# step  684/1000: dist 0.26 loss 1.13
# step  685/1000: dist 0.26 loss 4.61
# step  686/1000: dist 0.26 loss 6.08
# step  687/1000: dist 0.26 loss 2.24
# step  688/1000: dist 0.26 loss 1.38
# step  689/1000: dist 0.26 loss 4.09
# step  690/1000: dist 0.26 loss 3.41
# step  691/1000: dist 0.26 loss 1.02
# step  692/1000: dist 0.26 loss 1.91
# step  693/1000: dist 0.26 loss 2.88
# step  694/1000: dist 0.26 loss 1.31
# step  695/1000: dist 0.26 loss 0.87
# step  696/1000: dist 0.26 loss 1.98
# step  697/1000: dist 0.26 loss 1.50
# step  698/1000: dist 0.26 loss 0.64
# step  699/1000: dist 0.26 loss 1.33
# step  700/1000: dist 0.26 loss 1.53
# step  701/1000: dist 0.26 loss 0.68
# step  702/1000: dist 0.26 loss 0.86
# step  703/1000: dist 0.26 loss 1.50
# step  704/1000: dist 0.26 loss 1.15
# step  705/1000: dist 0.26 loss 1.16
# step  706/1000: dist 0.26 loss 2.35
# step  707/1000: dist 0.26 loss 3.54
# step  708/1000: dist 0.26 loss 5.13
# step  709/1000: dist 0.26 loss 8.71
# step  710/1000: dist 0.26 loss 13.57
# step  711/1000: dist 0.26 loss 17.33
# step  712/1000: dist 0.26 loss 17.15
# step  713/1000: dist 0.26 loss 11.06
# step  714/1000: dist 0.26 loss 2.89
# step  715/1000: dist 0.26 loss 0.58
# step  716/1000: dist 0.26 loss 5.09
# step  717/1000: dist 0.26 loss 8.34
# step  718/1000: dist 0.26 loss 5.07
# step  719/1000: dist 0.26 loss 0.66
# step  720/1000: dist 0.26 loss 1.65
# step  721/1000: dist 0.26 loss 4.69
# step  722/1000: dist 0.26 loss 3.67
# step  723/1000: dist 0.26 loss 0.70
# step  724/1000: dist 0.26 loss 1.08
# step  725/1000: dist 0.26 loss 3.04
# step  726/1000: dist 0.26 loss 2.22
# step  727/1000: dist 0.26 loss 0.43
# step  728/1000: dist 0.26 loss 1.08
# step  729/1000: dist 0.26 loss 2.15
# step  730/1000: dist 0.26 loss 1.17
# step  731/1000: dist 0.25 loss 0.33
# step  732/1000: dist 0.26 loss 1.15
# step  733/1000: dist 0.26 loss 1.44
# step  734/1000: dist 0.26 loss 0.56
# step  735/1000: dist 0.26 loss 0.48
# step  736/1000: dist 0.26 loss 1.13
# step  737/1000: dist 0.26 loss 0.94
# step  738/1000: dist 0.26 loss 0.48
# step  739/1000: dist 0.26 loss 0.88
# step  740/1000: dist 0.25 loss 1.34
# step  741/1000: dist 0.26 loss 1.32
# step  742/1000: dist 0.26 loss 1.85
# step  743/1000: dist 0.25 loss 3.36
# step  744/1000: dist 0.26 loss 5.45
# step  745/1000: dist 0.25 loss 8.81
# step  746/1000: dist 0.26 loss 14.52
# step  747/1000: dist 0.26 loss 21.58
# step  748/1000: dist 0.25 loss 26.40
# step  749/1000: dist 0.26 loss 24.51
# step  750/1000: dist 0.26 loss 16.70
# step  751/1000: dist 0.26 loss 10.98
# step  752/1000: dist 0.25 loss 12.16
# step  753/1000: dist 0.25 loss 14.00
# step  754/1000: dist 0.25 loss 9.07
# step  755/1000: dist 0.26 loss 1.74
# step  756/1000: dist 0.25 loss 2.12
# step  757/1000: dist 0.25 loss 8.17
# step  758/1000: dist 0.25 loss 8.92
# step  759/1000: dist 0.25 loss 3.70
# step  760/1000: dist 0.25 loss 1.54
# step  761/1000: dist 0.25 loss 3.53
# step  762/1000: dist 0.25 loss 3.63
# step  763/1000: dist 0.25 loss 2.35
# step  764/1000: dist 0.25 loss 3.08
# step  765/1000: dist 0.25 loss 3.13
# step  766/1000: dist 0.25 loss 1.01
# step  767/1000: dist 0.25 loss 0.86
# step  768/1000: dist 0.25 loss 2.73
# step  769/1000: dist 0.25 loss 2.31
# step  770/1000: dist 0.25 loss 0.60
# step  771/1000: dist 0.25 loss 0.93
# step  772/1000: dist 0.25 loss 1.66
# step  773/1000: dist 0.25 loss 1.14
# step  774/1000: dist 0.25 loss 0.99
# step  775/1000: dist 0.25 loss 1.19
# step  776/1000: dist 0.25 loss 0.77
# step  777/1000: dist 0.25 loss 0.80
# step  778/1000: dist 0.25 loss 1.33
# step  779/1000: dist 0.26 loss 1.04
# step  780/1000: dist 0.26 loss 0.65
# step  781/1000: dist 0.26 loss 1.06
# step  782/1000: dist 0.26 loss 1.19
# step  783/1000: dist 0.25 loss 0.86
# step  784/1000: dist 0.26 loss 0.89
# step  785/1000: dist 0.25 loss 0.91
# step  786/1000: dist 0.26 loss 0.70
# step  787/1000: dist 0.25 loss 0.66
# step  788/1000: dist 0.26 loss 0.57
# step  789/1000: dist 0.25 loss 0.35
# step  790/1000: dist 0.26 loss 0.39
# step  998/1000: dist 0.24 loss 0.24
# step  999/1000: dist 0.24 loss 0.24
# step 1000/1000: dist 0.24 loss 0.24
# Elapsed: 61.0 s

# %% [markdown]
# With the conversion complete, lets have a look at the two GANs.

# %%
img_gan_source = cv2.imread('/content/out_source/proj.png')
img = cv2.cvtColor(img_gan_source, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('source-gan')
plt.show()

# %%
img_gan_target = cv2.imread('/content/out_target/proj.png')
img = cv2.cvtColor(img_gan_target, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('target-gan')
plt.show()

# %% [markdown]
# # Build the Video
#
# The following code builds a transition video between the two latent vectors previously obtained.

# %%
import torch
import dnnlib
import legacy
import PIL.Image
import numpy as np
import imageio
from tqdm.notebook import tqdm

lvec1 = np.load('/content/out_source/projected_w.npz')['w']
lvec2 = np.load('/content/out_target/projected_w.npz')['w']

network_pkl = "/content/stylegan2ada-weights/network-snapshot-004920.pkl"
device = torch.device('cuda')
with dnnlib.util.open_url(network_pkl) as fp:
    G = legacy.load_network_pkl(fp)['G_ema'].requires_grad_(False).to(device) # type: ignore

############
STEPS = 600
############

diff = lvec2 - lvec1
step = diff / STEPS
current = lvec1.copy()
target_uint8 = np.array([1024,1024,3], dtype=np.uint8)

video = imageio.get_writer('/content/movie.mp4', mode='I', fps=FPS, codec='libx264', bitrate='16M')

for j in tqdm(range(STEPS)):
  z = torch.from_numpy(current).to(device)
  synth_image = G.synthesis(z, noise_mode='const')
  synth_image = (synth_image + 1) * (255/2)
  synth_image = synth_image.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

  repeat = FREEZE_STEPS if j==0 or j==(STEPS-1) else 1
   
  for i in range(repeat):
    video.append_data(synth_image)
  current = current + step


video.close()
# Out:
#   0%|          | 0/600 [00:00<?, ?it/s]

# %% [markdown]
# # Download your Video
#
# If you made it through all of these steps, you are now ready to download your video.

# %%
from google.colab import files
files.download("movie.mp4")

# %% [markdown]
# # Exploring Some Python Files

# %% [markdown]
# *First off, what is projector.py?*
#
# We know at a high-level, this basically takes an input image and the network model tries to find the best latent vector to represent it.
#
# ```py
# @click.option('--network', 'network_pkl', help='Network pickle filename', required=True)
# @click.option('--target', 'target_fname', help='Target image file to project to', required=True, metavar='FILE')
# @click.option('--num-steps',              help='Number of optimization steps', type=int, default=1000, show_default=True)
# @click.option('--seed',                   help='Random seed', type=int, default=303, show_default=True)
# @click.option('--save-video',             help='Save an mp4 video of optimization progress', type=bool, default=True, show_default=True)
# @click.option('--outdir',                 help='Where to save the output images', required=True, metavar='DIR')
# ```
#
# Well, that about sums up the parameters! Looking through a bit of the code, it does, indeed, look like they are optimizing a latent vector.

# %% [markdown]
# Well, that's great. We understand this projector.py file on a high level and how to use it. *Now how does the "Build the Video" section work?*
#
# From a 2nd longer look, it looks like it's taking the difference between the 2 vectors and dividing it into intervals. Each interval mark is a new image. At each interval, the synthesis network will predict an image. These images are all put into an mp4.
