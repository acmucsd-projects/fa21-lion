# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/stylegan2-toys/blob/master/morph_video_real.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Jeff Heaton](https://raw.githubusercontent.com/jeffheaton/present/master/images/github.jpg)
#
# Copyright 2021 by [Jeff Heaton](https://www.youtube.com/channel/UCR1-GEpyOPzT2AO4D_eifdw), [released under Apache 2.0 license](https://github.com/jeffheaton/present/blob/master/LICENSE)
# # StyleGAN2 Morph Between Two REAL Images
#
# This notebook allows you to choose a starting and ending image and use StyleGAN2 to produce a "morph" video between the two pictures.  For the morph to work correctly, both images should be of human faces.  It helps if both pictures are cropped reasonably well to a square portrait to eliminate the possibility of two faces being present in one image.  The preprocessing code will lock in on the exact positioning of each image, so your crop does not have to be perfect. The main point of your crop is for you to remove anything else that might be confused for a face.  If multiple faces are detected, you will receive an error.
#
# Also, make sure you have selected a GPU Runtime from CoLab. Choose "Runtime," then "Change Runtime Type," and choose GPU for "Hardware Accelerator."
#
# The following YouTube video describes precisely how to run this notebook.
#
# [Morphing Real Images to Video with StyleGAN2 ADA](http://youtube.com)
#
# These settings allow you to change the high-level configuration.  The number of steps determines how long your resulting video is.  The video plays at 30 frames a second, so 150 is 5 seconds. You can also specify freeze steps to leave the video unchanged at the beginning and end. You will not likely need to change the network.

# %%
STEPS = 1000
FPS = 30
FREEZE_STEPS = 30

# %%
# Let's get the tick-4920 trained StyleGAN2-ADA.

from google.colab import files
files.upload()  # Upload your kaggle.json here.

# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# Kaggle datasets here.

# Trained tick-4920.
# !mkdir stylegan2ada-weights
# %cd stylegan2ada-weights/
# !kaggle datasets download -d edwardyangiscool/stylegan-weights
# !unzip -q stylegan-weights.zip
# !rm stylegan-weights.zip
# %cd ../
# Out:
#      <input type="file" id="files-c83b6027-3fe8-4db0-aa33-7d0461530797" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c83b6027-3fe8-4db0-aa33-7d0461530797">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (3).json
# mkdir: cannot create directory ‘stylegan2ada-weights’: File exists
# /content/stylegan2ada-weights
# Downloading stylegan-weights.zip to /content/stylegan2ada-weights
#  95% 475M/501M [00:01<00:00, 296MB/s]
# 100% 501M/501M [00:01<00:00, 274MB/s]
# replace network-snapshot-003680.pkl? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# /content

# %%
# list all weights snapshots
# !ls ./stylegan2ada-weights
# Out:
# network-snapshot-003680.pkl  network-snapshot-004920.pkl

# %%
NETWORK = r"/content/stylegan2ada-weights/network-snapshot-004920.pkl"

# %% [markdown]
# # Upload Starting Image
#
# Choose your starting image.

# %%
import os
from google.colab import files

uploaded = files.upload()

if len(uploaded) != 1:
  print("Upload exactly 1 file for source.")
else:
  for k, v in uploaded.items():
    _, ext = os.path.splitext(k)
    os.remove(k)
    SOURCE_NAME = f"source{ext}"
    open(SOURCE_NAME, 'wb').write(v)
# Out:
#      <input type="file" id="files-93fd20c8-170a-498a-a543-0c26b870f7d5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93fd20c8-170a-498a-a543-0c26b870f7d5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving photo-1597223557154-721c1cecc4b0.jpeg to photo-1597223557154-721c1cecc4b0.jpeg

# %% [markdown]
# Also, choose your ending image.

# %%
uploaded = files.upload()

if len(uploaded) != 1:
  print("Upload exactly 1 file for target.")
else:
  for k, v in uploaded.items():
    _, ext = os.path.splitext(k)
    os.remove(k)
    TARGET_NAME = f"target{ext}"
    open(TARGET_NAME, 'wb').write(v)
# Out:
#      <input type="file" id="files-3d52fce2-8a47-43a8-a46e-a1554f53a460" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d52fce2-8a47-43a8-a46e-a1554f53a460">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving _methode_times_prod_web_bin_84e03f68-eef8-11eb-a2a3-afea84050239.jpeg to _methode_times_prod_web_bin_84e03f68-eef8-11eb-a2a3-afea84050239.jpeg

# %% [markdown]
# # Install Software
#
# Some software must be installed into Colab, for this notebook to work. We are specificially using these technologies:
#
# * [Training Generative Adversarial Networks with Limited Data](https://arxiv.org/abs/2006.06676)
# Tero Karras, Miika Aittala, Janne Hellsten, Samuli Laine, Jaakko Lehtinen, Timo Aila
# * [One millisecond face alignment with an ensemble of regression trees](https://www.cv-foundation.org/openaccess/content_cvpr_2014/papers/Kazemi_One_Millisecond_Face_2014_CVPR_paper.pdf) Vahid Kazemi, Josephine Sullivan

# %%
# !wget http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# !bzip2 -d shape_predictor_5_face_landmarks.dat.bz2
# Out:
# --2022-01-06 23:17:58--  http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5706710 (5.4M)
# Saving to: ‘shape_predictor_5_face_landmarks.dat.bz2.6’
#
# shape_predictor_5_f 100%[===================>]   5.44M  5.77MB/s    in 0.9s
#
# 2022-01-06 23:17:59 (5.77 MB/s) - ‘shape_predictor_5_face_landmarks.dat.bz2.6’ saved [5706710/5706710]
#
# bzip2: Output file shape_predictor_5_face_landmarks.dat already exists.

# %%
import sys
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# !pip install ninja
sys.path.insert(0, "/content/stylegan2-ada-pytorch")
# Out:
# fatal: destination path 'stylegan2-ada-pytorch' already exists and is not an empty directory.
# Requirement already satisfied: ninja in /usr/local/lib/python3.7/dist-packages (1.10.2.3)

# %% [markdown]
# # Preprocess Images for Best StyleGAN Results
#
# The following are helper functions for the preprocessing.

# %%
import cv2
import numpy as np
from PIL import Image
import dlib

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_5_face_landmarks.dat')

def find_eyes(img):
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  rects = detector(gray, 0)
  
  if len(rects) == 0:
    raise ValueError("No faces detected")
  elif len(rects) > 1:
    raise ValueError("Multiple faces detected")

  shape = predictor(gray, rects[0])
  features = []

  for i in range(0, 5):
    features.append((i, (shape.part(i).x, shape.part(i).y)))

  return (int(features[3][1][0] + features[2][1][0]) // 2, \
    int(features[3][1][1] + features[2][1][1]) // 2), \
    (int(features[1][1][0] + features[0][1][0]) // 2, \
    int(features[1][1][1] + features[0][1][1]) // 2)

def crop_stylegan(img):
  left_eye, right_eye = find_eyes(img)
  d = abs(right_eye[0] - left_eye[0])
  z = 255/d
  ar = img.shape[0]/img.shape[1]
  w = img.shape[1] * z
  img2 = cv2.resize(img, (int(w), int(w*ar)))
  bordersize = 1024
  img3 = cv2.copyMakeBorder(
      img2,
      top=bordersize,
      bottom=bordersize,
      left=bordersize,
      right=bordersize,
      borderType=cv2.BORDER_REPLICATE)

  left_eye2, right_eye2 = find_eyes(img3)

  crop1 = left_eye2[0] - 385 
  crop0 = left_eye2[1] - 490
  return img3[crop0:crop0+1024,crop1:crop1+1024]

# %% [markdown]
# The following will preprocess and crop your images.  If you receive an error indicating multiple faces were found, try to crop your image better or obscure the background.  If the program does not see a face, then attempt to obtain a clearer and more high-resolution image.

# %%
print(SOURCE_NAME, TARGET_NAME)
# Out:
# source.jpeg target.jpeg

# %%
from matplotlib import pyplot as plt
import cv2

image_source = cv2.imread(SOURCE_NAME)
if image_source is None:
    raise ValueError("Source image not found")

image_target = cv2.imread(TARGET_NAME)
if image_target is None:
    raise ValueError("Source image not found")


cropped_source = crop_stylegan(image_source)
#cropped_target = crop_stylegan(image_target)
cropped_target = image_target

img = cv2.cvtColor(cropped_source, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('cropped_source')
plt.show()

cv2.imwrite("cropped_source.png", cropped_source)
cv2.imwrite("cropped_target.png", cropped_target)

#print(find_eyes(cropped_source))
#print(find_eyes(cropped_target))
# Out:
# True

# %%
# make cropped_target square

def crop_center(pil_img, crop_width, crop_height):
    img_width, img_height = pil_img.size
    return pil_img.crop(((img_width - crop_width) // 2,
                         (img_height - crop_height) // 2,
                         (img_width + crop_width) // 2,
                         (img_height + crop_height) // 2))

img = Image.open('cropped_target.png')

img = crop_center(img, min(img.size), min(img.size))
img.resize((1024, 1024))

img.save('cropped_target.png')

plt.imshow(img)
plt.title('cropped_target')
plt.show()

# %% [markdown]
# # Convert Source to a GAN
#
# First, we convert the source to a GAN latent vector.  This process will take several minutes.

# %%
cmd = f"python /content/stylegan2-ada-pytorch/projector.py --save-video 0 --num-steps 1000 --outdir=out_source --target=cropped_source.png --network={NETWORK}"
# !{cmd}
# Out:
# Loading networks from "/content/stylegan2ada-weights/network-snapshot-004920.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/1000: dist 0.75 loss 24566.10
# step    2/1000: dist 0.56 loss 27639.28
# step    3/1000: dist 0.75 loss 27166.57
# step    4/1000: dist 0.74 loss 26250.56
# step    5/1000: dist 0.54 loss 24954.46
# step    6/1000: dist 0.58 loss 23352.38
# step    7/1000: dist 0.65 loss 21509.97
# step    8/1000: dist 0.69 loss 19484.46
# step    9/1000: dist 0.47 loss 17336.94
# step   10/1000: dist 0.54 loss 15137.38
# step   11/1000: dist 0.53 loss 12947.12
# step   12/1000: dist 0.49 loss 10817.13
# step   13/1000: dist 0.52 loss 8799.22
# step   14/1000: dist 0.55 loss 6944.93
# step   15/1000: dist 0.64 loss 5313.10
# step   16/1000: dist 0.58 loss 3968.37
# step   17/1000: dist 0.54 loss 2940.03
# step   18/1000: dist 0.45 loss 2212.67
# step   19/1000: dist 0.51 loss 1756.61
# step   20/1000: dist 0.48 loss 1564.46
# step   21/1000: dist 0.43 loss 1599.29
# step   22/1000: dist 0.51 loss 1785.68
# step   23/1000: dist 0.45 loss 2049.93
# step   24/1000: dist 0.41 loss 2324.57
# step   25/1000: dist 0.47 loss 2535.27
# step   26/1000: dist 0.47 loss 2633.68
# step   27/1000: dist 0.52 loss 2599.82
# step   28/1000: dist 0.46 loss 2473.09
# step   29/1000: dist 0.47 loss 2312.23
# step   30/1000: dist 0.41 loss 2116.59
# step   31/1000: dist 0.48 loss 1877.89
# step   32/1000: dist 0.42 loss 1620.27
# step   33/1000: dist 0.40 loss 1381.41
# step   34/1000: dist 0.49 loss 1178.83
# step   35/1000: dist 0.50 loss 1020.01
# step   36/1000: dist 0.39 loss 901.24
# step   37/1000: dist 0.38 loss 821.88
# step   38/1000: dist 0.44 loss 799.12
# step   39/1000: dist 0.53 loss 804.51
# step   40/1000: dist 0.48 loss 823.01
# step   41/1000: dist 0.49 loss 819.70
# step   42/1000: dist 0.47 loss 754.06
# step   43/1000: dist 0.54 loss 643.01
# step   44/1000: dist 0.38 loss 514.23
# step   45/1000: dist 0.37 loss 396.21
# step   46/1000: dist 0.48 loss 310.00
# step   47/1000: dist 0.44 loss 255.31
# step   48/1000: dist 0.42 loss 235.61
# step   49/1000: dist 0.57 loss 246.82
# step   50/1000: dist 0.46 loss 297.23
# step   51/1000: dist 0.37 loss 358.67
# step   52/1000: dist 0.48 loss 384.95
# step   53/1000: dist 0.53 loss 371.40
# step   54/1000: dist 0.46 loss 331.67
# step   55/1000: dist 0.38 loss 265.29
# step   56/1000: dist 0.40 loss 185.46
# step   57/1000: dist 0.43 loss 114.05
# step   58/1000: dist 0.45 loss 66.31
# step   59/1000: dist 0.37 loss 46.55
# step   60/1000: dist 0.46 loss 42.04
# step   61/1000: dist 0.43 loss 53.74
# step   62/1000: dist 0.42 loss 78.75
# step   63/1000: dist 0.41 loss 103.87
# step   64/1000: dist 0.36 loss 119.96
# step   65/1000: dist 0.40 loss 123.63
# step   66/1000: dist 0.40 loss 112.84
# step   67/1000: dist 0.36 loss 94.12
# step   68/1000: dist 0.38 loss 67.63
# step   69/1000: dist 0.40 loss 42.77
# step   70/1000: dist 0.40 loss 25.09
# step   71/1000: dist 0.36 loss 14.78
# step   72/1000: dist 0.37 loss 12.98
# step   73/1000: dist 0.35 loss 17.93
# step   74/1000: dist 0.37 loss 23.57
# step   75/1000: dist 0.37 loss 29.73
# step   76/1000: dist 0.35 loss 32.91
# step   77/1000: dist 0.39 loss 31.68
# step   78/1000: dist 0.37 loss 28.83
# step   79/1000: dist 0.34 loss 27.32
# step   80/1000: dist 0.36 loss 25.54
# step   81/1000: dist 0.41 loss 19.89
# step   82/1000: dist 0.38 loss 11.87
# step   83/1000: dist 0.42 loss 9.94
# step  640/1000: dist 0.20 loss 2.87
# step  641/1000: dist 0.20 loss 6.45
# step  642/1000: dist 0.20 loss 9.10
# step  643/1000: dist 0.20 loss 8.61
# step  644/1000: dist 0.20 loss 9.60
# step  645/1000: dist 0.20 loss 11.19
# step  646/1000: dist 0.20 loss 8.49
# step  647/1000: dist 0.20 loss 3.36
# step  648/1000: dist 0.20 loss 1.20
# step  649/1000: dist 0.20 loss 2.07
# step  650/1000: dist 0.20 loss 3.42
# step  651/1000: dist 0.20 loss 4.47
# step  652/1000: dist 0.21 loss 4.39
# step  653/1000: dist 0.20 loss 2.88
# step  654/1000: dist 0.20 loss 2.17
# step  655/1000: dist 0.20 loss 4.15
# step  656/1000: dist 0.20 loss 7.94
# step  657/1000: dist 0.20 loss 12.34
# step  658/1000: dist 0.20 loss 17.64
# step  659/1000: dist 0.20 loss 23.10
# step  660/1000: dist 0.20 loss 25.24
# step  661/1000: dist 0.20 loss 20.20
# step  662/1000: dist 0.20 loss 10.14
# step  663/1000: dist 0.20 loss 3.41
# step  664/1000: dist 0.20 loss 5.47
# step  665/1000: dist 0.20 loss 10.86
# step  666/1000: dist 0.20 loss 10.55
# step  667/1000: dist 0.20 loss 5.12
# step  668/1000: dist 0.20 loss 3.21
# step  669/1000: dist 0.20 loss 7.17
# step  670/1000: dist 0.20 loss 9.85
# step  671/1000: dist 0.20 loss 8.09
# step  672/1000: dist 0.20 loss 7.81
# step  673/1000: dist 0.20 loss 11.77
# step  674/1000: dist 0.20 loss 13.52
# step  675/1000: dist 0.20 loss 9.47
# step  676/1000: dist 0.20 loss 4.71
# step  677/1000: dist 0.20 loss 3.41
# step  678/1000: dist 0.20 loss 3.11
# step  679/1000: dist 0.20 loss 2.53
# step  680/1000: dist 0.20 loss 3.80
# step  681/1000: dist 0.20 loss 5.48
# step  682/1000: dist 0.20 loss 3.92
# step  683/1000: dist 0.20 loss 0.87
# step  684/1000: dist 0.20 loss 0.72
# step  685/1000: dist 0.20 loss 2.67
# step  686/1000: dist 0.20 loss 3.13
# step  687/1000: dist 0.20 loss 1.92
# step  688/1000: dist 0.20 loss 1.00
# step  689/1000: dist 0.20 loss 0.94
# step  690/1000: dist 0.20 loss 1.32
# step  691/1000: dist 0.20 loss 1.77
# step  692/1000: dist 0.20 loss 1.65
# step  693/1000: dist 0.20 loss 1.01
# step  694/1000: dist 0.20 loss 0.96
# step  695/1000: dist 0.20 loss 1.87
# step  696/1000: dist 0.21 loss 2.83
# step  697/1000: dist 0.20 loss 3.66
# step  698/1000: dist 0.20 loss 5.46
# step  699/1000: dist 0.20 loss 8.80
# step  700/1000: dist 0.20 loss 13.29
# step  701/1000: dist 0.20 loss 17.30
# step  702/1000: dist 0.20 loss 18.05
# step  703/1000: dist 0.20 loss 12.49
# step  704/1000: dist 0.21 loss 4.15
# step  705/1000: dist 0.20 loss 0.42
# step  706/1000: dist 0.20 loss 3.57
# step  707/1000: dist 0.21 loss 7.82
# step  708/1000: dist 0.21 loss 6.99
# step  987/1000: dist 0.18 loss 0.18
# step  988/1000: dist 0.18 loss 0.18
# step  989/1000: dist 0.18 loss 0.18
# step  990/1000: dist 0.18 loss 0.18
# step  991/1000: dist 0.18 loss 0.18
# step  992/1000: dist 0.18 loss 0.18
# step  993/1000: dist 0.18 loss 0.18
# step  994/1000: dist 0.18 loss 0.18
# step  995/1000: dist 0.18 loss 0.18
# step  996/1000: dist 0.18 loss 0.18
# step  997/1000: dist 0.18 loss 0.18
# step  998/1000: dist 0.18 loss 0.18
# step  999/1000: dist 0.18 loss 0.18
# step 1000/1000: dist 0.18 loss 0.18
# Elapsed: 62.1 s

# %% [markdown]
# # Convert Target to a GAN
#
# Next, we convert the target to a GAN latent vector.  This process will also take several minutes.

# %%
cmd = f"python /content/stylegan2-ada-pytorch/projector.py --save-video 0 --num-steps 1000 --outdir=out_target --target=cropped_target.png --network={NETWORK}"
# !{cmd}
# Out:
# Loading networks from "/content/stylegan2ada-weights/network-snapshot-004920.pkl"...
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/1000: dist 0.64 loss 24565.99
# step    2/1000: dist 0.76 loss 27639.47
# step    3/1000: dist 0.59 loss 27166.42
# step    4/1000: dist 0.60 loss 26250.42
# step    5/1000: dist 0.77 loss 24954.69
# step    6/1000: dist 0.64 loss 23352.44
# step    7/1000: dist 0.58 loss 21509.91
# step    8/1000: dist 0.57 loss 19484.34
# step    9/1000: dist 0.66 loss 17337.13
# step   10/1000: dist 0.58 loss 15137.42
# step   11/1000: dist 0.61 loss 12947.20
# step   12/1000: dist 0.69 loss 10817.34
# step   13/1000: dist 0.53 loss 8799.24
# step   14/1000: dist 0.60 loss 6944.97
# step   15/1000: dist 0.66 loss 5313.12
# step   16/1000: dist 0.61 loss 3968.40
# step   17/1000: dist 0.58 loss 2940.07
# step   18/1000: dist 0.55 loss 2212.77
# step   19/1000: dist 0.54 loss 1756.64
# step   20/1000: dist 0.51 loss 1564.49
# step   21/1000: dist 0.52 loss 1599.39
# step   22/1000: dist 0.54 loss 1785.72
# step   23/1000: dist 0.54 loss 2050.02
# step   24/1000: dist 0.48 loss 2324.64
# step   25/1000: dist 0.46 loss 2535.26
# step   26/1000: dist 0.49 loss 2633.70
# step   27/1000: dist 0.53 loss 2599.84
# step   28/1000: dist 0.48 loss 2473.11
# step   29/1000: dist 0.52 loss 2312.28
# step   30/1000: dist 0.45 loss 2116.64
# step   31/1000: dist 0.52 loss 1877.94
# step   32/1000: dist 0.49 loss 1620.34
# step   33/1000: dist 0.52 loss 1381.53
# step   34/1000: dist 0.48 loss 1178.82
# step   35/1000: dist 0.45 loss 1019.97
# step   36/1000: dist 0.51 loss 901.36
# step   37/1000: dist 0.48 loss 821.99
# step   38/1000: dist 0.52 loss 799.20
# step   39/1000: dist 0.51 loss 804.49
# step   40/1000: dist 0.47 loss 823.01
# step   41/1000: dist 0.51 loss 819.73
# step   42/1000: dist 0.42 loss 754.02
# step   43/1000: dist 0.43 loss 642.89
# step   44/1000: dist 0.46 loss 514.31
# step   45/1000: dist 0.48 loss 396.30
# step   46/1000: dist 0.48 loss 309.97
# step   47/1000: dist 0.47 loss 255.32
# step   48/1000: dist 0.45 loss 235.63
# step   49/1000: dist 0.49 loss 246.76
# step   50/1000: dist 0.47 loss 297.26
# step   51/1000: dist 0.46 loss 358.78
# step   52/1000: dist 0.46 loss 384.94
# step   53/1000: dist 0.46 loss 371.32
# step   54/1000: dist 0.46 loss 331.63
# step   55/1000: dist 0.45 loss 265.34
# step   56/1000: dist 0.45 loss 185.56
# step   57/1000: dist 0.44 loss 114.08
# step   58/1000: dist 0.47 loss 66.30
# step   59/1000: dist 0.43 loss 46.64
# step   60/1000: dist 0.44 loss 42.05
# step   61/1000: dist 0.46 loss 53.75
# step   62/1000: dist 0.43 loss 78.76
# step   63/1000: dist 0.43 loss 103.86
# step   64/1000: dist 0.42 loss 119.97
# step   65/1000: dist 0.44 loss 123.68
# step   66/1000: dist 0.44 loss 112.90
# step   67/1000: dist 0.44 loss 94.18
# step   68/1000: dist 0.42 loss 67.65
# step   69/1000: dist 0.42 loss 42.78
# step   70/1000: dist 0.47 loss 25.16
# step   71/1000: dist 0.40 loss 14.83
# step   72/1000: dist 0.42 loss 13.01
# step   73/1000: dist 0.41 loss 17.99
# step   74/1000: dist 0.44 loss 23.64
# step   75/1000: dist 0.41 loss 29.76
# step   76/1000: dist 0.45 loss 33.00
# step   77/1000: dist 0.41 loss 31.71
# step   78/1000: dist 0.44 loss 28.93
# step   79/1000: dist 0.43 loss 27.49
# step   80/1000: dist 0.40 loss 25.66
# step   81/1000: dist 0.42 loss 19.90
# step   82/1000: dist 0.42 loss 11.86
# step   83/1000: dist 0.41 loss 9.97
# step   84/1000: dist 0.40 loss 13.60
# step   85/1000: dist 0.40 loss 13.90
# step   86/1000: dist 0.40 loss 10.51
# step   87/1000: dist 0.41 loss 10.22
# step   88/1000: dist 0.46 loss 10.82
# step   89/1000: dist 0.41 loss 8.44
# step   90/1000: dist 0.40 loss 6.14
# step   91/1000: dist 0.42 loss 5.73
# step   92/1000: dist 0.38 loss 5.51
# step   93/1000: dist 0.47 loss 5.95
# step   94/1000: dist 0.43 loss 7.95
# step   95/1000: dist 0.42 loss 10.09
# step   96/1000: dist 0.39 loss 11.04
# step   97/1000: dist 0.41 loss 10.07
# step   98/1000: dist 0.41 loss 6.65
# step   99/1000: dist 0.43 loss 3.27
# step  100/1000: dist 0.41 loss 2.65
# step  101/1000: dist 0.39 loss 3.99
# step  102/1000: dist 0.40 loss 4.12
# step  103/1000: dist 0.41 loss 2.52
# step  104/1000: dist 0.44 loss 1.96
# step  105/1000: dist 0.38 loss 3.28
# step  106/1000: dist 0.41 loss 4.66
# step  107/1000: dist 0.39 loss 4.88
# step  108/1000: dist 0.40 loss 4.92
# step  109/1000: dist 0.40 loss 4.85
# step  110/1000: dist 0.43 loss 3.81
# step  111/1000: dist 0.41 loss 2.37
# step  667/1000: dist 0.28 loss 8.50
# step  668/1000: dist 0.27 loss 7.28
# step  669/1000: dist 0.28 loss 3.18
# step  670/1000: dist 0.27 loss 2.44
# step  671/1000: dist 0.27 loss 4.18
# step  672/1000: dist 0.27 loss 4.24
# step  673/1000: dist 0.27 loss 2.86
# step  674/1000: dist 0.27 loss 2.25
# step  675/1000: dist 0.27 loss 2.43
# step  676/1000: dist 0.27 loss 2.57
# step  677/1000: dist 0.27 loss 2.61
# step  678/1000: dist 0.27 loss 2.39
# step  679/1000: dist 0.27 loss 2.28
# step  680/1000: dist 0.27 loss 3.24
# step  681/1000: dist 0.27 loss 4.93
# step  682/1000: dist 0.27 loss 6.54
# step  683/1000: dist 0.27 loss 9.06
# step  684/1000: dist 0.27 loss 13.31
# step  685/1000: dist 0.27 loss 16.35
# step  686/1000: dist 0.27 loss 14.67
# step  687/1000: dist 0.27 loss 8.57
# step  688/1000: dist 0.27 loss 3.30
# step  689/1000: dist 0.27 loss 3.06
# step  690/1000: dist 0.27 loss 7.49
# step  691/1000: dist 0.27 loss 12.86
# step  692/1000: dist 0.27 loss 16.02
# step  693/1000: dist 0.27 loss 18.50
# step  694/1000: dist 0.27 loss 22.40
# step  695/1000: dist 0.27 loss 22.17
# step  696/1000: dist 0.27 loss 12.50
# step  697/1000: dist 0.27 loss 2.17
# step  698/1000: dist 0.27 loss 3.51
# step  699/1000: dist 0.27 loss 11.29
# step  700/1000: dist 0.27 loss 10.71
# step  701/1000: dist 0.27 loss 2.73
# step  702/1000: dist 0.27 loss 1.42
# step  703/1000: dist 0.27 loss 6.70
# step  704/1000: dist 0.27 loss 6.39
# step  705/1000: dist 0.27 loss 1.40
# step  706/1000: dist 0.27 loss 1.78
# step  707/1000: dist 0.27 loss 4.76
# step  708/1000: dist 0.27 loss 3.01
# step  709/1000: dist 0.27 loss 0.83
# step  710/1000: dist 0.27 loss 2.40
# step  711/1000: dist 0.27 loss 2.83
# step  712/1000: dist 0.27 loss 1.09
# step  713/1000: dist 0.27 loss 1.34
# step  714/1000: dist 0.27 loss 2.11
# step  715/1000: dist 0.27 loss 1.07
# step  716/1000: dist 0.27 loss 0.86
# step  717/1000: dist 0.27 loss 1.64
# step  718/1000: dist 0.27 loss 1.01
# step  719/1000: dist 0.27 loss 0.49
# step  720/1000: dist 0.27 loss 1.22
# step  721/1000: dist 0.27 loss 1.06
# step  722/1000: dist 0.27 loss 0.34
# step  723/1000: dist 0.27 loss 0.77
# step  724/1000: dist 0.27 loss 1.04
# step  725/1000: dist 0.27 loss 0.44
# step  726/1000: dist 0.27 loss 0.48
# step  727/1000: dist 0.27 loss 0.90
# step  728/1000: dist 0.27 loss 0.65
# step  729/1000: dist 0.27 loss 0.55
# step  730/1000: dist 0.27 loss 0.97
# step  731/1000: dist 0.27 loss 1.18
# step  732/1000: dist 0.27 loss 1.50
# step  733/1000: dist 0.27 loss 2.53
# step  734/1000: dist 0.27 loss 4.11
# step  735/1000: dist 0.27 loss 6.70
# step  736/1000: dist 0.27 loss 11.14
# step  737/1000: dist 0.27 loss 17.34
# step  738/1000: dist 0.27 loss 24.26
# step  739/1000: dist 0.27 loss 29.45
# step  740/1000: dist 0.27 loss 29.25
# step  741/1000: dist 0.27 loss 22.11
# step  742/1000: dist 0.27 loss 12.33
# step  743/1000: dist 0.27 loss 8.45
# step  744/1000: dist 0.27 loss 13.95
# step  745/1000: dist 0.27 loss 21.77
# step  746/1000: dist 0.27 loss 23.66
# step  747/1000: dist 0.27 loss 20.75
# step  748/1000: dist 0.27 loss 19.31
# step  749/1000: dist 0.27 loss 20.26
# step  750/1000: dist 0.27 loss 18.90
# step  751/1000: dist 0.27 loss 16.90
# step  752/1000: dist 0.27 loss 20.09
# step  753/1000: dist 0.27 loss 25.30
# step  754/1000: dist 0.27 loss 21.74
# step  755/1000: dist 0.26 loss 9.08
# step  756/1000: dist 0.27 loss 1.31
# step  757/1000: dist 0.27 loss 5.72
# step  758/1000: dist 0.27 loss 12.63
# step  759/1000: dist 0.27 loss 11.16
# step  760/1000: dist 0.27 loss 4.33
# step  761/1000: dist 0.26 loss 1.88
# step  762/1000: dist 0.27 loss 4.98
# step  763/1000: dist 0.27 loss 6.90
# step  764/1000: dist 0.27 loss 4.61
# step  765/1000: dist 0.27 loss 1.88
# step  766/1000: dist 0.27 loss 2.24
# step  767/1000: dist 0.27 loss 3.91
# step  768/1000: dist 0.26 loss 3.54
# step  769/1000: dist 0.26 loss 1.66
# step  770/1000: dist 0.27 loss 1.25
# step  771/1000: dist 0.27 loss 2.42
# step  772/1000: dist 0.26 loss 2.52
# step  773/1000: dist 0.27 loss 1.22
# step  774/1000: dist 0.26 loss 0.86
# step  775/1000: dist 0.26 loss 1.74
# step  776/1000: dist 0.26 loss 1.79
# step  777/1000: dist 0.26 loss 0.89
# step  778/1000: dist 0.26 loss 0.85
# step  779/1000: dist 0.26 loss 1.53
# step  780/1000: dist 0.26 loss 1.43
# step  781/1000: dist 0.26 loss 0.93
# step  782/1000: dist 0.26 loss 1.20
# step  783/1000: dist 0.26 loss 1.65
# step  784/1000: dist 0.26 loss 1.45
# step  785/1000: dist 0.26 loss 1.26
# step  786/1000: dist 0.26 loss 1.51
# step  787/1000: dist 0.26 loss 1.50
# step  788/1000: dist 0.26 loss 1.08
# step  789/1000: dist 0.26 loss 0.88
# step  790/1000: dist 0.26 loss 0.81
# step  791/1000: dist 0.26 loss 0.54
# step  792/1000: dist 0.26 loss 0.35
# step  793/1000: dist 0.26 loss 0.44
# step  794/1000: dist 0.26 loss 0.52
# step  795/1000: dist 0.26 loss 0.50
# step  796/1000: dist 0.26 loss 0.55
# step  797/1000: dist 0.26 loss 0.55
# step  798/1000: dist 0.26 loss 0.42
# step  799/1000: dist 0.26 loss 0.34
# step  800/1000: dist 0.26 loss 0.35
# step  801/1000: dist 0.26 loss 0.34
# step  802/1000: dist 0.26 loss 0.36
# step  803/1000: dist 0.26 loss 0.40
# step  804/1000: dist 0.26 loss 0.36
# step  805/1000: dist 0.26 loss 0.31
# step  806/1000: dist 0.26 loss 0.30
# step  807/1000: dist 0.26 loss 0.30
# step  808/1000: dist 0.26 loss 0.31
# step  809/1000: dist 0.26 loss 0.33
# step  810/1000: dist 0.26 loss 0.30
# step  811/1000: dist 0.26 loss 0.28
# step  812/1000: dist 0.26 loss 0.29
# step  813/1000: dist 0.26 loss 0.29
# step  814/1000: dist 0.26 loss 0.29
# step  815/1000: dist 0.26 loss 0.29
# step  816/1000: dist 0.26 loss 0.27
# step  817/1000: dist 0.26 loss 0.27
# step  818/1000: dist 0.26 loss 0.28
# step  819/1000: dist 0.26 loss 0.28
# step  820/1000: dist 0.26 loss 0.27
# step  821/1000: dist 0.26 loss 0.27
# step  822/1000: dist 0.26 loss 0.27
# step  823/1000: dist 0.26 loss 0.27
# step  824/1000: dist 0.26 loss 0.27
# step  825/1000: dist 0.26 loss 0.26
# step  826/1000: dist 0.26 loss 0.27
# step  827/1000: dist 0.26 loss 0.27
# step  828/1000: dist 0.26 loss 0.26
# step  829/1000: dist 0.26 loss 0.26
# step  830/1000: dist 0.26 loss 0.26
# step  831/1000: dist 0.26 loss 0.26
# step  832/1000: dist 0.26 loss 0.26
# step  833/1000: dist 0.26 loss 0.26
# step  834/1000: dist 0.26 loss 0.26
# step  835/1000: dist 0.26 loss 0.26
# step  836/1000: dist 0.26 loss 0.26
# step  837/1000: dist 0.26 loss 0.26
# step  838/1000: dist 0.26 loss 0.26
# step  839/1000: dist 0.26 loss 0.26
# step  840/1000: dist 0.26 loss 0.26
# step  841/1000: dist 0.26 loss 0.26
# step  842/1000: dist 0.26 loss 0.26
# step  843/1000: dist 0.26 loss 0.26
# step  844/1000: dist 0.26 loss 0.26
# step  845/1000: dist 0.26 loss 0.26
# step  846/1000: dist 0.26 loss 0.26
# step  847/1000: dist 0.26 loss 0.26
# step  848/1000: dist 0.26 loss 0.26
# step  849/1000: dist 0.26 loss 0.26
# step  850/1000: dist 0.26 loss 0.26
# step  851/1000: dist 0.26 loss 0.26
# step  852/1000: dist 0.26 loss 0.26
# step  853/1000: dist 0.26 loss 0.26
# step  854/1000: dist 0.26 loss 0.26
# step  855/1000: dist 0.26 loss 0.26
# step  856/1000: dist 0.26 loss 0.26
# step  857/1000: dist 0.26 loss 0.26
# step  858/1000: dist 0.26 loss 0.26
# step  859/1000: dist 0.26 loss 0.26
# step  860/1000: dist 0.26 loss 0.26
# step  861/1000: dist 0.26 loss 0.26
# step  862/1000: dist 0.26 loss 0.26
# step  863/1000: dist 0.26 loss 0.26
# step  864/1000: dist 0.26 loss 0.26
# step  865/1000: dist 0.26 loss 0.26
# step  866/1000: dist 0.26 loss 0.26
# step  867/1000: dist 0.26 loss 0.26
# step  868/1000: dist 0.26 loss 0.26
# step  869/1000: dist 0.26 loss 0.26
# step  870/1000: dist 0.26 loss 0.26
# step  871/1000: dist 0.26 loss 0.26
# step  872/1000: dist 0.26 loss 0.26
# step  873/1000: dist 0.26 loss 0.26
# step  874/1000: dist 0.26 loss 0.26
# step  875/1000: dist 0.26 loss 0.26
# step  876/1000: dist 0.26 loss 0.26
# step  877/1000: dist 0.26 loss 0.26
# step  878/1000: dist 0.26 loss 0.26
# step  879/1000: dist 0.26 loss 0.26
# step  880/1000: dist 0.26 loss 0.26
# step  881/1000: dist 0.26 loss 0.26
# step  882/1000: dist 0.26 loss 0.26
# step  883/1000: dist 0.26 loss 0.26
# step  884/1000: dist 0.26 loss 0.26
# step  885/1000: dist 0.26 loss 0.26
# step  886/1000: dist 0.26 loss 0.26
# step  887/1000: dist 0.26 loss 0.26
# step  888/1000: dist 0.26 loss 0.26
# step  889/1000: dist 0.26 loss 0.26
# step  890/1000: dist 0.26 loss 0.26
# step  891/1000: dist 0.26 loss 0.26
# step  892/1000: dist 0.26 loss 0.26
# step  893/1000: dist 0.26 loss 0.26
# step  894/1000: dist 0.26 loss 0.26
# step  895/1000: dist 0.26 loss 0.26
# step  896/1000: dist 0.26 loss 0.26
# step  897/1000: dist 0.26 loss 0.26
# step  898/1000: dist 0.26 loss 0.26
# step  899/1000: dist 0.26 loss 0.26
# step  900/1000: dist 0.26 loss 0.26
# step  901/1000: dist 0.26 loss 0.26
# step  902/1000: dist 0.26 loss 0.26
# step  903/1000: dist 0.26 loss 0.26
# step  904/1000: dist 0.26 loss 0.26
# step  905/1000: dist 0.26 loss 0.26
# step  906/1000: dist 0.26 loss 0.26
# step  907/1000: dist 0.26 loss 0.26
# step  908/1000: dist 0.26 loss 0.26
# step  909/1000: dist 0.26 loss 0.26
# step  910/1000: dist 0.26 loss 0.26
# step  911/1000: dist 0.26 loss 0.26
# step  912/1000: dist 0.26 loss 0.26
# step  913/1000: dist 0.26 loss 0.26
# step  914/1000: dist 0.26 loss 0.26
# step  915/1000: dist 0.26 loss 0.26
# step  916/1000: dist 0.26 loss 0.26
# step  917/1000: dist 0.26 loss 0.26
# step  918/1000: dist 0.26 loss 0.26
# step  919/1000: dist 0.26 loss 0.26
# step  920/1000: dist 0.26 loss 0.26
# step  921/1000: dist 0.26 loss 0.26
# step  922/1000: dist 0.26 loss 0.26
# step  923/1000: dist 0.26 loss 0.26
# step  924/1000: dist 0.26 loss 0.26
# step  925/1000: dist 0.26 loss 0.26
# step  926/1000: dist 0.26 loss 0.26
# step  927/1000: dist 0.26 loss 0.26
# step  928/1000: dist 0.26 loss 0.26
# step  929/1000: dist 0.26 loss 0.26
# step  930/1000: dist 0.26 loss 0.26
# step  931/1000: dist 0.26 loss 0.26
# step  932/1000: dist 0.26 loss 0.26
# step  933/1000: dist 0.26 loss 0.26
# step  934/1000: dist 0.26 loss 0.26
# step  935/1000: dist 0.25 loss 0.25
# step  936/1000: dist 0.25 loss 0.25
# step  937/1000: dist 0.25 loss 0.25
# step  938/1000: dist 0.25 loss 0.25
# step  939/1000: dist 0.25 loss 0.25
# step  940/1000: dist 0.25 loss 0.25
# step  941/1000: dist 0.25 loss 0.25
# step  942/1000: dist 0.25 loss 0.25
# step  943/1000: dist 0.25 loss 0.25
# step  944/1000: dist 0.25 loss 0.25
# step  945/1000: dist 0.25 loss 0.25
# step  946/1000: dist 0.25 loss 0.25
# step  947/1000: dist 0.25 loss 0.25
# step  948/1000: dist 0.25 loss 0.25
# step  949/1000: dist 0.25 loss 0.25
# step  950/1000: dist 0.25 loss 0.25
# step  951/1000: dist 0.25 loss 0.25
# step  952/1000: dist 0.25 loss 0.25
# step  953/1000: dist 0.25 loss 0.25
# step  954/1000: dist 0.25 loss 0.25
# step  955/1000: dist 0.25 loss 0.25
# step  956/1000: dist 0.25 loss 0.25
# step  957/1000: dist 0.25 loss 0.25
# step  958/1000: dist 0.25 loss 0.25
# step  959/1000: dist 0.25 loss 0.25
# step  960/1000: dist 0.25 loss 0.25
# step  961/1000: dist 0.25 loss 0.25
# step  962/1000: dist 0.25 loss 0.25
# step  963/1000: dist 0.25 loss 0.25
# step  964/1000: dist 0.25 loss 0.25
# step  965/1000: dist 0.25 loss 0.25
# step  966/1000: dist 0.25 loss 0.25
# step  967/1000: dist 0.25 loss 0.25
# step  968/1000: dist 0.25 loss 0.25
# step  969/1000: dist 0.25 loss 0.25
# step  970/1000: dist 0.25 loss 0.25
# step  971/1000: dist 0.25 loss 0.25
# step  972/1000: dist 0.25 loss 0.25
# step  973/1000: dist 0.25 loss 0.25
# step  974/1000: dist 0.25 loss 0.25
# step  975/1000: dist 0.25 loss 0.25
# step  976/1000: dist 0.25 loss 0.25
# step  977/1000: dist 0.25 loss 0.25
# step  978/1000: dist 0.25 loss 0.25
# step  979/1000: dist 0.25 loss 0.25
# step  980/1000: dist 0.25 loss 0.25
# step  981/1000: dist 0.25 loss 0.25
# step  982/1000: dist 0.25 loss 0.25
# step  983/1000: dist 0.25 loss 0.25
# step  984/1000: dist 0.25 loss 0.25
# step  985/1000: dist 0.25 loss 0.25
# step  986/1000: dist 0.25 loss 0.25
# step  987/1000: dist 0.25 loss 0.25
# step  988/1000: dist 0.25 loss 0.25
# step  989/1000: dist 0.25 loss 0.25
# step  990/1000: dist 0.25 loss 0.25
# step  991/1000: dist 0.25 loss 0.25
# step  992/1000: dist 0.25 loss 0.25
# step  993/1000: dist 0.25 loss 0.25
# step  994/1000: dist 0.25 loss 0.25
# step  995/1000: dist 0.25 loss 0.25
# step  996/1000: dist 0.25 loss 0.25
# step  997/1000: dist 0.25 loss 0.25
# step  998/1000: dist 0.25 loss 0.25
# step  999/1000: dist 0.25 loss 0.25
# step 1000/1000: dist 0.25 loss 0.25
# Elapsed: 62.4 s

# %% [markdown]
# # Images Projected as GAN

# %% [markdown]
# With the conversion complete, lets have a look at the two GANs.

# %%
img_gan_source = cv2.imread('/content/out_source/proj.png')
img = cv2.cvtColor(img_gan_source, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('source-gan')
plt.show()

# %%
img_gan_target = cv2.imread('/content/out_target/proj.png')
img = cv2.cvtColor(img_gan_target, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('target-gan')
plt.show()

# %% [markdown]
# # Build the Video
#
# The following code builds a transition video between the two latent vectors previously obtained.

# %%
import math

def skipped_frames_by_step_num(step_num, steps, max_skip):
  power = .8 * (max_skip / steps) * (step_num - (steps / 2))
  function = (4 * max_skip) * ((-1 * math.exp(power)) / ((1 + math.exp(power)) ** 2)) + max_skip
  
  return math.floor(function)

# %%
import torch
import dnnlib
import legacy
import PIL.Image
import numpy as np
import imageio
from tqdm.notebook import tqdm

lvec1 = np.load('/content/out_source/projected_w.npz')['w']
lvec2 = np.load('/content/out_target/projected_w.npz')['w']

network_pkl = "/content/stylegan2ada-weights/network-snapshot-004920.pkl"
device = torch.device('cuda')
with dnnlib.util.open_url(network_pkl) as fp:
    G = legacy.load_network_pkl(fp)['G_ema'].requires_grad_(False).to(device) # type: ignore

############
STEPS = 2000
SKIPPED_FRAME_CAP = 20
############

diff = lvec2 - lvec1
step = diff / STEPS
current = lvec1.copy()
target_uint8 = np.array([1024,1024,3], dtype=np.uint8)

video = imageio.get_writer('/content/movie.mp4', mode='I', fps=FPS, codec='libx264', bitrate='16M')

MID_SECTION = 200 # num steps to have in the mid section



for j in tqdm(range(STEPS)):
  z = torch.from_numpy(current).to(device)
  synth_image = G.synthesis(z, noise_mode='const')

  synth_image = (synth_image + 1) * (255/2)

  synth_image = synth_image.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

  repeat = FREEZE_STEPS if j==0 or j==(STEPS-1) else 1

  if (j < (STEPS * 1 / 3)):
    skip_frames = skipped_frames_by_step_num(j, STEPS * 2 / 3, SKIPPED_FRAME_CAP)
  else:
    skip_frames = skipped_frames_by_step_num(j, STEPS * 2 / 3, SKIPPED_FRAME_CAP * 2)

  if (repeat == 1 and skip_frames > 0):
    if (j % skip_frames == 0):
      video.append_data(synth_image)
  else:
    for i in range(repeat):
      video.append_data(synth_image)
  
  current = current + step


video.close()
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %% [markdown]
# # Download your Video
#
# If you made it through all of these steps, you are now ready to download your video.

# %%
from google.colab import files
files.download("movie.mp4")

# %% [markdown]
# # Exploring Some Python Files

# %% [markdown]
# *First off, what is projector.py?*
#
# We know at a high-level, this basically takes an input image and the network model tries to find the best latent vector to represent it.
#
# ```py
# @click.option('--network', 'network_pkl', help='Network pickle filename', required=True)
# @click.option('--target', 'target_fname', help='Target image file to project to', required=True, metavar='FILE')
# @click.option('--num-steps',              help='Number of optimization steps', type=int, default=1000, show_default=True)
# @click.option('--seed',                   help='Random seed', type=int, default=303, show_default=True)
# @click.option('--save-video',             help='Save an mp4 video of optimization progress', type=bool, default=True, show_default=True)
# @click.option('--outdir',                 help='Where to save the output images', required=True, metavar='DIR')
# ```
#
# Well, that about sums up the parameters! Looking through a bit of the code, it does, indeed, look like they are optimizing a latent vector.

# %% [markdown]
# Well, that's great. We understand this projector.py file on a high level and how to use it. *Now how does the "Build the Video" section work?*
#
# From a 2nd longer look, it looks like it's taking the difference between the 2 vectors and dividing it into intervals. Each interval mark is a new image. At each interval, the synthesis network will predict an image. These images are all put into an mp4.
