# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/stylegan2-toys/blob/master/morph_video_real.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Jeff Heaton](https://raw.githubusercontent.com/jeffheaton/present/master/images/github.jpg)
#
# Copyright 2021 by [Jeff Heaton](https://www.youtube.com/channel/UCR1-GEpyOPzT2AO4D_eifdw), [released under Apache 2.0 license](https://github.com/jeffheaton/present/blob/master/LICENSE)
# # StyleGAN2 Morph Between Two REAL Images
#
# This notebook allows you to choose a starting and ending image and use StyleGAN2 to produce a "morph" video between the two pictures.  For the morph to work correctly, both images should be of human faces.  It helps if both pictures are cropped reasonably well to a square portrait to eliminate the possibility of two faces being present in one image.  The preprocessing code will lock in on the exact positioning of each image, so your crop does not have to be perfect. The main point of your crop is for you to remove anything else that might be confused for a face.  If multiple faces are detected, you will receive an error.
#
# Also, make sure you have selected a GPU Runtime from CoLab. Choose "Runtime," then "Change Runtime Type," and choose GPU for "Hardware Accelerator."
#
# The following YouTube video describes precisely how to run this notebook.
#
# [Morphing Real Images to Video with StyleGAN2 ADA](http://youtube.com)
#
# These settings allow you to change the high-level configuration.  The number of steps determines how long your resulting video is.  The video plays at 30 frames a second, so 150 is 5 seconds. You can also specify freeze steps to leave the video unchanged at the beginning and end. You will not likely need to change the network.

# %%
face_NETWORK = "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl"
NETWORK = "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/afhqcat.pkl"
STEPS = 150
FPS = 30
FREEZE_STEPS = 30

# %% [markdown]
# # Upload Starting Image
#
# Choose your starting image.

# %%
import os
from google.colab import files

uploaded = files.upload()

if len(uploaded) != 1:
  print("Upload exactly 1 file for source.")
else:
  for k, v in uploaded.items():
    _, ext = os.path.splitext(k)
    os.remove(k)
    SOURCE_NAME = f"source{ext}"
    open(SOURCE_NAME, 'wb').write(v)
# Out:
#      <input type="file" id="files-5fd87418-8888-4518-83fa-f2889e4d0875" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5fd87418-8888-4518-83fa-f2889e4d0875">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving human_aligned.jpg to human_aligned.jpg

# %% [markdown]
# Also, choose your ending image.

# %%
uploaded = files.upload()

if len(uploaded) != 1:
  print("Upload exactly 1 file for target.")
else:
  for k, v in uploaded.items():
    _, ext = os.path.splitext(k)
    os.remove(k)
    TARGET_NAME = f"target{ext}"
    open(TARGET_NAME, 'wb').write(v)
# Out:
#      <input type="file" id="files-54c71809-40ee-4976-bf9d-8d36a005b401" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-54c71809-40ee-4976-bf9d-8d36a005b401">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat_best_LL.jpg to cat_best_LL.jpg

# %% [markdown]
# # Install Software
#
# Some software must be installed into Colab, for this notebook to work. We are specificially using these technologies:
#
# * [Training Generative Adversarial Networks with Limited Data](https://arxiv.org/abs/2006.06676)
# Tero Karras, Miika Aittala, Janne Hellsten, Samuli Laine, Jaakko Lehtinen, Timo Aila
# * [One millisecond face alignment with an ensemble of regression trees](https://www.cv-foundation.org/openaccess/content_cvpr_2014/papers/Kazemi_One_Millisecond_Face_2014_CVPR_paper.pdf) Vahid Kazemi, Josephine Sullivan

# %%
# !wget http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# !bzip2 -d shape_predictor_5_face_landmarks.dat.bz2
# Out:
# --2021-12-24 05:50:24--  http://dlib.net/files/shape_predictor_5_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5706710 (5.4M)
# Saving to: ‘shape_predictor_5_face_landmarks.dat.bz2’
#
# shape_predictor_5_f 100%[===================>]   5.44M  28.3MB/s    in 0.2s
#
# 2021-12-24 05:50:25 (28.3 MB/s) - ‘shape_predictor_5_face_landmarks.dat.bz2’ saved [5706710/5706710]

# %%
import sys
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# !pip install ninja
sys.path.insert(0, "/content/stylegan2-ada-pytorch")
# Out:
# Cloning into 'stylegan2-ada-pytorch'...
# remote: Enumerating objects: 128, done.
# remote: Total 128 (delta 0), reused 0 (delta 0), pack-reused 128
# Receiving objects: 100% (128/128), 1.12 MiB | 32.78 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# Collecting ninja
#   Downloading ninja-1.10.2.3-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (108 kB)
#      |████████████████████████████████| 108 kB 7.3 MB/s
# Installing collected packages: ninja
# Successfully installed ninja-1.10.2.3

# %% [markdown]
# # Preprocess Images for Best StyleGAN Results
#
# The following are helper functions for the preprocessing.

# %%
import cv2
import numpy as np
from PIL import Image
import dlib

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('shape_predictor_5_face_landmarks.dat')

def find_eyes(img):
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  rects = detector(gray, 0)
  
  if len(rects) == 0:
    raise ValueError("No faces detected")
  elif len(rects) > 1:
    raise ValueError("Multiple faces detected")

  shape = predictor(gray, rects[0])
  features = []

  for i in range(0, 5):
    features.append((i, (shape.part(i).x, shape.part(i).y)))

  return (int(features[3][1][0] + features[2][1][0]) // 2, \
    int(features[3][1][1] + features[2][1][1]) // 2), \
    (int(features[1][1][0] + features[0][1][0]) // 2, \
    int(features[1][1][1] + features[0][1][1]) // 2)

def crop_stylegan(img):
  left_eye, right_eye = find_eyes(img)
  d = abs(right_eye[0] - left_eye[0])
  z = 255/d
  ar = img.shape[0]/img.shape[1]
  w = img.shape[1] * z
  img2 = cv2.resize(img, (int(w), int(w*ar)))
  bordersize = 1024
  img3 = cv2.copyMakeBorder(
      img2,
      top=bordersize,
      bottom=bordersize,
      left=bordersize,
      right=bordersize,
      borderType=cv2.BORDER_REPLICATE)

  left_eye2, right_eye2 = find_eyes(img3)

  crop1 = left_eye2[0] - 385 
  crop0 = left_eye2[1] - 490
  return img3[crop0:crop0+1024,crop1:crop1+1024]

# %% [markdown]
# The following will preprocess and crop your images.  If you receive an error indicating multiple faces were found, try to crop your image better or obscure the background.  If the program does not see a face, then attempt to obtain a clearer and more high-resolution image.

# %%
print(SOURCE_NAME, TARGET_NAME)
# Out:
# source.jpg target.jpg

# %%
from matplotlib import pyplot as plt
import cv2

image_source = cv2.imread(SOURCE_NAME)
if image_source is None:
    raise ValueError("Source image not found")

image_target = cv2.imread(TARGET_NAME)
if image_target is None:
    raise ValueError("Source image not found")


cropped_source = crop_stylegan(image_source)
# cropped_target = crop_stylegan(image_target)
cropped_target = image_target

img = cv2.cvtColor(cropped_source, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('source')
plt.show()

img = cv2.cvtColor(cropped_target, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('target')
plt.show()

cv2.imwrite("cropped_source.png", cropped_source)
cv2.imwrite("cropped_target.png", cropped_target)

#print(find_eyes(cropped_source))
#print(find_eyes(cropped_target))
# Out:
# True

# %%
# Avoid the aligning from the above face detector.
# We can do manual aligning and center cropping, but I think the cat image is already
# pretty centered, so I simply resized. If you find fault with
# your cat image, add some preprocessing here!

img = Image.open('cropped_target.png')
img = img.resize((1024, 1024))
img.save('cropped_target.png')

# %% [markdown]
# # Convert Source to a GAN
#
# First, we convert the source to a GAN latent vector.  This process will take several minutes.

# %%
cmd = f"python /content/stylegan2-ada-pytorch/projector.py --save-video 0 --num-steps 1000 --outdir=out_source --target=cropped_source.png --network={face_NETWORK}"
# !{cmd}
# Out:
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl"...
# Downloading https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/ffhq.pkl ... done
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Downloading https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/metrics/vgg16.pt ... done
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/1000: dist 0.62 loss 24567.17
# step    2/1000: dist 0.57 loss 27640.47
# step    3/1000: dist 0.58 loss 27166.95
# step    4/1000: dist 0.58 loss 26253.08
# step    5/1000: dist 0.59 loss 24956.89
# step    6/1000: dist 0.60 loss 23353.74
# step    7/1000: dist 0.62 loss 21512.52
# step    8/1000: dist 0.56 loss 19485.86
# step    9/1000: dist 0.62 loss 17339.20
# step   10/1000: dist 0.57 loss 15139.44
# step   11/1000: dist 0.55 loss 12948.96
# step   12/1000: dist 0.64 loss 10818.45
# step   13/1000: dist 0.58 loss 8801.99
# step   14/1000: dist 0.55 loss 6945.90
# step   15/1000: dist 0.56 loss 5315.22
# step   16/1000: dist 0.57 loss 3970.87
# step   17/1000: dist 0.55 loss 2943.98
# step   18/1000: dist 0.55 loss 2215.11
# step   19/1000: dist 0.56 loss 1759.64
# step   20/1000: dist 0.52 loss 1566.64
# step   21/1000: dist 0.52 loss 1602.59
# step   22/1000: dist 0.53 loss 1787.64
# step   23/1000: dist 0.53 loss 2053.09
# step   24/1000: dist 0.53 loss 2328.97
# step   25/1000: dist 0.54 loss 2537.91
# step   26/1000: dist 0.52 loss 2636.90
# step   27/1000: dist 0.50 loss 2605.44
# step   28/1000: dist 0.53 loss 2475.65
# step   29/1000: dist 0.50 loss 2314.33
# step   30/1000: dist 0.53 loss 2122.35
# step   31/1000: dist 0.50 loss 1881.71
# step   32/1000: dist 0.50 loss 1621.36
# step   33/1000: dist 0.52 loss 1383.76
# step   34/1000: dist 0.51 loss 1183.36
# step   35/1000: dist 0.51 loss 1025.44
# step   36/1000: dist 0.50 loss 906.45
# step   37/1000: dist 0.49 loss 830.04
# step   38/1000: dist 0.48 loss 818.90
# step   39/1000: dist 0.52 loss 830.55
# step   40/1000: dist 0.51 loss 838.06
# step   41/1000: dist 0.47 loss 840.54
# step   42/1000: dist 0.48 loss 773.28
# step   43/1000: dist 0.49 loss 653.07
# step   44/1000: dist 0.47 loss 534.70
# step   45/1000: dist 0.47 loss 407.70
# step   46/1000: dist 0.48 loss 319.96
# step   47/1000: dist 0.46 loss 268.02
# step   48/1000: dist 0.46 loss 242.94
# step   49/1000: dist 0.45 loss 261.26
# step   50/1000: dist 0.46 loss 308.88
# step   51/1000: dist 0.46 loss 371.41
# step   52/1000: dist 0.46 loss 402.16
# step   53/1000: dist 0.46 loss 383.45
# step   54/1000: dist 0.44 loss 352.42
# step   55/1000: dist 0.45 loss 287.32
# step   56/1000: dist 0.44 loss 193.57
# step   57/1000: dist 0.45 loss 128.41
# step   58/1000: dist 0.44 loss 81.67
# step   59/1000: dist 0.45 loss 52.93
# step   60/1000: dist 0.42 loss 54.06
# step   61/1000: dist 0.44 loss 61.85
# step   62/1000: dist 0.43 loss 82.25
# step   63/1000: dist 0.44 loss 113.74
# step   64/1000: dist 0.44 loss 124.10
# step   65/1000: dist 0.44 loss 128.56
# step   66/1000: dist 0.44 loss 120.35
# step   67/1000: dist 0.43 loss 96.47
# step   68/1000: dist 0.43 loss 72.59
# step   69/1000: dist 0.43 loss 46.86
# step   70/1000: dist 0.43 loss 28.58
# step   71/1000: dist 0.41 loss 19.05
# step   72/1000: dist 0.43 loss 16.81
# step   73/1000: dist 0.43 loss 23.00
# step   74/1000: dist 0.45 loss 26.34
# step   75/1000: dist 0.42 loss 33.62
# step   76/1000: dist 0.43 loss 36.07
# step   77/1000: dist 0.42 loss 32.47
# step   78/1000: dist 0.42 loss 31.46
# step   79/1000: dist 0.42 loss 28.53
# step   80/1000: dist 0.42 loss 26.51
# step   81/1000: dist 0.41 loss 21.44
# step   82/1000: dist 0.42 loss 12.98
# step   83/1000: dist 0.41 loss 12.25
# step   84/1000: dist 0.41 loss 15.37
# step   85/1000: dist 0.41 loss 15.85
# step   86/1000: dist 0.43 loss 13.23
# step   87/1000: dist 0.43 loss 12.37
# step   88/1000: dist 0.43 loss 13.90
# step   89/1000: dist 0.42 loss 12.60
# step   90/1000: dist 0.42 loss 10.65
# step   91/1000: dist 0.41 loss 10.47
# step   92/1000: dist 0.42 loss 9.26
# step   93/1000: dist 0.40 loss 9.07
# step   94/1000: dist 0.41 loss 12.45
# step   95/1000: dist 0.41 loss 16.74
# step   96/1000: dist 0.40 loss 18.80
# step   97/1000: dist 0.42 loss 15.67
# step   98/1000: dist 0.42 loss 9.19
# step   99/1000: dist 0.41 loss 5.64
# step  100/1000: dist 0.41 loss 7.28
# step  101/1000: dist 0.39 loss 10.24
# step  102/1000: dist 0.41 loss 9.26
# step  103/1000: dist 0.40 loss 4.81
# step  104/1000: dist 0.42 loss 2.82
# step  105/1000: dist 0.41 loss 4.88
# step  106/1000: dist 0.43 loss 7.11
# step  107/1000: dist 0.44 loss 7.12
# step  108/1000: dist 0.40 loss 6.51
# step  109/1000: dist 0.41 loss 6.59
# step  110/1000: dist 0.40 loss 6.01
# step  111/1000: dist 0.40 loss 4.24
# step  112/1000: dist 0.40 loss 3.05
# step  113/1000: dist 0.39 loss 3.44
# step  114/1000: dist 0.41 loss 4.15
# step  115/1000: dist 0.40 loss 4.13
# step  116/1000: dist 0.41 loss 4.20
# step  117/1000: dist 0.41 loss 4.72
# step  118/1000: dist 0.42 loss 4.83
# step  119/1000: dist 0.40 loss 4.07
# step  120/1000: dist 0.39 loss 3.14
# step  121/1000: dist 0.40 loss 2.47
# step  122/1000: dist 0.39 loss 1.80
# step  123/1000: dist 0.40 loss 1.27
# step  124/1000: dist 0.41 loss 1.46
# step  125/1000: dist 0.40 loss 2.39
# step  126/1000: dist 0.40 loss 3.18
# step  127/1000: dist 0.40 loss 3.17
# step  128/1000: dist 0.40 loss 2.93
# step  129/1000: dist 0.41 loss 3.75
# step  130/1000: dist 0.40 loss 6.30
# step  131/1000: dist 0.39 loss 10.20
# step  132/1000: dist 0.39 loss 13.07
# step  133/1000: dist 0.42 loss 10.52
# step  134/1000: dist 0.41 loss 4.17
# step  135/1000: dist 0.40 loss 2.45
# step  136/1000: dist 0.40 loss 6.20
# step  137/1000: dist 0.40 loss 7.22
# step  138/1000: dist 0.39 loss 3.12
# step  139/1000: dist 0.39 loss 1.71
# step  140/1000: dist 0.41 loss 4.76
# step  141/1000: dist 0.39 loss 5.08
# step  142/1000: dist 0.38 loss 2.53
# step  143/1000: dist 0.40 loss 3.48
# step  144/1000: dist 0.39 loss 6.72
# step  145/1000: dist 0.42 loss 7.69
# step  146/1000: dist 0.40 loss 8.30
# step  147/1000: dist 0.40 loss 9.92
# step  148/1000: dist 0.40 loss 7.74
# step  149/1000: dist 0.40 loss 2.53
# step  150/1000: dist 0.40 loss 1.48
# step  151/1000: dist 0.39 loss 4.85
# step  152/1000: dist 0.39 loss 6.84
# step  153/1000: dist 0.39 loss 6.48
# step  154/1000: dist 0.39 loss 8.27
# step  155/1000: dist 0.39 loss 15.70
# step  156/1000: dist 0.40 loss 27.60
# step  157/1000: dist 0.39 loss 35.39
# step  158/1000: dist 0.39 loss 31.21
# step  159/1000: dist 0.40 loss 28.85
# step  160/1000: dist 0.38 loss 40.09
# step  161/1000: dist 0.40 loss 46.30
# step  162/1000: dist 0.40 loss 30.96
# step  163/1000: dist 0.38 loss 24.01
# step  164/1000: dist 0.40 loss 36.68
# step  165/1000: dist 0.40 loss 33.82
# step  166/1000: dist 0.38 loss 17.70
# step  167/1000: dist 0.39 loss 20.09
# step  168/1000: dist 0.38 loss 24.54
# step  169/1000: dist 0.38 loss 16.33
# step  170/1000: dist 0.38 loss 14.79
# step  171/1000: dist 0.38 loss 12.49
# step  172/1000: dist 0.39 loss 5.88
# step  173/1000: dist 0.40 loss 13.72
# step  174/1000: dist 0.38 loss 17.73
# step  175/1000: dist 0.38 loss 6.82
# step  176/1000: dist 0.39 loss 5.89
# step  177/1000: dist 0.38 loss 10.31
# step  178/1000: dist 0.38 loss 8.02
# step  179/1000: dist 0.38 loss 7.82
# step  180/1000: dist 0.39 loss 7.02
# step  181/1000: dist 0.38 loss 6.01
# step  182/1000: dist 0.38 loss 8.29
# step  183/1000: dist 0.38 loss 6.01
# step  184/1000: dist 0.39 loss 4.92
# step  185/1000: dist 0.38 loss 10.30
# step  186/1000: dist 0.38 loss 13.46
# step  187/1000: dist 0.39 loss 15.30
# step  188/1000: dist 0.37 loss 16.08
# step  189/1000: dist 0.37 loss 11.00
# step  190/1000: dist 0.39 loss 8.19
# step  191/1000: dist 0.38 loss 11.12
# step  192/1000: dist 0.38 loss 12.26
# step  193/1000: dist 0.37 loss 9.63
# step  194/1000: dist 0.39 loss 6.73
# step  195/1000: dist 0.38 loss 6.68
# step  196/1000: dist 0.38 loss 7.92
# step  197/1000: dist 0.38 loss 5.96
# step  198/1000: dist 0.37 loss 3.54
# step  199/1000: dist 0.39 loss 4.70
# step  200/1000: dist 0.38 loss 5.64
# step  201/1000: dist 0.37 loss 4.19
# step  202/1000: dist 0.39 loss 3.84
# step  203/1000: dist 0.37 loss 5.48
# step  204/1000: dist 0.38 loss 7.16
# step  205/1000: dist 0.37 loss 9.44
# step  206/1000: dist 0.37 loss 13.21
# step  207/1000: dist 0.39 loss 14.59
# step  208/1000: dist 0.38 loss 9.35
# step  209/1000: dist 0.37 loss 2.98
# step  210/1000: dist 0.38 loss 3.35
# step  211/1000: dist 0.37 loss 7.48
# step  212/1000: dist 0.38 loss 8.06
# step  213/1000: dist 0.37 loss 5.14
# step  214/1000: dist 0.39 loss 4.70
# step  215/1000: dist 0.37 loss 7.69
# step  216/1000: dist 0.38 loss 9.53
# step  217/1000: dist 0.37 loss 8.36
# step  218/1000: dist 0.38 loss 7.03
# step  219/1000: dist 0.37 loss 6.82
# step  220/1000: dist 0.39 loss 5.90
# step  221/1000: dist 0.39 loss 5.04
# step  222/1000: dist 0.40 loss 7.45
# step  223/1000: dist 0.39 loss 12.21
# step  224/1000: dist 0.37 loss 14.43
# step  225/1000: dist 0.38 loss 11.93
# step  226/1000: dist 0.38 loss 7.86
# step  227/1000: dist 0.38 loss 7.15
# step  228/1000: dist 0.37 loss 12.18
# step  229/1000: dist 0.38 loss 21.28
# step  230/1000: dist 0.37 loss 27.81
# step  231/1000: dist 0.38 loss 22.29
# step  232/1000: dist 0.37 loss 7.64
# step  233/1000: dist 0.38 loss 2.69
# step  234/1000: dist 0.37 loss 10.70
# step  235/1000: dist 0.38 loss 13.17
# step  236/1000: dist 0.38 loss 4.83
# step  237/1000: dist 0.37 loss 3.00
# step  238/1000: dist 0.37 loss 9.76
# step  239/1000: dist 0.37 loss 9.67
# step  240/1000: dist 0.36 loss 6.23
# step  241/1000: dist 0.38 loss 12.74
# step  242/1000: dist 0.38 loss 23.48
# step  243/1000: dist 0.37 loss 27.97
# step  244/1000: dist 0.37 loss 20.98
# step  245/1000: dist 0.37 loss 6.77
# step  246/1000: dist 0.37 loss 5.66
# step  247/1000: dist 0.38 loss 15.67
# step  248/1000: dist 0.37 loss 11.57
# step  249/1000: dist 0.36 loss 1.53
# step  250/1000: dist 0.37 loss 7.37
# step  251/1000: dist 0.37 loss 9.96
# step  252/1000: dist 0.37 loss 2.34
# step  253/1000: dist 0.38 loss 4.98
# step  254/1000: dist 0.37 loss 7.32
# step  255/1000: dist 0.37 loss 1.87
# step  256/1000: dist 0.36 loss 3.80
# step  257/1000: dist 0.36 loss 4.89
# step  258/1000: dist 0.36 loss 1.06
# step  259/1000: dist 0.37 loss 3.09
# step  260/1000: dist 0.36 loss 3.39
# step  261/1000: dist 0.38 loss 1.32
# step  262/1000: dist 0.37 loss 2.94
# step  263/1000: dist 0.37 loss 2.05
# step  264/1000: dist 0.36 loss 1.28
# step  265/1000: dist 0.36 loss 2.57
# step  266/1000: dist 0.36 loss 1.29
# step  267/1000: dist 0.36 loss 1.51
# step  268/1000: dist 0.36 loss 2.40
# step  269/1000: dist 0.36 loss 1.77
# step  270/1000: dist 0.36 loss 3.55
# step  271/1000: dist 0.36 loss 5.71
# step  272/1000: dist 0.36 loss 8.77
# step  273/1000: dist 0.36 loss 15.97
# step  274/1000: dist 0.36 loss 23.39
# step  275/1000: dist 0.36 loss 27.42
# step  276/1000: dist 0.36 loss 26.92
# step  277/1000: dist 0.36 loss 26.92
# step  278/1000: dist 0.36 loss 34.79
# step  279/1000: dist 0.36 loss 41.61
# step  280/1000: dist 0.36 loss 32.10
# step  281/1000: dist 0.36 loss 14.30
# step  282/1000: dist 0.36 loss 10.17
# step  283/1000: dist 0.36 loss 19.01
# step  284/1000: dist 0.36 loss 21.11
# step  285/1000: dist 0.37 loss 13.64
# step  286/1000: dist 0.36 loss 13.27
# step  287/1000: dist 0.36 loss 21.84
# step  288/1000: dist 0.36 loss 25.59
# step  289/1000: dist 0.37 loss 24.03
# step  290/1000: dist 0.37 loss 22.25
# step  291/1000: dist 0.36 loss 17.99
# step  292/1000: dist 0.36 loss 13.64
# step  293/1000: dist 0.36 loss 15.66
# step  294/1000: dist 0.36 loss 18.88
# step  295/1000: dist 0.37 loss 13.93
# step  296/1000: dist 0.36 loss 6.12
# step  297/1000: dist 0.37 loss 6.42
# step  298/1000: dist 0.35 loss 11.33
# step  299/1000: dist 0.36 loss 13.17
# step  300/1000: dist 0.35 loss 13.70
# step  301/1000: dist 0.36 loss 15.69
# step  302/1000: dist 0.35 loss 17.00
# step  303/1000: dist 0.35 loss 15.13
# step  304/1000: dist 0.36 loss 10.16
# step  305/1000: dist 0.35 loss 5.33
# step  306/1000: dist 0.36 loss 5.11
# step  307/1000: dist 0.35 loss 8.25
# step  308/1000: dist 0.36 loss 8.86
# step  309/1000: dist 0.36 loss 5.43
# step  310/1000: dist 0.36 loss 3.34
# step  311/1000: dist 0.36 loss 5.14
# step  312/1000: dist 0.35 loss 6.76
# step  313/1000: dist 0.35 loss 6.01
# step  314/1000: dist 0.36 loss 6.18
# step  315/1000: dist 0.35 loss 9.07
# step  316/1000: dist 0.36 loss 12.05
# step  317/1000: dist 0.35 loss 12.85
# step  318/1000: dist 0.35 loss 12.74
# step  319/1000: dist 0.35 loss 13.42
# step  320/1000: dist 0.36 loss 14.83
# step  321/1000: dist 0.36 loss 15.38
# step  322/1000: dist 0.36 loss 14.60
# step  323/1000: dist 0.36 loss 13.54
# step  324/1000: dist 0.35 loss 13.61
# step  325/1000: dist 0.35 loss 15.74
# step  326/1000: dist 0.35 loss 18.80
# step  327/1000: dist 0.36 loss 18.47
# step  328/1000: dist 0.35 loss 12.35
# step  329/1000: dist 0.34 loss 5.37
# step  330/1000: dist 0.35 loss 4.59
# step  331/1000: dist 0.35 loss 8.61
# step  332/1000: dist 0.35 loss 10.15
# step  333/1000: dist 0.35 loss 6.63
# step  334/1000: dist 0.35 loss 3.64
# step  335/1000: dist 0.34 loss 5.33
# step  336/1000: dist 0.35 loss 7.99
# step  337/1000: dist 0.35 loss 7.59
# step  338/1000: dist 0.35 loss 6.74
# step  339/1000: dist 0.35 loss 8.99
# step  340/1000: dist 0.35 loss 11.98
# step  341/1000: dist 0.35 loss 11.35
# step  342/1000: dist 0.35 loss 7.93
# step  343/1000: dist 0.35 loss 4.97
# step  344/1000: dist 0.36 loss 3.45
# step  345/1000: dist 0.34 loss 2.72
# step  346/1000: dist 0.34 loss 3.45
# step  347/1000: dist 0.34 loss 5.22
# step  348/1000: dist 0.34 loss 5.24
# step  349/1000: dist 0.35 loss 2.77
# step  350/1000: dist 0.35 loss 1.01
# step  351/1000: dist 0.34 loss 2.16
# step  352/1000: dist 0.34 loss 4.19
# step  353/1000: dist 0.34 loss 4.69
# step  354/1000: dist 0.36 loss 4.64
# step  355/1000: dist 0.35 loss 6.34
# step  356/1000: dist 0.36 loss 10.25
# step  357/1000: dist 0.35 loss 14.34
# step  358/1000: dist 0.34 loss 15.49
# step  359/1000: dist 0.34 loss 11.11
# step  360/1000: dist 0.35 loss 4.63
# step  361/1000: dist 0.35 loss 3.14
# step  362/1000: dist 0.34 loss 8.34
# step  363/1000: dist 0.35 loss 14.30
# step  364/1000: dist 0.34 loss 16.11
# step  365/1000: dist 0.35 loss 17.05
# step  366/1000: dist 0.34 loss 21.34
# step  367/1000: dist 0.34 loss 23.96
# step  368/1000: dist 0.35 loss 17.63
# step  369/1000: dist 0.34 loss 6.89
# step  370/1000: dist 0.34 loss 3.39
# step  371/1000: dist 0.34 loss 8.29
# step  372/1000: dist 0.34 loss 12.01
# step  373/1000: dist 0.35 loss 9.92
# step  374/1000: dist 0.34 loss 7.23
# step  375/1000: dist 0.34 loss 7.93
# step  376/1000: dist 0.34 loss 9.06
# step  377/1000: dist 0.34 loss 7.97
# step  378/1000: dist 0.34 loss 6.39
# step  379/1000: dist 0.34 loss 5.74
# step  380/1000: dist 0.34 loss 4.80
# step  381/1000: dist 0.34 loss 3.92
# step  382/1000: dist 0.34 loss 5.82
# step  383/1000: dist 0.34 loss 11.75
# step  384/1000: dist 0.35 loss 20.84
# step  385/1000: dist 0.34 loss 32.53
# step  386/1000: dist 0.34 loss 43.45
# step  387/1000: dist 0.34 loss 41.82
# step  388/1000: dist 0.34 loss 25.57
# step  389/1000: dist 0.34 loss 11.70
# step  390/1000: dist 0.34 loss 12.47
# step  391/1000: dist 0.34 loss 17.60
# step  392/1000: dist 0.33 loss 15.39
# step  393/1000: dist 0.34 loss 11.65
# step  394/1000: dist 0.34 loss 9.66
# step  395/1000: dist 0.35 loss 7.59
# step  396/1000: dist 0.35 loss 8.69
# step  397/1000: dist 0.35 loss 9.71
# step  398/1000: dist 0.34 loss 5.21
# step  399/1000: dist 0.34 loss 4.31
# step  400/1000: dist 0.34 loss 8.31
# step  401/1000: dist 0.34 loss 5.50
# step  402/1000: dist 0.34 loss 2.03
# step  403/1000: dist 0.33 loss 6.37
# step  404/1000: dist 0.34 loss 7.21
# step  405/1000: dist 0.33 loss 4.84
# step  406/1000: dist 0.33 loss 10.39
# step  407/1000: dist 0.33 loss 16.54
# step  408/1000: dist 0.34 loss 17.47
# step  409/1000: dist 0.34 loss 18.03
# step  410/1000: dist 0.33 loss 13.11
# step  411/1000: dist 0.33 loss 4.01
# step  412/1000: dist 0.33 loss 4.92
# step  413/1000: dist 0.33 loss 13.32
# step  414/1000: dist 0.34 loss 15.65
# step  415/1000: dist 0.34 loss 12.17
# step  416/1000: dist 0.33 loss 10.85
# step  417/1000: dist 0.34 loss 11.32
# step  418/1000: dist 0.33 loss 8.26
# step  419/1000: dist 0.33 loss 2.57
# step  420/1000: dist 0.33 loss 2.01
# step  421/1000: dist 0.33 loss 6.79
# step  422/1000: dist 0.34 loss 7.71
# step  423/1000: dist 0.33 loss 3.53
# step  424/1000: dist 0.34 loss 1.66
# step  425/1000: dist 0.33 loss 3.07
# step  426/1000: dist 0.33 loss 3.68
# step  427/1000: dist 0.34 loss 3.24
# step  428/1000: dist 0.33 loss 2.76
# step  429/1000: dist 0.33 loss 2.04
# step  430/1000: dist 0.33 loss 1.84
# step  431/1000: dist 0.33 loss 2.87
# step  432/1000: dist 0.33 loss 3.89
# step  433/1000: dist 0.33 loss 3.97
# step  434/1000: dist 0.33 loss 4.88
# step  435/1000: dist 0.33 loss 8.22
# step  436/1000: dist 0.33 loss 12.12
# step  437/1000: dist 0.33 loss 13.61
# step  438/1000: dist 0.33 loss 11.76
# step  439/1000: dist 0.33 loss 7.02
# step  440/1000: dist 0.33 loss 2.23
# step  441/1000: dist 0.33 loss 1.46
# step  442/1000: dist 0.33 loss 4.53
# step  443/1000: dist 0.33 loss 6.42
# step  444/1000: dist 0.33 loss 4.19
# step  445/1000: dist 0.33 loss 1.22
# step  446/1000: dist 0.33 loss 1.39
# step  447/1000: dist 0.33 loss 3.31
# step  448/1000: dist 0.33 loss 3.44
# step  449/1000: dist 0.33 loss 1.64
# step  450/1000: dist 0.33 loss 0.83
# step  451/1000: dist 0.33 loss 1.89
# step  452/1000: dist 0.33 loss 2.55
# step  453/1000: dist 0.33 loss 1.62
# step  454/1000: dist 0.33 loss 0.93
# step  455/1000: dist 0.33 loss 1.73
# step  456/1000: dist 0.33 loss 2.57
# step  457/1000: dist 0.33 loss 2.37
# step  458/1000: dist 0.33 loss 2.45
# step  459/1000: dist 0.33 loss 3.87
# step  460/1000: dist 0.33 loss 5.59
# step  461/1000: dist 0.33 loss 6.61
# step  462/1000: dist 0.33 loss 7.36
# step  463/1000: dist 0.33 loss 7.97
# step  464/1000: dist 0.32 loss 7.45
# step  465/1000: dist 0.33 loss 6.00
# step  466/1000: dist 0.33 loss 6.21
# step  467/1000: dist 0.33 loss 10.39
# step  468/1000: dist 0.33 loss 17.72
# step  469/1000: dist 0.32 loss 23.72
# step  470/1000: dist 0.32 loss 22.22
# step  471/1000: dist 0.33 loss 13.69
# step  472/1000: dist 0.33 loss 10.01
# step  473/1000: dist 0.33 loss 19.79
# step  474/1000: dist 0.32 loss 34.43
# step  475/1000: dist 0.32 loss 39.00
# step  476/1000: dist 0.32 loss 32.26
# step  477/1000: dist 0.32 loss 30.92
# step  478/1000: dist 0.32 loss 40.41
# step  479/1000: dist 0.32 loss 42.57
# step  480/1000: dist 0.32 loss 30.33
# step  481/1000: dist 0.32 loss 20.65
# step  482/1000: dist 0.32 loss 25.26
# step  483/1000: dist 0.32 loss 30.19
# step  484/1000: dist 0.32 loss 22.33
# step  485/1000: dist 0.32 loss 14.03
# step  486/1000: dist 0.32 loss 15.92
# step  487/1000: dist 0.32 loss 17.25
# step  488/1000: dist 0.32 loss 11.20
# step  489/1000: dist 0.32 loss 8.20
# step  490/1000: dist 0.32 loss 11.00
# step  491/1000: dist 0.32 loss 10.22
# step  492/1000: dist 0.32 loss 8.57
# step  493/1000: dist 0.32 loss 14.08
# step  494/1000: dist 0.32 loss 20.55
# step  495/1000: dist 0.32 loss 24.14
# step  496/1000: dist 0.32 loss 33.24
# step  497/1000: dist 0.32 loss 43.09
# step  498/1000: dist 0.32 loss 36.54
# step  499/1000: dist 0.32 loss 15.67
# step  500/1000: dist 0.32 loss 4.39
# step  501/1000: dist 0.32 loss 11.30
# step  502/1000: dist 0.32 loss 21.45
# step  503/1000: dist 0.32 loss 19.80
# step  504/1000: dist 0.32 loss 11.86
# step  505/1000: dist 0.32 loss 16.21
# step  506/1000: dist 0.32 loss 30.77
# step  507/1000: dist 0.32 loss 33.81
# step  508/1000: dist 0.32 loss 19.60
# step  509/1000: dist 0.32 loss 7.64
# step  510/1000: dist 0.32 loss 8.45
# step  511/1000: dist 0.32 loss 13.18
# step  512/1000: dist 0.32 loss 14.16
# step  513/1000: dist 0.32 loss 11.00
# step  514/1000: dist 0.32 loss 8.76
# step  515/1000: dist 0.32 loss 12.93
# step  516/1000: dist 0.32 loss 19.13
# step  517/1000: dist 0.32 loss 19.36
# step  518/1000: dist 0.32 loss 16.71
# step  519/1000: dist 0.32 loss 14.67
# step  520/1000: dist 0.32 loss 8.87
# step  521/1000: dist 0.32 loss 2.77
# step  522/1000: dist 0.32 loss 5.71
# step  523/1000: dist 0.32 loss 11.80
# step  524/1000: dist 0.32 loss 10.53
# step  525/1000: dist 0.32 loss 7.46
# step  526/1000: dist 0.32 loss 10.99
# step  527/1000: dist 0.32 loss 18.11
# step  528/1000: dist 0.32 loss 24.00
# step  529/1000: dist 0.32 loss 24.16
# step  530/1000: dist 0.31 loss 14.49
# step  531/1000: dist 0.32 loss 3.52
# step  532/1000: dist 0.32 loss 4.23
# step  533/1000: dist 0.32 loss 11.26
# step  534/1000: dist 0.32 loss 11.27
# step  535/1000: dist 0.32 loss 5.05
# step  536/1000: dist 0.32 loss 2.70
# step  537/1000: dist 0.32 loss 5.69
# step  538/1000: dist 0.32 loss 6.91
# step  539/1000: dist 0.31 loss 3.90
# step  540/1000: dist 0.31 loss 1.96
# step  541/1000: dist 0.32 loss 3.79
# step  542/1000: dist 0.31 loss 4.67
# step  543/1000: dist 0.31 loss 2.31
# step  544/1000: dist 0.32 loss 1.44
# step  545/1000: dist 0.31 loss 3.35
# step  546/1000: dist 0.31 loss 3.33
# step  547/1000: dist 0.32 loss 1.47
# step  548/1000: dist 0.31 loss 2.18
# step  549/1000: dist 0.31 loss 4.22
# step  550/1000: dist 0.31 loss 4.31
# step  551/1000: dist 0.31 loss 5.05
# step  552/1000: dist 0.32 loss 9.37
# step  553/1000: dist 0.31 loss 15.13
# step  554/1000: dist 0.31 loss 21.32
# step  555/1000: dist 0.31 loss 29.01
# step  556/1000: dist 0.31 loss 34.81
# step  557/1000: dist 0.31 loss 32.56
# step  558/1000: dist 0.31 loss 24.13
# step  559/1000: dist 0.31 loss 16.92
# step  560/1000: dist 0.31 loss 13.31
# step  561/1000: dist 0.31 loss 12.06
# step  562/1000: dist 0.31 loss 12.42
# step  563/1000: dist 0.32 loss 12.72
# step  564/1000: dist 0.31 loss 12.02
# step  565/1000: dist 0.31 loss 12.35
# step  566/1000: dist 0.31 loss 16.97
# step  567/1000: dist 0.31 loss 25.18
# step  568/1000: dist 0.31 loss 29.56
# step  569/1000: dist 0.31 loss 23.40
# step  570/1000: dist 0.31 loss 10.16
# step  571/1000: dist 0.31 loss 4.53
# step  572/1000: dist 0.31 loss 10.02
# step  573/1000: dist 0.31 loss 14.11
# step  574/1000: dist 0.31 loss 8.93
# step  575/1000: dist 0.31 loss 3.38
# step  576/1000: dist 0.31 loss 6.34
# step  577/1000: dist 0.31 loss 9.70
# step  578/1000: dist 0.31 loss 6.22
# step  579/1000: dist 0.31 loss 4.18
# step  580/1000: dist 0.31 loss 8.64
# step  581/1000: dist 0.31 loss 11.82
# step  582/1000: dist 0.31 loss 12.35
# step  583/1000: dist 0.31 loss 17.09
# step  584/1000: dist 0.31 loss 23.60
# step  585/1000: dist 0.31 loss 24.83
# step  586/1000: dist 0.31 loss 23.74
# step  587/1000: dist 0.31 loss 22.27
# step  588/1000: dist 0.31 loss 16.77
# step  589/1000: dist 0.31 loss 9.57
# step  590/1000: dist 0.31 loss 8.24
# step  591/1000: dist 0.31 loss 10.59
# step  592/1000: dist 0.31 loss 10.58
# step  593/1000: dist 0.31 loss 7.85
# step  594/1000: dist 0.31 loss 4.75
# step  595/1000: dist 0.31 loss 4.94
# step  596/1000: dist 0.31 loss 7.45
# step  597/1000: dist 0.31 loss 6.12
# step  598/1000: dist 0.31 loss 1.94
# step  599/1000: dist 0.31 loss 2.56
# step  600/1000: dist 0.31 loss 5.91
# step  601/1000: dist 0.31 loss 4.20
# step  602/1000: dist 0.31 loss 0.68
# step  603/1000: dist 0.31 loss 2.12
# step  604/1000: dist 0.31 loss 4.38
# step  605/1000: dist 0.31 loss 2.54
# step  606/1000: dist 0.31 loss 0.78
# step  607/1000: dist 0.31 loss 2.12
# step  608/1000: dist 0.31 loss 2.99
# step  609/1000: dist 0.31 loss 1.93
# step  610/1000: dist 0.31 loss 1.64
# step  611/1000: dist 0.31 loss 2.58
# step  612/1000: dist 0.31 loss 3.05
# step  613/1000: dist 0.31 loss 3.32
# step  614/1000: dist 0.31 loss 4.40
# step  615/1000: dist 0.31 loss 5.85
# step  616/1000: dist 0.31 loss 7.31
# step  617/1000: dist 0.31 loss 9.16
# step  618/1000: dist 0.31 loss 10.68
# step  619/1000: dist 0.31 loss 10.66
# step  620/1000: dist 0.31 loss 9.81
# step  621/1000: dist 0.31 loss 9.51
# step  622/1000: dist 0.31 loss 10.20
# step  623/1000: dist 0.31 loss 11.91
# step  624/1000: dist 0.31 loss 13.36
# step  625/1000: dist 0.31 loss 11.73
# step  626/1000: dist 0.31 loss 6.69
# step  627/1000: dist 0.31 loss 2.45
# step  628/1000: dist 0.31 loss 2.34
# step  629/1000: dist 0.31 loss 4.68
# step  630/1000: dist 0.31 loss 5.77
# step  631/1000: dist 0.31 loss 4.30
# step  632/1000: dist 0.30 loss 2.32
# step  633/1000: dist 0.31 loss 2.01
# step  634/1000: dist 0.31 loss 2.89
# step  635/1000: dist 0.31 loss 2.99
# step  636/1000: dist 0.31 loss 1.96
# step  637/1000: dist 0.31 loss 1.44
# step  638/1000: dist 0.31 loss 2.15
# step  639/1000: dist 0.31 loss 2.76
# step  640/1000: dist 0.30 loss 2.47
# step  641/1000: dist 0.30 loss 2.48
# step  642/1000: dist 0.30 loss 4.08
# step  643/1000: dist 0.31 loss 7.06
# step  644/1000: dist 0.30 loss 10.72
# step  645/1000: dist 0.30 loss 14.75
# step  646/1000: dist 0.30 loss 17.50
# step  647/1000: dist 0.30 loss 15.38
# step  648/1000: dist 0.30 loss 7.85
# step  649/1000: dist 0.30 loss 1.62
# step  650/1000: dist 0.30 loss 2.77
# step  651/1000: dist 0.30 loss 7.91
# step  652/1000: dist 0.30 loss 9.20
# step  653/1000: dist 0.30 loss 6.05
# step  654/1000: dist 0.30 loss 5.98
# step  655/1000: dist 0.30 loss 11.33
# step  656/1000: dist 0.30 loss 14.54
# step  657/1000: dist 0.30 loss 11.19
# step  658/1000: dist 0.30 loss 8.02
# step  659/1000: dist 0.30 loss 12.17
# step  660/1000: dist 0.30 loss 21.18
# step  661/1000: dist 0.30 loss 29.59
# step  662/1000: dist 0.30 loss 34.17
# step  663/1000: dist 0.30 loss 29.68
# step  664/1000: dist 0.30 loss 15.57
# step  665/1000: dist 0.30 loss 4.28
# step  666/1000: dist 0.30 loss 7.22
# step  667/1000: dist 0.30 loss 18.22
# step  668/1000: dist 0.30 loss 23.88
# step  669/1000: dist 0.30 loss 22.29
# step  670/1000: dist 0.30 loss 21.88
# step  671/1000: dist 0.30 loss 24.19
# step  672/1000: dist 0.30 loss 20.69
# step  673/1000: dist 0.30 loss 10.33
# step  674/1000: dist 0.30 loss 4.34
# step  675/1000: dist 0.30 loss 8.37
# step  676/1000: dist 0.30 loss 13.30
# step  677/1000: dist 0.30 loss 9.71
# step  678/1000: dist 0.30 loss 3.46
# step  679/1000: dist 0.30 loss 4.18
# step  680/1000: dist 0.30 loss 7.76
# step  681/1000: dist 0.30 loss 6.10
# step  682/1000: dist 0.30 loss 2.74
# step  683/1000: dist 0.30 loss 3.46
# step  684/1000: dist 0.30 loss 4.69
# step  685/1000: dist 0.30 loss 3.21
# step  686/1000: dist 0.30 loss 2.53
# step  687/1000: dist 0.30 loss 3.35
# step  688/1000: dist 0.30 loss 2.85
# step  689/1000: dist 0.30 loss 2.48
# step  690/1000: dist 0.30 loss 4.04
# step  691/1000: dist 0.30 loss 5.23
# step  692/1000: dist 0.30 loss 6.32
# step  693/1000: dist 0.30 loss 10.72
# step  694/1000: dist 0.30 loss 16.94
# step  695/1000: dist 0.30 loss 20.81
# step  696/1000: dist 0.30 loss 19.58
# step  697/1000: dist 0.30 loss 12.50
# step  698/1000: dist 0.30 loss 3.42
# step  699/1000: dist 0.30 loss 1.36
# step  700/1000: dist 0.30 loss 7.07
# step  701/1000: dist 0.30 loss 10.33
# step  702/1000: dist 0.30 loss 5.67
# step  703/1000: dist 0.30 loss 0.92
# step  704/1000: dist 0.30 loss 2.84
# step  705/1000: dist 0.30 loss 5.92
# step  706/1000: dist 0.30 loss 4.10
# step  707/1000: dist 0.30 loss 1.12
# step  708/1000: dist 0.30 loss 1.99
# step  709/1000: dist 0.30 loss 3.78
# step  710/1000: dist 0.30 loss 2.46
# step  711/1000: dist 0.30 loss 0.70
# step  712/1000: dist 0.30 loss 1.69
# step  713/1000: dist 0.30 loss 2.71
# step  714/1000: dist 0.30 loss 1.39
# step  715/1000: dist 0.30 loss 0.51
# step  716/1000: dist 0.30 loss 1.51
# step  717/1000: dist 0.30 loss 1.75
# step  718/1000: dist 0.30 loss 0.68
# step  719/1000: dist 0.30 loss 0.65
# step  720/1000: dist 0.30 loss 1.40
# step  721/1000: dist 0.30 loss 1.05
# step  722/1000: dist 0.30 loss 0.41
# step  723/1000: dist 0.30 loss 0.84
# step  724/1000: dist 0.30 loss 1.29
# step  725/1000: dist 0.30 loss 1.06
# step  726/1000: dist 0.30 loss 1.46
# step  727/1000: dist 0.30 loss 3.03
# step  728/1000: dist 0.30 loss 5.40
# step  729/1000: dist 0.30 loss 9.91
# step  730/1000: dist 0.30 loss 18.22
# step  731/1000: dist 0.30 loss 28.51
# step  732/1000: dist 0.30 loss 31.07
# step  733/1000: dist 0.30 loss 18.69
# step  734/1000: dist 0.30 loss 2.63
# step  735/1000: dist 0.30 loss 3.60
# step  736/1000: dist 0.30 loss 14.35
# step  737/1000: dist 0.30 loss 12.09
# step  738/1000: dist 0.30 loss 1.59
# step  739/1000: dist 0.30 loss 3.72
# step  740/1000: dist 0.30 loss 9.98
# step  741/1000: dist 0.30 loss 4.71
# step  742/1000: dist 0.30 loss 1.34
# step  743/1000: dist 0.30 loss 7.09
# step  744/1000: dist 0.30 loss 6.98
# step  745/1000: dist 0.30 loss 4.72
# step  746/1000: dist 0.30 loss 11.42
# step  747/1000: dist 0.30 loss 17.04
# step  748/1000: dist 0.30 loss 19.65
# step  749/1000: dist 0.30 loss 24.15
# step  750/1000: dist 0.30 loss 19.09
# step  751/1000: dist 0.30 loss 5.71
# step  752/1000: dist 0.30 loss 2.27
# step  753/1000: dist 0.30 loss 7.53
# step  754/1000: dist 0.30 loss 11.37
# step  755/1000: dist 0.30 loss 10.53
# step  756/1000: dist 0.30 loss 5.63
# step  757/1000: dist 0.30 loss 6.58
# step  758/1000: dist 0.30 loss 15.39
# step  759/1000: dist 0.30 loss 20.35
# step  760/1000: dist 0.30 loss 23.01
# step  761/1000: dist 0.30 loss 32.90
# step  762/1000: dist 0.30 loss 43.09
# step  763/1000: dist 0.30 loss 42.72
# step  764/1000: dist 0.30 loss 30.03
# step  765/1000: dist 0.30 loss 17.09
# step  766/1000: dist 0.30 loss 19.15
# step  767/1000: dist 0.30 loss 26.40
# step  768/1000: dist 0.30 loss 19.97
# step  769/1000: dist 0.30 loss 5.86
# step  770/1000: dist 0.30 loss 3.87
# step  771/1000: dist 0.30 loss 12.91
# step  772/1000: dist 0.30 loss 13.97
# step  773/1000: dist 0.30 loss 6.42
# step  774/1000: dist 0.30 loss 5.38
# step  775/1000: dist 0.30 loss 7.26
# step  776/1000: dist 0.30 loss 5.42
# step  777/1000: dist 0.30 loss 6.88
# step  778/1000: dist 0.30 loss 8.49
# step  779/1000: dist 0.30 loss 6.06
# step  780/1000: dist 0.30 loss 7.89
# step  781/1000: dist 0.30 loss 11.24
# step  782/1000: dist 0.30 loss 9.63
# step  783/1000: dist 0.30 loss 8.42
# step  784/1000: dist 0.30 loss 6.74
# step  785/1000: dist 0.30 loss 2.47
# step  786/1000: dist 0.30 loss 1.91
# step  787/1000: dist 0.30 loss 3.43
# step  788/1000: dist 0.30 loss 3.18
# step  789/1000: dist 0.30 loss 3.78
# step  790/1000: dist 0.30 loss 3.27
# step  791/1000: dist 0.30 loss 1.14
# step  792/1000: dist 0.29 loss 1.26
# step  793/1000: dist 0.30 loss 2.14
# step  794/1000: dist 0.30 loss 2.14
# step  795/1000: dist 0.30 loss 1.77
# step  796/1000: dist 0.30 loss 0.70
# step  797/1000: dist 0.30 loss 0.84
# step  798/1000: dist 0.30 loss 1.78
# step  799/1000: dist 0.30 loss 1.16
# step  800/1000: dist 0.30 loss 0.55
# step  801/1000: dist 0.29 loss 0.82
# step  802/1000: dist 0.29 loss 0.97
# step  803/1000: dist 0.30 loss 0.87
# step  804/1000: dist 0.29 loss 0.56
# step  805/1000: dist 0.29 loss 0.57
# step  806/1000: dist 0.29 loss 0.75
# step  807/1000: dist 0.29 loss 0.59
# step  808/1000: dist 0.29 loss 0.51
# step  809/1000: dist 0.29 loss 0.49
# step  810/1000: dist 0.29 loss 0.52
# step  811/1000: dist 0.29 loss 0.55
# step  812/1000: dist 0.29 loss 0.38
# step  813/1000: dist 0.30 loss 0.42
# step  814/1000: dist 0.29 loss 0.50
# step  815/1000: dist 0.30 loss 0.38
# step  816/1000: dist 0.29 loss 0.37
# step  817/1000: dist 0.29 loss 0.41
# step  818/1000: dist 0.29 loss 0.40
# step  819/1000: dist 0.29 loss 0.34
# step  820/1000: dist 0.29 loss 0.36
# step  821/1000: dist 0.29 loss 0.39
# step  822/1000: dist 0.29 loss 0.32
# step  823/1000: dist 0.29 loss 0.34
# step  824/1000: dist 0.30 loss 0.36
# step  825/1000: dist 0.29 loss 0.31
# step  826/1000: dist 0.29 loss 0.32
# step  827/1000: dist 0.29 loss 0.34
# step  828/1000: dist 0.29 loss 0.31
# step  829/1000: dist 0.29 loss 0.31
# step  830/1000: dist 0.29 loss 0.33
# step  831/1000: dist 0.29 loss 0.31
# step  832/1000: dist 0.29 loss 0.31
# step  833/1000: dist 0.29 loss 0.32
# step  834/1000: dist 0.29 loss 0.30
# step  835/1000: dist 0.29 loss 0.30
# step  836/1000: dist 0.29 loss 0.31
# step  837/1000: dist 0.29 loss 0.30
# step  838/1000: dist 0.29 loss 0.30
# step  839/1000: dist 0.29 loss 0.30
# step  840/1000: dist 0.29 loss 0.30
# step  841/1000: dist 0.29 loss 0.30
# step  842/1000: dist 0.29 loss 0.30
# step  843/1000: dist 0.29 loss 0.30
# step  844/1000: dist 0.29 loss 0.30
# step  845/1000: dist 0.29 loss 0.29
# step  846/1000: dist 0.29 loss 0.30
# step  847/1000: dist 0.29 loss 0.30
# step  848/1000: dist 0.29 loss 0.30
# step  849/1000: dist 0.29 loss 0.30
# step  850/1000: dist 0.29 loss 0.30
# step  851/1000: dist 0.29 loss 0.30
# step  852/1000: dist 0.29 loss 0.30
# step  853/1000: dist 0.29 loss 0.29
# step  854/1000: dist 0.29 loss 0.30
# step  855/1000: dist 0.29 loss 0.29
# step  856/1000: dist 0.29 loss 0.29
# step  857/1000: dist 0.29 loss 0.29
# step  858/1000: dist 0.29 loss 0.29
# step  859/1000: dist 0.29 loss 0.29
# step  860/1000: dist 0.29 loss 0.29
# step  861/1000: dist 0.29 loss 0.29
# step  862/1000: dist 0.29 loss 0.29
# step  863/1000: dist 0.29 loss 0.29
# step  864/1000: dist 0.29 loss 0.29
# step  865/1000: dist 0.29 loss 0.29
# step  866/1000: dist 0.29 loss 0.29
# step  867/1000: dist 0.29 loss 0.29
# step  868/1000: dist 0.29 loss 0.29
# step  869/1000: dist 0.29 loss 0.29
# step  870/1000: dist 0.29 loss 0.29
# step  871/1000: dist 0.29 loss 0.29
# step  872/1000: dist 0.29 loss 0.29
# step  873/1000: dist 0.29 loss 0.29
# step  874/1000: dist 0.29 loss 0.29
# step  875/1000: dist 0.29 loss 0.29
# step  876/1000: dist 0.29 loss 0.29
# step  877/1000: dist 0.29 loss 0.29
# step  878/1000: dist 0.29 loss 0.29
# step  879/1000: dist 0.29 loss 0.29
# step  880/1000: dist 0.29 loss 0.29
# step  881/1000: dist 0.29 loss 0.29
# step  882/1000: dist 0.29 loss 0.29
# step  883/1000: dist 0.29 loss 0.29
# step  884/1000: dist 0.29 loss 0.29
# step  885/1000: dist 0.29 loss 0.29
# step  886/1000: dist 0.29 loss 0.29
# step  887/1000: dist 0.29 loss 0.29
# step  888/1000: dist 0.29 loss 0.29
# step  889/1000: dist 0.29 loss 0.29
# step  890/1000: dist 0.29 loss 0.29
# step  891/1000: dist 0.29 loss 0.29
# step  892/1000: dist 0.29 loss 0.29
# step  893/1000: dist 0.29 loss 0.29
# step  894/1000: dist 0.29 loss 0.29
# step  895/1000: dist 0.29 loss 0.29
# step  896/1000: dist 0.29 loss 0.29
# step  897/1000: dist 0.29 loss 0.29
# step  898/1000: dist 0.29 loss 0.29
# step  899/1000: dist 0.29 loss 0.29
# step  900/1000: dist 0.29 loss 0.29
# step  901/1000: dist 0.29 loss 0.29
# step  902/1000: dist 0.29 loss 0.29
# step  903/1000: dist 0.29 loss 0.29
# step  904/1000: dist 0.29 loss 0.29
# step  905/1000: dist 0.29 loss 0.29
# step  906/1000: dist 0.29 loss 0.29
# step  907/1000: dist 0.29 loss 0.29
# step  908/1000: dist 0.29 loss 0.29
# step  909/1000: dist 0.29 loss 0.29
# step  910/1000: dist 0.29 loss 0.29
# step  911/1000: dist 0.29 loss 0.29
# step  912/1000: dist 0.29 loss 0.29
# step  913/1000: dist 0.29 loss 0.29
# step  914/1000: dist 0.29 loss 0.29
# step  915/1000: dist 0.29 loss 0.29
# step  916/1000: dist 0.29 loss 0.29
# step  917/1000: dist 0.29 loss 0.29
# step  918/1000: dist 0.29 loss 0.29
# step  919/1000: dist 0.29 loss 0.29
# step  920/1000: dist 0.29 loss 0.29
# step  921/1000: dist 0.29 loss 0.29
# step  922/1000: dist 0.29 loss 0.29
# step  923/1000: dist 0.29 loss 0.29
# step  924/1000: dist 0.29 loss 0.29
# step  925/1000: dist 0.29 loss 0.29
# step  926/1000: dist 0.29 loss 0.29
# step  927/1000: dist 0.29 loss 0.29
# step  928/1000: dist 0.29 loss 0.29
# step  929/1000: dist 0.29 loss 0.29
# step  930/1000: dist 0.29 loss 0.29
# step  931/1000: dist 0.29 loss 0.29
# step  932/1000: dist 0.29 loss 0.29
# step  933/1000: dist 0.29 loss 0.29
# step  934/1000: dist 0.29 loss 0.29
# step  935/1000: dist 0.29 loss 0.29
# step  936/1000: dist 0.29 loss 0.29
# step  937/1000: dist 0.29 loss 0.29
# step  938/1000: dist 0.29 loss 0.29
# step  939/1000: dist 0.29 loss 0.29
# step  940/1000: dist 0.29 loss 0.29
# step  941/1000: dist 0.29 loss 0.29
# step  942/1000: dist 0.29 loss 0.29
# step  943/1000: dist 0.29 loss 0.29
# step  944/1000: dist 0.29 loss 0.29
# step  945/1000: dist 0.29 loss 0.29
# step  946/1000: dist 0.29 loss 0.29
# step  947/1000: dist 0.29 loss 0.29
# step  948/1000: dist 0.29 loss 0.29
# step  949/1000: dist 0.29 loss 0.29
# step  950/1000: dist 0.29 loss 0.29
# step  951/1000: dist 0.29 loss 0.29
# step  952/1000: dist 0.29 loss 0.29
# step  953/1000: dist 0.29 loss 0.29
# step  954/1000: dist 0.29 loss 0.29
# step  955/1000: dist 0.29 loss 0.29
# step  956/1000: dist 0.29 loss 0.29
# step  957/1000: dist 0.29 loss 0.29
# step  958/1000: dist 0.29 loss 0.29
# step  959/1000: dist 0.29 loss 0.29
# step  960/1000: dist 0.29 loss 0.29
# step  961/1000: dist 0.29 loss 0.29
# step  962/1000: dist 0.29 loss 0.29
# step  963/1000: dist 0.29 loss 0.29
# step  964/1000: dist 0.29 loss 0.29
# step  965/1000: dist 0.29 loss 0.29
# step  966/1000: dist 0.29 loss 0.29
# step  967/1000: dist 0.29 loss 0.29
# step  968/1000: dist 0.29 loss 0.29
# step  969/1000: dist 0.29 loss 0.29
# step  970/1000: dist 0.29 loss 0.29
# step  971/1000: dist 0.29 loss 0.29
# step  972/1000: dist 0.29 loss 0.29
# step  973/1000: dist 0.29 loss 0.29
# step  974/1000: dist 0.29 loss 0.29
# step  975/1000: dist 0.29 loss 0.29
# step  976/1000: dist 0.29 loss 0.29
# step  977/1000: dist 0.29 loss 0.29
# step  978/1000: dist 0.29 loss 0.29
# step  979/1000: dist 0.29 loss 0.29
# step  980/1000: dist 0.29 loss 0.29
# step  981/1000: dist 0.29 loss 0.29
# step  982/1000: dist 0.29 loss 0.29
# step  983/1000: dist 0.29 loss 0.29
# step  984/1000: dist 0.29 loss 0.29
# step  985/1000: dist 0.29 loss 0.29
# step  986/1000: dist 0.29 loss 0.29
# step  987/1000: dist 0.29 loss 0.29
# step  988/1000: dist 0.29 loss 0.29
# step  989/1000: dist 0.29 loss 0.29
# step  990/1000: dist 0.29 loss 0.29
# step  991/1000: dist 0.29 loss 0.29
# step  992/1000: dist 0.29 loss 0.29
# step  993/1000: dist 0.29 loss 0.29
# step  994/1000: dist 0.29 loss 0.29
# step  995/1000: dist 0.29 loss 0.29
# step  996/1000: dist 0.29 loss 0.29
# step  997/1000: dist 0.29 loss 0.29
# step  998/1000: dist 0.29 loss 0.29
# step  999/1000: dist 0.29 loss 0.29
# step 1000/1000: dist 0.29 loss 0.29
# Elapsed: 246.4 s

# %% [markdown]
# # Convert Target to a GAN
#
# Next, we convert the target to a GAN latent vector.  This process will also take several minutes.

# %%
cmd = f"python /content/stylegan2-ada-pytorch/projector.py --save-video 0 --num-steps 1000 --outdir=out_target --target=cropped_target.png --network={NETWORK}"
# !{cmd}
# Out:
# Loading networks from "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/afhqcat.pkl"...
# Downloading https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/afhqcat.pkl ... done
# Computing W midpoint and stddev using 10000 samples...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
# step    1/1000: dist 0.60 loss 24566.36
# step    2/1000: dist 0.63 loss 27639.75
# step    3/1000: dist 0.65 loss 27166.90
# step    4/1000: dist 0.64 loss 26251.34
# step    5/1000: dist 0.58 loss 24955.40
# step    6/1000: dist 0.63 loss 23353.00
# step    7/1000: dist 0.59 loss 21511.21
# step    8/1000: dist 0.63 loss 19484.66
# step    9/1000: dist 0.57 loss 17338.62
# step   10/1000: dist 0.57 loss 15137.80
# step   11/1000: dist 0.56 loss 12948.33
# step   12/1000: dist 0.57 loss 10817.59
# step   13/1000: dist 0.57 loss 8800.51
# step   14/1000: dist 0.55 loss 6945.34
# step   15/1000: dist 0.59 loss 5313.95
# step   16/1000: dist 0.59 loss 3969.27
# step   17/1000: dist 0.55 loss 2941.61
# step   18/1000: dist 0.55 loss 2214.50
# step   19/1000: dist 0.54 loss 1757.51
# step   20/1000: dist 0.51 loss 1565.53
# step   21/1000: dist 0.55 loss 1601.32
# step   22/1000: dist 0.49 loss 1786.53
# step   23/1000: dist 0.49 loss 2051.87
# step   24/1000: dist 0.53 loss 2327.63
# step   25/1000: dist 0.48 loss 2536.09
# step   26/1000: dist 0.50 loss 2634.89
# step   27/1000: dist 0.51 loss 2601.85
# step   28/1000: dist 0.48 loss 2474.06
# step   29/1000: dist 0.47 loss 2313.71
# step   30/1000: dist 0.47 loss 2119.44
# step   31/1000: dist 0.47 loss 1879.57
# step   32/1000: dist 0.46 loss 1620.50
# step   33/1000: dist 0.48 loss 1382.60
# step   34/1000: dist 0.47 loss 1181.44
# step   35/1000: dist 0.46 loss 1022.52
# step   36/1000: dist 0.43 loss 903.75
# step   37/1000: dist 0.45 loss 827.39
# step   38/1000: dist 0.45 loss 809.84
# step   39/1000: dist 0.43 loss 815.00
# step   40/1000: dist 0.43 loss 833.57
# step   41/1000: dist 0.44 loss 833.68
# step   42/1000: dist 0.41 loss 763.07
# step   43/1000: dist 0.40 loss 650.55
# step   44/1000: dist 0.43 loss 524.03
# step   45/1000: dist 0.42 loss 403.29
# step   46/1000: dist 0.42 loss 317.07
# step   47/1000: dist 0.40 loss 261.74
# step   48/1000: dist 0.42 loss 241.72
# step   49/1000: dist 0.44 loss 253.45
# step   50/1000: dist 0.40 loss 301.85
# step   51/1000: dist 0.41 loss 364.17
# step   52/1000: dist 0.42 loss 390.65
# step   53/1000: dist 0.41 loss 374.80
# step   54/1000: dist 0.42 loss 336.28
# step   55/1000: dist 0.41 loss 269.40
# step   56/1000: dist 0.41 loss 188.07
# step   57/1000: dist 0.41 loss 118.70
# step   58/1000: dist 0.41 loss 69.37
# step   59/1000: dist 0.44 loss 48.88
# step   60/1000: dist 0.40 loss 46.74
# step   61/1000: dist 0.40 loss 56.32
# step   62/1000: dist 0.40 loss 80.49
# step   63/1000: dist 0.41 loss 107.36
# step   64/1000: dist 0.41 loss 121.22
# step   65/1000: dist 0.40 loss 124.49
# step   66/1000: dist 0.40 loss 115.17
# step   67/1000: dist 0.39 loss 94.78
# step   68/1000: dist 0.40 loss 68.41
# step   69/1000: dist 0.42 loss 45.07
# step   70/1000: dist 0.40 loss 26.25
# step   71/1000: dist 0.39 loss 15.98
# step   72/1000: dist 0.41 loss 15.29
# step   73/1000: dist 0.39 loss 19.39
# step   74/1000: dist 0.38 loss 24.67
# step   75/1000: dist 0.38 loss 31.45
# step   76/1000: dist 0.39 loss 33.84
# step   77/1000: dist 0.42 loss 31.78
# step   78/1000: dist 0.39 loss 29.00
# step   79/1000: dist 0.41 loss 26.96
# step   80/1000: dist 0.44 loss 25.17
# step   81/1000: dist 0.41 loss 21.47
# step   82/1000: dist 0.38 loss 14.01
# step   83/1000: dist 0.38 loss 9.97
# step   84/1000: dist 0.39 loss 13.11
# step   85/1000: dist 0.39 loss 15.53
# step   86/1000: dist 0.37 loss 13.02
# step   87/1000: dist 0.38 loss 11.78
# step   88/1000: dist 0.38 loss 12.81
# step   89/1000: dist 0.39 loss 12.12
# step   90/1000: dist 0.38 loss 9.62
# step   91/1000: dist 0.40 loss 7.87
# step   92/1000: dist 0.37 loss 7.50
# step   93/1000: dist 0.38 loss 8.71
# step   94/1000: dist 0.37 loss 11.99
# step   95/1000: dist 0.36 loss 15.86
# step   96/1000: dist 0.38 loss 17.40
# step   97/1000: dist 0.38 loss 14.11
# step   98/1000: dist 0.37 loss 7.84
# step   99/1000: dist 0.37 loss 3.93
# step  100/1000: dist 0.38 loss 4.64
# step  101/1000: dist 0.37 loss 6.87
# step  102/1000: dist 0.37 loss 6.41
# step  103/1000: dist 0.35 loss 3.65
# step  104/1000: dist 0.36 loss 2.88
# step  105/1000: dist 0.37 loss 5.04
# step  106/1000: dist 0.35 loss 6.57
# step  107/1000: dist 0.36 loss 5.74
# step  108/1000: dist 0.38 loss 4.85
# step  109/1000: dist 0.35 loss 5.35
# step  110/1000: dist 0.36 loss 5.41
# step  111/1000: dist 0.37 loss 3.95
# step  112/1000: dist 0.36 loss 2.81
# step  113/1000: dist 0.35 loss 3.20
# step  114/1000: dist 0.36 loss 3.97
# step  115/1000: dist 0.36 loss 3.89
# step  116/1000: dist 0.37 loss 3.62
# step  117/1000: dist 0.36 loss 3.85
# step  118/1000: dist 0.37 loss 3.99
# step  119/1000: dist 0.38 loss 3.43
# step  120/1000: dist 0.40 loss 2.69
# step  121/1000: dist 0.35 loss 2.24
# step  122/1000: dist 0.36 loss 1.94
# step  123/1000: dist 0.35 loss 1.63
# step  124/1000: dist 0.36 loss 1.91
# step  125/1000: dist 0.36 loss 2.82
# step  126/1000: dist 0.37 loss 3.52
# step  127/1000: dist 0.36 loss 3.33
# step  128/1000: dist 0.36 loss 2.75
# step  129/1000: dist 0.37 loss 2.60
# step  130/1000: dist 0.37 loss 2.90
# step  131/1000: dist 0.36 loss 3.05
# step  132/1000: dist 0.37 loss 2.77
# step  133/1000: dist 0.36 loss 2.22
# step  134/1000: dist 0.36 loss 1.69
# step  135/1000: dist 0.34 loss 1.28
# step  136/1000: dist 0.35 loss 1.02
# step  137/1000: dist 0.35 loss 1.00
# step  138/1000: dist 0.34 loss 1.28
# step  139/1000: dist 0.35 loss 1.69
# step  140/1000: dist 0.35 loss 2.01
# step  141/1000: dist 0.36 loss 2.17
# step  142/1000: dist 0.36 loss 2.36
# step  143/1000: dist 0.34 loss 2.89
# step  144/1000: dist 0.35 loss 4.09
# step  145/1000: dist 0.33 loss 6.03
# step  146/1000: dist 0.33 loss 8.25
# step  147/1000: dist 0.33 loss 9.02
# step  148/1000: dist 0.33 loss 6.69
# step  149/1000: dist 0.34 loss 2.94
# step  150/1000: dist 0.35 loss 1.89
# step  151/1000: dist 0.35 loss 4.38
# step  152/1000: dist 0.36 loss 7.04
# step  153/1000: dist 0.35 loss 7.25
# step  154/1000: dist 0.33 loss 7.40
# step  155/1000: dist 0.34 loss 12.13
# step  156/1000: dist 0.36 loss 21.74
# step  157/1000: dist 0.33 loss 29.34
# step  158/1000: dist 0.34 loss 25.16
# step  159/1000: dist 0.34 loss 13.25
# step  160/1000: dist 0.34 loss 12.11
# step  161/1000: dist 0.35 loss 21.26
# step  162/1000: dist 0.36 loss 23.76
# step  163/1000: dist 0.34 loss 20.21
# step  164/1000: dist 0.34 loss 21.72
# step  165/1000: dist 0.37 loss 20.23
# step  166/1000: dist 0.34 loss 10.59
# step  167/1000: dist 0.34 loss 8.80
# step  168/1000: dist 0.35 loss 15.49
# step  169/1000: dist 0.34 loss 14.00
# step  170/1000: dist 0.35 loss 6.74
# step  171/1000: dist 0.35 loss 5.18
# step  172/1000: dist 0.32 loss 7.39
# step  173/1000: dist 0.35 loss 9.57
# step  174/1000: dist 0.33 loss 9.64
# step  175/1000: dist 0.34 loss 5.15
# step  176/1000: dist 0.35 loss 2.56
# step  177/1000: dist 0.35 loss 6.30
# step  178/1000: dist 0.35 loss 8.13
# step  179/1000: dist 0.34 loss 5.22
# step  180/1000: dist 0.33 loss 4.21
# step  181/1000: dist 0.33 loss 5.20
# step  182/1000: dist 0.34 loss 4.86
# step  183/1000: dist 0.33 loss 4.32
# step  184/1000: dist 0.33 loss 4.22
# step  185/1000: dist 0.33 loss 4.62
# step  186/1000: dist 0.33 loss 7.06
# step  187/1000: dist 0.32 loss 11.20
# step  188/1000: dist 0.32 loss 16.27
# step  189/1000: dist 0.32 loss 21.20
# step  190/1000: dist 0.33 loss 20.40
# step  191/1000: dist 0.35 loss 11.59
# step  192/1000: dist 0.33 loss 7.20
# step  193/1000: dist 0.32 loss 14.39
# step  194/1000: dist 0.32 loss 21.48
# step  195/1000: dist 0.32 loss 17.39
# step  196/1000: dist 0.35 loss 8.97
# step  197/1000: dist 0.33 loss 7.32
# step  198/1000: dist 0.32 loss 9.28
# step  199/1000: dist 0.31 loss 8.48
# step  200/1000: dist 0.33 loss 7.54
# step  201/1000: dist 0.31 loss 8.13
# step  202/1000: dist 0.32 loss 8.42
# step  203/1000: dist 0.32 loss 9.34
# step  204/1000: dist 0.34 loss 11.06
# step  205/1000: dist 0.33 loss 10.86
# step  206/1000: dist 0.31 loss 9.35
# step  207/1000: dist 0.33 loss 7.96
# step  208/1000: dist 0.31 loss 4.74
# step  209/1000: dist 0.31 loss 1.94
# step  210/1000: dist 0.31 loss 4.08
# step  211/1000: dist 0.31 loss 7.12
# step  212/1000: dist 0.32 loss 4.94
# step  213/1000: dist 0.31 loss 1.55
# step  214/1000: dist 0.32 loss 2.37
# step  215/1000: dist 0.32 loss 4.06
# step  216/1000: dist 0.32 loss 3.49
# step  217/1000: dist 0.32 loss 2.82
# step  218/1000: dist 0.32 loss 3.02
# step  219/1000: dist 0.33 loss 3.19
# step  220/1000: dist 0.33 loss 4.35
# step  221/1000: dist 0.34 loss 7.11
# step  222/1000: dist 0.33 loss 10.03
# step  223/1000: dist 0.33 loss 12.59
# step  224/1000: dist 0.33 loss 13.64
# step  225/1000: dist 0.33 loss 10.70
# step  226/1000: dist 0.33 loss 5.49
# step  227/1000: dist 0.31 loss 4.38
# step  228/1000: dist 0.31 loss 7.99
# step  229/1000: dist 0.32 loss 9.82
# step  230/1000: dist 0.31 loss 6.17
# step  231/1000: dist 0.32 loss 1.94
# step  232/1000: dist 0.33 loss 2.19
# step  233/1000: dist 0.32 loss 4.24
# step  234/1000: dist 0.32 loss 3.77
# step  235/1000: dist 0.32 loss 2.28
# step  236/1000: dist 0.31 loss 2.99
# step  237/1000: dist 0.31 loss 4.32
# step  238/1000: dist 0.31 loss 3.42
# step  239/1000: dist 0.31 loss 1.89
# step  240/1000: dist 0.32 loss 2.45
# step  241/1000: dist 0.32 loss 3.95
# step  242/1000: dist 0.31 loss 4.40
# step  243/1000: dist 0.32 loss 4.82
# step  244/1000: dist 0.32 loss 6.27
# step  245/1000: dist 0.31 loss 6.99
# step  246/1000: dist 0.32 loss 5.39
# step  247/1000: dist 0.31 loss 2.85
# step  248/1000: dist 0.31 loss 1.48
# step  249/1000: dist 0.31 loss 1.32
# step  250/1000: dist 0.31 loss 1.70
# step  251/1000: dist 0.32 loss 2.52
# step  252/1000: dist 0.34 loss 3.39
# step  253/1000: dist 0.32 loss 3.28
# step  254/1000: dist 0.32 loss 2.39
# step  255/1000: dist 0.32 loss 2.14
# step  256/1000: dist 0.32 loss 3.25
# step  257/1000: dist 0.31 loss 5.13
# step  258/1000: dist 0.30 loss 6.88
# step  259/1000: dist 0.31 loss 8.01
# step  260/1000: dist 0.32 loss 7.74
# step  261/1000: dist 0.32 loss 5.62
# step  262/1000: dist 0.31 loss 2.63
# step  263/1000: dist 0.32 loss 1.12
# step  264/1000: dist 0.29 loss 1.88
# step  265/1000: dist 0.31 loss 3.53
# step  266/1000: dist 0.31 loss 4.07
# step  267/1000: dist 0.30 loss 3.01
# step  268/1000: dist 0.31 loss 1.89
# step  269/1000: dist 0.32 loss 2.52
# step  270/1000: dist 0.30 loss 5.38
# step  271/1000: dist 0.31 loss 10.02
# step  272/1000: dist 0.30 loss 16.11
# step  273/1000: dist 0.31 loss 22.68
# step  274/1000: dist 0.33 loss 24.51
# step  275/1000: dist 0.33 loss 19.27
# step  276/1000: dist 0.32 loss 16.31
# step  277/1000: dist 0.30 loss 21.61
# step  278/1000: dist 0.32 loss 25.13
# step  279/1000: dist 0.29 loss 20.57
# step  280/1000: dist 0.31 loss 18.60
# step  281/1000: dist 0.35 loss 22.12
# step  282/1000: dist 0.31 loss 18.29
# step  283/1000: dist 0.31 loss 8.66
# step  284/1000: dist 0.30 loss 11.17
# step  285/1000: dist 0.31 loss 23.62
# step  286/1000: dist 0.31 loss 25.67
# step  287/1000: dist 0.30 loss 19.49
# step  288/1000: dist 0.30 loss 20.38
# step  289/1000: dist 0.30 loss 22.99
# step  290/1000: dist 0.30 loss 19.01
# step  291/1000: dist 0.29 loss 16.89
# step  292/1000: dist 0.31 loss 19.15
# step  293/1000: dist 0.31 loss 15.07
# step  294/1000: dist 0.32 loss 5.88
# step  295/1000: dist 0.31 loss 3.97
# step  296/1000: dist 0.30 loss 9.45
# step  297/1000: dist 0.29 loss 12.05
# step  298/1000: dist 0.29 loss 8.26
# step  299/1000: dist 0.30 loss 3.75
# step  300/1000: dist 0.32 loss 3.67
# step  301/1000: dist 0.30 loss 5.82
# step  302/1000: dist 0.32 loss 5.72
# step  303/1000: dist 0.31 loss 4.08
# step  304/1000: dist 0.30 loss 3.70
# step  305/1000: dist 0.29 loss 3.40
# step  306/1000: dist 0.31 loss 2.38
# step  307/1000: dist 0.32 loss 2.67
# step  308/1000: dist 0.31 loss 3.75
# step  309/1000: dist 0.31 loss 2.94
# step  310/1000: dist 0.30 loss 1.27
# step  311/1000: dist 0.29 loss 1.41
# step  312/1000: dist 0.29 loss 2.51
# step  313/1000: dist 0.30 loss 2.67
# step  314/1000: dist 0.30 loss 2.25
# step  315/1000: dist 0.31 loss 2.41
# step  316/1000: dist 0.30 loss 3.46
# step  317/1000: dist 0.30 loss 5.22
# step  318/1000: dist 0.29 loss 7.01
# step  319/1000: dist 0.30 loss 7.71
# step  320/1000: dist 0.30 loss 6.83
# step  321/1000: dist 0.30 loss 5.48
# step  322/1000: dist 0.31 loss 5.85
# step  323/1000: dist 0.30 loss 8.89
# step  324/1000: dist 0.29 loss 12.68
# step  325/1000: dist 0.29 loss 13.41
# step  326/1000: dist 0.29 loss 8.98
# step  327/1000: dist 0.30 loss 3.38
# step  328/1000: dist 0.30 loss 2.55
# step  329/1000: dist 0.30 loss 7.56
# step  330/1000: dist 0.28 loss 14.11
# step  331/1000: dist 0.29 loss 16.47
# step  332/1000: dist 0.29 loss 11.29
# step  333/1000: dist 0.31 loss 3.97
# step  334/1000: dist 0.29 loss 4.89
# step  335/1000: dist 0.29 loss 11.92
# step  336/1000: dist 0.29 loss 13.97
# step  337/1000: dist 0.29 loss 11.21
# step  338/1000: dist 0.30 loss 13.57
# step  339/1000: dist 0.29 loss 18.00
# step  340/1000: dist 0.28 loss 13.67
# step  341/1000: dist 0.28 loss 5.97
# step  342/1000: dist 0.30 loss 8.19
# step  343/1000: dist 0.30 loss 16.35
# step  344/1000: dist 0.29 loss 18.44
# step  345/1000: dist 0.29 loss 15.03
# step  346/1000: dist 0.29 loss 13.32
# step  347/1000: dist 0.29 loss 13.65
# step  348/1000: dist 0.28 loss 11.97
# step  349/1000: dist 0.28 loss 7.84
# step  350/1000: dist 0.28 loss 4.10
# step  351/1000: dist 0.28 loss 4.09
# step  352/1000: dist 0.30 loss 7.18
# step  353/1000: dist 0.29 loss 8.07
# step  354/1000: dist 0.29 loss 4.87
# step  355/1000: dist 0.28 loss 2.32
# step  356/1000: dist 0.29 loss 3.24
# step  357/1000: dist 0.29 loss 4.55
# step  358/1000: dist 0.28 loss 4.59
# step  359/1000: dist 0.29 loss 5.17
# step  360/1000: dist 0.30 loss 6.68
# step  361/1000: dist 0.29 loss 9.02
# step  362/1000: dist 0.29 loss 14.05
# step  363/1000: dist 0.28 loss 20.48
# step  364/1000: dist 0.28 loss 20.29
# step  365/1000: dist 0.29 loss 9.82
# step  366/1000: dist 0.29 loss 0.84
# step  367/1000: dist 0.30 loss 3.89
# step  368/1000: dist 0.28 loss 10.77
# step  369/1000: dist 0.28 loss 8.76
# step  370/1000: dist 0.29 loss 1.85
# step  371/1000: dist 0.28 loss 2.11
# step  372/1000: dist 0.29 loss 6.43
# step  373/1000: dist 0.29 loss 4.90
# step  374/1000: dist 0.28 loss 1.40
# step  375/1000: dist 0.28 loss 3.23
# step  376/1000: dist 0.28 loss 5.30
# step  377/1000: dist 0.29 loss 3.61
# step  378/1000: dist 0.29 loss 4.43
# step  379/1000: dist 0.28 loss 9.45
# step  380/1000: dist 0.28 loss 14.03
# step  381/1000: dist 0.29 loss 19.76
# step  382/1000: dist 0.29 loss 28.47
# step  383/1000: dist 0.28 loss 32.37
# step  384/1000: dist 0.28 loss 28.18
# step  385/1000: dist 0.28 loss 22.85
# step  386/1000: dist 0.28 loss 21.05
# step  387/1000: dist 0.29 loss 22.42
# step  388/1000: dist 0.29 loss 23.08
# step  389/1000: dist 0.28 loss 20.68
# step  390/1000: dist 0.28 loss 18.34
# step  391/1000: dist 0.29 loss 21.43
# step  392/1000: dist 0.28 loss 26.34
# step  393/1000: dist 0.29 loss 22.28
# step  394/1000: dist 0.28 loss 10.03
# step  395/1000: dist 0.28 loss 4.36
# step  396/1000: dist 0.28 loss 9.90
# step  397/1000: dist 0.28 loss 14.86
# step  398/1000: dist 0.28 loss 10.26
# step  399/1000: dist 0.28 loss 3.33
# step  400/1000: dist 0.28 loss 4.49
# step  401/1000: dist 0.28 loss 9.24
# step  402/1000: dist 0.29 loss 7.59
# step  403/1000: dist 0.28 loss 2.64
# step  404/1000: dist 0.28 loss 3.48
# step  405/1000: dist 0.27 loss 7.18
# step  406/1000: dist 0.28 loss 6.25
# step  407/1000: dist 0.27 loss 4.02
# step  408/1000: dist 0.28 loss 6.58
# step  409/1000: dist 0.27 loss 10.12
# step  410/1000: dist 0.27 loss 10.00
# step  411/1000: dist 0.28 loss 9.04
# step  412/1000: dist 0.27 loss 8.66
# step  413/1000: dist 0.27 loss 5.87
# step  414/1000: dist 0.28 loss 1.87
# step  415/1000: dist 0.27 loss 1.30
# step  416/1000: dist 0.27 loss 3.62
# step  417/1000: dist 0.27 loss 4.81
# step  418/1000: dist 0.27 loss 3.98
# step  419/1000: dist 0.27 loss 2.64
# step  420/1000: dist 0.28 loss 1.67
# step  421/1000: dist 0.27 loss 1.69
# step  422/1000: dist 0.28 loss 2.89
# step  423/1000: dist 0.27 loss 3.86
# step  424/1000: dist 0.27 loss 3.78
# step  425/1000: dist 0.27 loss 4.18
# step  426/1000: dist 0.27 loss 6.57
# step  427/1000: dist 0.27 loss 10.01
# step  428/1000: dist 0.27 loss 12.52
# step  429/1000: dist 0.26 loss 12.32
# step  430/1000: dist 0.27 loss 8.55
# step  431/1000: dist 0.27 loss 3.31
# step  432/1000: dist 0.27 loss 1.03
# step  433/1000: dist 0.27 loss 2.96
# step  434/1000: dist 0.27 loss 5.55
# step  435/1000: dist 0.27 loss 5.11
# step  436/1000: dist 0.27 loss 2.33
# step  437/1000: dist 0.27 loss 0.95
# step  438/1000: dist 0.27 loss 2.25
# step  439/1000: dist 0.26 loss 3.65
# step  440/1000: dist 0.28 loss 3.09
# step  441/1000: dist 0.28 loss 1.89
# step  442/1000: dist 0.27 loss 2.45
# step  443/1000: dist 0.26 loss 4.57
# step  444/1000: dist 0.27 loss 6.53
# step  445/1000: dist 0.27 loss 8.43
# step  446/1000: dist 0.28 loss 11.94
# step  447/1000: dist 0.26 loss 16.70
# step  448/1000: dist 0.27 loss 19.38
# step  449/1000: dist 0.27 loss 16.56
# step  450/1000: dist 0.27 loss 9.24
# step  451/1000: dist 0.26 loss 2.87
# step  452/1000: dist 0.27 loss 2.09
# step  453/1000: dist 0.27 loss 6.09
# step  454/1000: dist 0.27 loss 9.97
# step  455/1000: dist 0.27 loss 10.06
# step  456/1000: dist 0.26 loss 8.12
# step  457/1000: dist 0.26 loss 9.43
# step  458/1000: dist 0.27 loss 15.29
# step  459/1000: dist 0.26 loss 19.72
# step  460/1000: dist 0.26 loss 15.97
# step  461/1000: dist 0.27 loss 6.50
# step  462/1000: dist 0.26 loss 2.02
# step  463/1000: dist 0.26 loss 7.26
# step  464/1000: dist 0.26 loss 15.29
# step  465/1000: dist 0.26 loss 18.73
# step  466/1000: dist 0.26 loss 19.87
# step  467/1000: dist 0.26 loss 23.11
# step  468/1000: dist 0.26 loss 21.99
# step  469/1000: dist 0.26 loss 11.12
# step  470/1000: dist 0.27 loss 2.44
# step  471/1000: dist 0.26 loss 6.61
# step  472/1000: dist 0.27 loss 13.31
# step  473/1000: dist 0.26 loss 8.94
# step  474/1000: dist 0.26 loss 1.82
# step  475/1000: dist 0.26 loss 4.42
# step  476/1000: dist 0.26 loss 8.42
# step  477/1000: dist 0.26 loss 4.52
# step  478/1000: dist 0.26 loss 1.63
# step  479/1000: dist 0.26 loss 4.89
# step  480/1000: dist 0.26 loss 5.50
# step  481/1000: dist 0.26 loss 2.75
# step  482/1000: dist 0.25 loss 3.89
# step  483/1000: dist 0.26 loss 6.38
# step  484/1000: dist 0.25 loss 6.14
# step  485/1000: dist 0.25 loss 7.48
# step  486/1000: dist 0.26 loss 10.39
# step  487/1000: dist 0.26 loss 10.46
# step  488/1000: dist 0.26 loss 8.73
# step  489/1000: dist 0.26 loss 6.79
# step  490/1000: dist 0.26 loss 3.16
# step  491/1000: dist 0.26 loss 0.85
# step  492/1000: dist 0.26 loss 2.52
# step  493/1000: dist 0.25 loss 4.72
# step  494/1000: dist 0.25 loss 5.33
# step  495/1000: dist 0.26 loss 5.63
# step  496/1000: dist 0.25 loss 5.72
# step  497/1000: dist 0.25 loss 6.81
# step  498/1000: dist 0.26 loss 11.08
# step  499/1000: dist 0.25 loss 15.91
# step  500/1000: dist 0.26 loss 15.79
# step  501/1000: dist 0.26 loss 10.23
# step  502/1000: dist 0.26 loss 3.38
# step  503/1000: dist 0.25 loss 0.86
# step  504/1000: dist 0.26 loss 3.97
# step  505/1000: dist 0.25 loss 7.55
# step  506/1000: dist 0.25 loss 6.10
# step  507/1000: dist 0.26 loss 1.68
# step  508/1000: dist 0.26 loss 0.69
# step  509/1000: dist 0.26 loss 3.34
# step  510/1000: dist 0.25 loss 4.49
# step  511/1000: dist 0.26 loss 2.37
# step  512/1000: dist 0.27 loss 0.55
# step  513/1000: dist 0.26 loss 1.51
# step  514/1000: dist 0.26 loss 2.95
# step  515/1000: dist 0.26 loss 2.26
# step  516/1000: dist 0.25 loss 1.12
# step  517/1000: dist 0.26 loss 2.01
# step  518/1000: dist 0.26 loss 3.92
# step  519/1000: dist 0.25 loss 5.55
# step  520/1000: dist 0.26 loss 9.05
# step  521/1000: dist 0.27 loss 17.16
# step  522/1000: dist 0.25 loss 29.68
# step  523/1000: dist 0.27 loss 42.07
# step  524/1000: dist 0.27 loss 45.01
# step  525/1000: dist 0.25 loss 31.77
# step  526/1000: dist 0.25 loss 18.84
# step  527/1000: dist 0.26 loss 27.69
# step  528/1000: dist 0.25 loss 45.16
# step  529/1000: dist 0.25 loss 38.10
# step  530/1000: dist 0.26 loss 9.69
# step  531/1000: dist 0.26 loss 3.00
# step  532/1000: dist 0.25 loss 21.55
# step  533/1000: dist 0.25 loss 24.21
# step  534/1000: dist 0.25 loss 5.66
# step  535/1000: dist 0.25 loss 3.12
# step  536/1000: dist 0.25 loss 16.03
# step  537/1000: dist 0.25 loss 12.24
# step  538/1000: dist 0.25 loss 0.94
# step  539/1000: dist 0.25 loss 6.27
# step  540/1000: dist 0.25 loss 11.22
# step  541/1000: dist 0.25 loss 3.33
# step  542/1000: dist 0.25 loss 2.04
# step  543/1000: dist 0.25 loss 7.46
# step  544/1000: dist 0.26 loss 4.36
# step  545/1000: dist 0.26 loss 1.12
# step  546/1000: dist 0.25 loss 4.33
# step  547/1000: dist 0.25 loss 3.97
# step  548/1000: dist 0.26 loss 1.34
# step  549/1000: dist 0.25 loss 2.53
# step  550/1000: dist 0.25 loss 2.90
# step  551/1000: dist 0.25 loss 1.56
# step  552/1000: dist 0.25 loss 1.78
# step  553/1000: dist 0.25 loss 1.89
# step  554/1000: dist 0.25 loss 1.55
# step  555/1000: dist 0.25 loss 1.74
# step  556/1000: dist 0.25 loss 1.58
# step  557/1000: dist 0.25 loss 1.97
# step  558/1000: dist 0.25 loss 3.16
# step  559/1000: dist 0.25 loss 4.34
# step  560/1000: dist 0.25 loss 7.62
# step  561/1000: dist 0.25 loss 14.10
# step  562/1000: dist 0.25 loss 22.20
# step  563/1000: dist 0.25 loss 29.50
# step  564/1000: dist 0.25 loss 29.77
# step  565/1000: dist 0.25 loss 20.43
# step  566/1000: dist 0.25 loss 11.11
# step  567/1000: dist 0.25 loss 8.90
# step  568/1000: dist 0.25 loss 10.08
# step  569/1000: dist 0.25 loss 9.34
# step  570/1000: dist 0.25 loss 7.92
# step  571/1000: dist 0.25 loss 7.79
# step  572/1000: dist 0.25 loss 6.87
# step  573/1000: dist 0.25 loss 4.69
# step  574/1000: dist 0.25 loss 4.17
# step  575/1000: dist 0.25 loss 5.62
# step  576/1000: dist 0.25 loss 5.06
# step  577/1000: dist 0.25 loss 2.57
# step  578/1000: dist 0.25 loss 2.60
# step  579/1000: dist 0.24 loss 4.39
# step  580/1000: dist 0.25 loss 3.59
# step  581/1000: dist 0.25 loss 1.93
# step  582/1000: dist 0.24 loss 3.20
# step  583/1000: dist 0.25 loss 5.21
# step  584/1000: dist 0.25 loss 5.63
# step  585/1000: dist 0.24 loss 7.47
# step  586/1000: dist 0.24 loss 12.45
# step  587/1000: dist 0.24 loss 16.80
# step  588/1000: dist 0.24 loss 17.10
# step  589/1000: dist 0.24 loss 12.45
# step  590/1000: dist 0.24 loss 5.45
# step  591/1000: dist 0.24 loss 1.31
# step  592/1000: dist 0.24 loss 3.42
# step  593/1000: dist 0.24 loss 7.79
# step  594/1000: dist 0.24 loss 7.20
# step  595/1000: dist 0.24 loss 2.30
# step  596/1000: dist 0.24 loss 0.73
# step  597/1000: dist 0.24 loss 3.98
# step  598/1000: dist 0.24 loss 5.44
# step  599/1000: dist 0.24 loss 2.88
# step  600/1000: dist 0.24 loss 1.96
# step  601/1000: dist 0.24 loss 5.26
# step  602/1000: dist 0.24 loss 8.79
# step  603/1000: dist 0.24 loss 11.12
# step  604/1000: dist 0.24 loss 15.37
# step  605/1000: dist 0.24 loss 19.61
# step  606/1000: dist 0.25 loss 16.52
# step  607/1000: dist 0.24 loss 6.24
# step  608/1000: dist 0.24 loss 0.56
# step  609/1000: dist 0.24 loss 4.57
# step  610/1000: dist 0.24 loss 9.74
# step  611/1000: dist 0.24 loss 7.90
# step  612/1000: dist 0.24 loss 2.49
# step  613/1000: dist 0.25 loss 1.87
# step  614/1000: dist 0.24 loss 5.50
# step  615/1000: dist 0.24 loss 6.67
# step  616/1000: dist 0.24 loss 4.54
# step  617/1000: dist 0.24 loss 4.76
# step  618/1000: dist 0.24 loss 9.40
# step  619/1000: dist 0.24 loss 14.85
# step  620/1000: dist 0.24 loss 20.14
# step  621/1000: dist 0.24 loss 28.44
# step  622/1000: dist 0.24 loss 38.30
# step  623/1000: dist 0.24 loss 41.41
# step  624/1000: dist 0.24 loss 34.60
# step  625/1000: dist 0.24 loss 27.59
# step  626/1000: dist 0.24 loss 30.15
# step  627/1000: dist 0.24 loss 38.50
# step  628/1000: dist 0.24 loss 40.08
# step  629/1000: dist 0.24 loss 28.85
# step  630/1000: dist 0.24 loss 14.29
# step  631/1000: dist 0.24 loss 13.25
# step  632/1000: dist 0.24 loss 21.77
# step  633/1000: dist 0.24 loss 23.16
# step  634/1000: dist 0.24 loss 18.35
# step  635/1000: dist 0.24 loss 23.39
# step  636/1000: dist 0.24 loss 35.87
# step  637/1000: dist 0.24 loss 37.89
# step  638/1000: dist 0.24 loss 33.73
# step  639/1000: dist 0.24 loss 40.66
# step  640/1000: dist 0.24 loss 47.43
# step  641/1000: dist 0.24 loss 38.07
# step  642/1000: dist 0.24 loss 28.71
# step  643/1000: dist 0.24 loss 32.54
# step  644/1000: dist 0.24 loss 34.37
# step  645/1000: dist 0.24 loss 27.72
# step  646/1000: dist 0.24 loss 23.62
# step  647/1000: dist 0.24 loss 22.98
# step  648/1000: dist 0.24 loss 17.23
# step  649/1000: dist 0.24 loss 9.77
# step  650/1000: dist 0.24 loss 9.87
# step  651/1000: dist 0.24 loss 15.36
# step  652/1000: dist 0.24 loss 14.27
# step  653/1000: dist 0.24 loss 6.91
# step  654/1000: dist 0.24 loss 5.74
# step  655/1000: dist 0.24 loss 9.55
# step  656/1000: dist 0.24 loss 8.85
# step  657/1000: dist 0.24 loss 7.25
# step  658/1000: dist 0.24 loss 9.35
# step  659/1000: dist 0.24 loss 11.00
# step  660/1000: dist 0.24 loss 12.76
# step  661/1000: dist 0.24 loss 14.50
# step  662/1000: dist 0.24 loss 9.53
# step  663/1000: dist 0.24 loss 2.52
# step  664/1000: dist 0.24 loss 3.37
# step  665/1000: dist 0.24 loss 7.32
# step  666/1000: dist 0.24 loss 6.88
# step  667/1000: dist 0.24 loss 4.17
# step  668/1000: dist 0.24 loss 2.54
# step  669/1000: dist 0.24 loss 2.81
# step  670/1000: dist 0.23 loss 4.29
# step  671/1000: dist 0.24 loss 3.91
# step  672/1000: dist 0.23 loss 1.71
# step  673/1000: dist 0.23 loss 1.53
# step  674/1000: dist 0.23 loss 2.85
# step  675/1000: dist 0.23 loss 2.61
# step  676/1000: dist 0.23 loss 1.46
# step  677/1000: dist 0.23 loss 1.15
# step  678/1000: dist 0.23 loss 1.59
# step  679/1000: dist 0.23 loss 1.93
# step  680/1000: dist 0.23 loss 1.43
# step  681/1000: dist 0.23 loss 0.80
# step  682/1000: dist 0.23 loss 1.31
# step  683/1000: dist 0.23 loss 2.16
# step  684/1000: dist 0.23 loss 2.25
# step  685/1000: dist 0.23 loss 3.03
# step  686/1000: dist 0.23 loss 5.88
# step  687/1000: dist 0.23 loss 10.56
# step  688/1000: dist 0.23 loss 16.94
# step  689/1000: dist 0.24 loss 23.54
# step  690/1000: dist 0.23 loss 24.09
# step  691/1000: dist 0.24 loss 13.88
# step  692/1000: dist 0.23 loss 2.12
# step  693/1000: dist 0.24 loss 2.37
# step  694/1000: dist 0.24 loss 10.40
# step  695/1000: dist 0.24 loss 10.58
# step  696/1000: dist 0.24 loss 2.54
# step  697/1000: dist 0.23 loss 1.19
# step  698/1000: dist 0.24 loss 6.64
# step  699/1000: dist 0.23 loss 5.73
# step  700/1000: dist 0.23 loss 0.74
# step  701/1000: dist 0.23 loss 2.24
# step  702/1000: dist 0.23 loss 4.88
# step  703/1000: dist 0.23 loss 1.96
# step  704/1000: dist 0.23 loss 0.73
# step  705/1000: dist 0.23 loss 3.25
# step  706/1000: dist 0.23 loss 2.51
# step  707/1000: dist 0.24 loss 0.73
# step  708/1000: dist 0.23 loss 2.47
# step  709/1000: dist 0.23 loss 3.25
# step  710/1000: dist 0.23 loss 2.31
# step  711/1000: dist 0.23 loss 4.13
# step  712/1000: dist 0.23 loss 6.84
# step  713/1000: dist 0.23 loss 8.32
# step  714/1000: dist 0.23 loss 11.35
# step  715/1000: dist 0.23 loss 13.87
# step  716/1000: dist 0.23 loss 11.98
# step  717/1000: dist 0.23 loss 7.00
# step  718/1000: dist 0.23 loss 2.52
# step  719/1000: dist 0.23 loss 0.66
# step  720/1000: dist 0.23 loss 2.82
# step  721/1000: dist 0.23 loss 5.88
# step  722/1000: dist 0.23 loss 4.99
# step  723/1000: dist 0.23 loss 1.71
# step  724/1000: dist 0.23 loss 0.58
# step  725/1000: dist 0.23 loss 1.91
# step  726/1000: dist 0.23 loss 3.16
# step  727/1000: dist 0.23 loss 2.55
# step  728/1000: dist 0.23 loss 0.80
# step  729/1000: dist 0.23 loss 0.45
# step  730/1000: dist 0.23 loss 1.77
# step  731/1000: dist 0.23 loss 2.08
# step  732/1000: dist 0.23 loss 0.83
# step  733/1000: dist 0.23 loss 0.31
# step  734/1000: dist 0.23 loss 1.01
# step  735/1000: dist 0.23 loss 1.36
# step  736/1000: dist 0.23 loss 0.84
# step  737/1000: dist 0.23 loss 0.35
# step  738/1000: dist 0.23 loss 0.54
# step  739/1000: dist 0.23 loss 0.94
# step  740/1000: dist 0.23 loss 0.77
# step  741/1000: dist 0.23 loss 0.30
# step  742/1000: dist 0.23 loss 0.35
# step  743/1000: dist 0.23 loss 0.70
# step  744/1000: dist 0.23 loss 0.61
# step  745/1000: dist 0.23 loss 0.29
# step  746/1000: dist 0.23 loss 0.31
# step  747/1000: dist 0.23 loss 0.51
# step  748/1000: dist 0.23 loss 0.49
# step  749/1000: dist 0.23 loss 0.31
# step  750/1000: dist 0.23 loss 0.27
# step  751/1000: dist 0.23 loss 0.38
# step  752/1000: dist 0.23 loss 0.42
# step  753/1000: dist 0.23 loss 0.31
# step  754/1000: dist 0.23 loss 0.24
# step  755/1000: dist 0.23 loss 0.31
# step  756/1000: dist 0.23 loss 0.37
# step  757/1000: dist 0.23 loss 0.29
# step  758/1000: dist 0.23 loss 0.23
# step  759/1000: dist 0.23 loss 0.28
# step  760/1000: dist 0.23 loss 0.32
# step  761/1000: dist 0.23 loss 0.28
# step  762/1000: dist 0.23 loss 0.25
# step  763/1000: dist 0.23 loss 0.27
# step  764/1000: dist 0.23 loss 0.32
# step  765/1000: dist 0.23 loss 0.34
# step  766/1000: dist 0.23 loss 0.37
# step  767/1000: dist 0.23 loss 0.46
# step  768/1000: dist 0.23 loss 0.65
# step  769/1000: dist 0.23 loss 0.95
# step  770/1000: dist 0.23 loss 1.40
# step  771/1000: dist 0.23 loss 2.19
# step  772/1000: dist 0.23 loss 3.44
# step  773/1000: dist 0.23 loss 5.18
# step  774/1000: dist 0.24 loss 7.30
# step  775/1000: dist 0.23 loss 9.17
# step  776/1000: dist 0.24 loss 9.66
# step  777/1000: dist 0.24 loss 7.68
# step  778/1000: dist 0.24 loss 3.87
# step  779/1000: dist 0.24 loss 0.77
# step  780/1000: dist 0.23 loss 0.50
# step  781/1000: dist 0.23 loss 2.46
# step  782/1000: dist 0.23 loss 3.88
# step  783/1000: dist 0.23 loss 2.99
# step  784/1000: dist 0.23 loss 0.94
# step  785/1000: dist 0.23 loss 0.29
# step  786/1000: dist 0.23 loss 1.38
# step  787/1000: dist 0.23 loss 2.19
# step  788/1000: dist 0.23 loss 1.41
# step  789/1000: dist 0.23 loss 0.33
# step  790/1000: dist 0.23 loss 0.52
# step  791/1000: dist 0.23 loss 1.29
# step  792/1000: dist 0.23 loss 1.14
# step  793/1000: dist 0.23 loss 0.38
# step  794/1000: dist 0.23 loss 0.33
# step  795/1000: dist 0.23 loss 0.85
# step  796/1000: dist 0.23 loss 0.81
# step  797/1000: dist 0.23 loss 0.32
# step  798/1000: dist 0.23 loss 0.31
# step  799/1000: dist 0.23 loss 0.64
# step  800/1000: dist 0.23 loss 0.55
# step  801/1000: dist 0.23 loss 0.25
# step  802/1000: dist 0.23 loss 0.34
# step  803/1000: dist 0.23 loss 0.52
# step  804/1000: dist 0.23 loss 0.36
# step  805/1000: dist 0.23 loss 0.23
# step  806/1000: dist 0.23 loss 0.37
# step  807/1000: dist 0.22 loss 0.39
# step  808/1000: dist 0.23 loss 0.25
# step  809/1000: dist 0.22 loss 0.26
# step  810/1000: dist 0.23 loss 0.35
# step  811/1000: dist 0.23 loss 0.28
# step  812/1000: dist 0.23 loss 0.23
# step  813/1000: dist 0.23 loss 0.30
# step  814/1000: dist 0.23 loss 0.29
# step  815/1000: dist 0.22 loss 0.23
# step  816/1000: dist 0.23 loss 0.27
# step  817/1000: dist 0.23 loss 0.28
# step  818/1000: dist 0.23 loss 0.23
# step  819/1000: dist 0.23 loss 0.25
# step  820/1000: dist 0.23 loss 0.27
# step  821/1000: dist 0.22 loss 0.23
# step  822/1000: dist 0.23 loss 0.24
# step  823/1000: dist 0.22 loss 0.25
# step  824/1000: dist 0.22 loss 0.23
# step  825/1000: dist 0.22 loss 0.23
# step  826/1000: dist 0.22 loss 0.24
# step  827/1000: dist 0.22 loss 0.23
# step  828/1000: dist 0.22 loss 0.23
# step  829/1000: dist 0.22 loss 0.24
# step  830/1000: dist 0.22 loss 0.23
# step  831/1000: dist 0.22 loss 0.23
# step  832/1000: dist 0.22 loss 0.23
# step  833/1000: dist 0.22 loss 0.22
# step  834/1000: dist 0.22 loss 0.23
# step  835/1000: dist 0.22 loss 0.23
# step  836/1000: dist 0.22 loss 0.22
# step  837/1000: dist 0.22 loss 0.23
# step  838/1000: dist 0.22 loss 0.22
# step  839/1000: dist 0.22 loss 0.23
# step  840/1000: dist 0.22 loss 0.23
# step  841/1000: dist 0.22 loss 0.22
# step  842/1000: dist 0.22 loss 0.23
# step  843/1000: dist 0.22 loss 0.22
# step  844/1000: dist 0.22 loss 0.22
# step  845/1000: dist 0.22 loss 0.23
# step  846/1000: dist 0.22 loss 0.22
# step  847/1000: dist 0.22 loss 0.22
# step  848/1000: dist 0.22 loss 0.22
# step  849/1000: dist 0.22 loss 0.22
# step  850/1000: dist 0.22 loss 0.22
# step  851/1000: dist 0.22 loss 0.22
# step  852/1000: dist 0.22 loss 0.22
# step  853/1000: dist 0.22 loss 0.22
# step  854/1000: dist 0.22 loss 0.22
# step  855/1000: dist 0.22 loss 0.22
# step  856/1000: dist 0.22 loss 0.22
# step  857/1000: dist 0.22 loss 0.22
# step  858/1000: dist 0.22 loss 0.22
# step  859/1000: dist 0.22 loss 0.22
# step  860/1000: dist 0.22 loss 0.22
# step  861/1000: dist 0.22 loss 0.22
# step  862/1000: dist 0.22 loss 0.22
# step  863/1000: dist 0.22 loss 0.22
# step  864/1000: dist 0.22 loss 0.22
# step  865/1000: dist 0.22 loss 0.22
# step  866/1000: dist 0.22 loss 0.22
# step  867/1000: dist 0.22 loss 0.22
# step  868/1000: dist 0.22 loss 0.22
# step  869/1000: dist 0.22 loss 0.22
# step  870/1000: dist 0.22 loss 0.22
# step  871/1000: dist 0.22 loss 0.22
# step  872/1000: dist 0.22 loss 0.22
# step  873/1000: dist 0.22 loss 0.22
# step  874/1000: dist 0.22 loss 0.22
# step  875/1000: dist 0.22 loss 0.22
# step  876/1000: dist 0.22 loss 0.22
# step  877/1000: dist 0.22 loss 0.22
# step  878/1000: dist 0.22 loss 0.22
# step  879/1000: dist 0.22 loss 0.22
# step  880/1000: dist 0.22 loss 0.22
# step  881/1000: dist 0.22 loss 0.22
# step  882/1000: dist 0.22 loss 0.22
# step  883/1000: dist 0.22 loss 0.22
# step  884/1000: dist 0.22 loss 0.22
# step  885/1000: dist 0.22 loss 0.22
# step  886/1000: dist 0.22 loss 0.22
# step  887/1000: dist 0.22 loss 0.22
# step  888/1000: dist 0.22 loss 0.22
# step  889/1000: dist 0.22 loss 0.22
# step  890/1000: dist 0.22 loss 0.22
# step  891/1000: dist 0.22 loss 0.22
# step  892/1000: dist 0.22 loss 0.22
# step  893/1000: dist 0.22 loss 0.22
# step  894/1000: dist 0.22 loss 0.22
# step  895/1000: dist 0.22 loss 0.22
# step  896/1000: dist 0.22 loss 0.22
# step  897/1000: dist 0.22 loss 0.22
# step  898/1000: dist 0.22 loss 0.22
# step  899/1000: dist 0.22 loss 0.22
# step  900/1000: dist 0.22 loss 0.22
# step  901/1000: dist 0.22 loss 0.22
# step  902/1000: dist 0.22 loss 0.22
# step  903/1000: dist 0.22 loss 0.22
# step  904/1000: dist 0.22 loss 0.22
# step  905/1000: dist 0.22 loss 0.22
# step  906/1000: dist 0.22 loss 0.22
# step  907/1000: dist 0.22 loss 0.22
# step  908/1000: dist 0.22 loss 0.22
# step  909/1000: dist 0.22 loss 0.22
# step  910/1000: dist 0.22 loss 0.22
# step  911/1000: dist 0.22 loss 0.22
# step  912/1000: dist 0.22 loss 0.22
# step  913/1000: dist 0.22 loss 0.22
# step  914/1000: dist 0.22 loss 0.22
# step  915/1000: dist 0.22 loss 0.22
# step  916/1000: dist 0.22 loss 0.22
# step  917/1000: dist 0.22 loss 0.22
# step  918/1000: dist 0.22 loss 0.22
# step  919/1000: dist 0.22 loss 0.22
# step  920/1000: dist 0.22 loss 0.22
# step  921/1000: dist 0.22 loss 0.22
# step  922/1000: dist 0.22 loss 0.22
# step  923/1000: dist 0.22 loss 0.22
# step  924/1000: dist 0.22 loss 0.22
# step  925/1000: dist 0.22 loss 0.22
# step  926/1000: dist 0.22 loss 0.22
# step  927/1000: dist 0.22 loss 0.22
# step  928/1000: dist 0.22 loss 0.22
# step  929/1000: dist 0.22 loss 0.22
# step  930/1000: dist 0.22 loss 0.22
# step  931/1000: dist 0.22 loss 0.22
# step  932/1000: dist 0.22 loss 0.22
# step  933/1000: dist 0.22 loss 0.22
# step  934/1000: dist 0.22 loss 0.22
# step  935/1000: dist 0.22 loss 0.22
# step  936/1000: dist 0.22 loss 0.22
# step  937/1000: dist 0.22 loss 0.22
# step  938/1000: dist 0.22 loss 0.22
# step  939/1000: dist 0.22 loss 0.22
# step  940/1000: dist 0.22 loss 0.22
# step  941/1000: dist 0.22 loss 0.22
# step  942/1000: dist 0.22 loss 0.22
# step  943/1000: dist 0.22 loss 0.22
# step  944/1000: dist 0.22 loss 0.22
# step  945/1000: dist 0.22 loss 0.22
# step  946/1000: dist 0.22 loss 0.22
# step  947/1000: dist 0.22 loss 0.22
# step  948/1000: dist 0.22 loss 0.22
# step  949/1000: dist 0.22 loss 0.22
# step  950/1000: dist 0.22 loss 0.22
# step  951/1000: dist 0.22 loss 0.22
# step  952/1000: dist 0.22 loss 0.22
# step  953/1000: dist 0.22 loss 0.22
# step  954/1000: dist 0.22 loss 0.22
# step  955/1000: dist 0.22 loss 0.22
# step  956/1000: dist 0.22 loss 0.22
# step  957/1000: dist 0.22 loss 0.22
# step  958/1000: dist 0.22 loss 0.22
# step  959/1000: dist 0.22 loss 0.22
# step  960/1000: dist 0.22 loss 0.22
# step  961/1000: dist 0.22 loss 0.22
# step  962/1000: dist 0.22 loss 0.22
# step  963/1000: dist 0.22 loss 0.22
# step  964/1000: dist 0.22 loss 0.22
# step  965/1000: dist 0.22 loss 0.22
# step  966/1000: dist 0.22 loss 0.22
# step  967/1000: dist 0.22 loss 0.22
# step  968/1000: dist 0.22 loss 0.22
# step  969/1000: dist 0.22 loss 0.22
# step  970/1000: dist 0.22 loss 0.22
# step  971/1000: dist 0.22 loss 0.22
# step  972/1000: dist 0.22 loss 0.22
# step  973/1000: dist 0.22 loss 0.22
# step  974/1000: dist 0.22 loss 0.22
# step  975/1000: dist 0.22 loss 0.22
# step  976/1000: dist 0.22 loss 0.22
# step  977/1000: dist 0.22 loss 0.22
# step  978/1000: dist 0.22 loss 0.22
# step  979/1000: dist 0.22 loss 0.22
# step  980/1000: dist 0.22 loss 0.22
# step  981/1000: dist 0.22 loss 0.22
# step  982/1000: dist 0.22 loss 0.22
# step  983/1000: dist 0.22 loss 0.22
# step  984/1000: dist 0.22 loss 0.22
# step  985/1000: dist 0.22 loss 0.22
# step  986/1000: dist 0.22 loss 0.22
# step  987/1000: dist 0.22 loss 0.22
# step  988/1000: dist 0.22 loss 0.22
# step  989/1000: dist 0.22 loss 0.22
# step  990/1000: dist 0.22 loss 0.22
# step  991/1000: dist 0.22 loss 0.22
# step  992/1000: dist 0.22 loss 0.22
# step  993/1000: dist 0.22 loss 0.22
# step  994/1000: dist 0.22 loss 0.22
# step  995/1000: dist 0.22 loss 0.22
# step  996/1000: dist 0.22 loss 0.22
# step  997/1000: dist 0.22 loss 0.22
# step  998/1000: dist 0.22 loss 0.22
# step  999/1000: dist 0.22 loss 0.22
# step 1000/1000: dist 0.22 loss 0.22
# Elapsed: 129.4 s

# %% [markdown]
# With the conversion complete, lets have a look at the two GANs.

# %%
img_gan_source = cv2.imread('/content/out_source/proj.png')
img = cv2.cvtColor(img_gan_source, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('source-gan')
plt.show()

# %%
img_gan_target = cv2.imread('/content/out_target/proj.png')
img = cv2.cvtColor(img_gan_target, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('target-gan')
plt.show()

# %% [markdown]
# # Build the Video
#
# The following code builds a transition video between the two latent vectors previously obtained.

# %%
lvec1 = np.load('/content/out_source/projected_w.npz')['w'][:, 2:, :]
lvec2 = np.load('/content/out_target/projected_w.npz')['w']

print(lvec1.shape, lvec2.shape)
# Out:
# (1, 16, 512) (1, 16, 512)

# %%
import torch
import dnnlib
import legacy
import PIL.Image
import numpy as np
import imageio
from tqdm.notebook import tqdm

lvec1 = np.load('/content/out_source/projected_w.npz')['w'][:, :16, :]
lvec2 = np.load('/content/out_target/projected_w.npz')['w']

network_pkl = "https://nvlabs-fi-cdn.nvidia.com/stylegan2-ada-pytorch/pretrained/afhqcat.pkl"
device = torch.device('cuda')
with dnnlib.util.open_url(network_pkl) as fp:
    G = legacy.load_network_pkl(fp)['G_ema'].requires_grad_(False).to(device) # type: ignore

diff = lvec2 - lvec1
step = diff / STEPS
current = lvec1.copy()
target_uint8 = np.array([1024,1024,3], dtype=np.uint8)

video = imageio.get_writer('/content/movie.mp4', mode='I', fps=FPS, codec='libx264', bitrate='16M')

for j in tqdm(range(STEPS)):
  z = torch.from_numpy(current).to(device)
  synth_image = G.synthesis(z, noise_mode='const')
  synth_image = (synth_image + 1) * (255/2)
  synth_image = synth_image.permute(0, 2, 3, 1).clamp(0, 255).to(torch.uint8)[0].cpu().numpy()

  repeat = FREEZE_STEPS if j==0 or j==(STEPS-1) else 1
   
  for i in range(repeat):
    video.append_data(synth_image)
  current = current + step


video.close()
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]

# %%
lvec1.shape, lvec2.shape
# Out:
# ((1, 16, 512), (1, 16, 512))

# %% [markdown]
# # Download your Video
#
# If you made it through all of these steps, you are now ready to download your video.

# %%
from google.colab import files
files.download("movie.mp4")

# %% [markdown]
# # Exploring Some Python Files

# %% [markdown]
# *First off, what is projector.py?*
#
# We know at a high-level, this basically takes an input image and the network model tries to find the best latent vector to represent it.
#
# ```py
# @click.option('--network', 'network_pkl', help='Network pickle filename', required=True)
# @click.option('--target', 'target_fname', help='Target image file to project to', required=True, metavar='FILE')
# @click.option('--num-steps',              help='Number of optimization steps', type=int, default=1000, show_default=True)
# @click.option('--seed',                   help='Random seed', type=int, default=303, show_default=True)
# @click.option('--save-video',             help='Save an mp4 video of optimization progress', type=bool, default=True, show_default=True)
# @click.option('--outdir',                 help='Where to save the output images', required=True, metavar='DIR')
# ```
#
# Well, that about sums up the parameters! Looking through a bit of the code, it does, indeed, look like they are optimizing a latent vector.

# %% [markdown]
# Well, that's great. We understand this projector.py file on a high level and how to use it. *Now how does the "Build the Video" section work?*
#
# From a 2nd longer look, it looks like it's taking the difference between the 2 vectors and dividing it into intervals. Each interval mark is a new image. At each interval, the synthesis network will predict an image. These images are all put into an mp4.
